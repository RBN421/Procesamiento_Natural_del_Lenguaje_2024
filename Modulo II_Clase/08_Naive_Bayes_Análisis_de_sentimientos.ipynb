# %% [markdown]
# <img style="float: left;;" src='https://github.com/gdesirena/Procesamiento_Natural_del_Lenguaje_2024/blob/main/Modulo%20II/Figures/alinco.png?raw=1' /></a>
#
# # Modulo I: Naive Bayes para Análisis de Sentimientos

# %% [markdown]
# Aplicaremos Naive Bayes para el análisis de sentimientos de tweets, lo que haremos en este notebook será:
#
# * Entrenar un modelo de Naive Bayes para el análisis de sentimientos
# * Probaremos el modelo creado
# * Calcularemos las proporciones de palabras positivas a palabras negativas
# * Veremos una función de análisis de errores
# * Predeciremos un tweet

# %%
from utils import process_tweet, lookup
import pdb
from nltk.corpus import stopwords, twitter_samples
import numpy as np
import pandas as pd
import nltk
import string
from nltk.tokenize import TweetTokenizer
from os import getcwd

# %% [markdown]
# Si aún no se han descargado:
# ```
# nltk.download('stopwords')
# nltk.download('twitter_samples')
# ```

# %%
nltk.download('stopwords')
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# True

# %%
# add folder, tmp2, from our local workspace containing pre-downloaded corpora files to nltk's data path
filePath = f"{getcwd()}/../tmp2/"
nltk.data.path.append(filePath)

# %%
# get the sets of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# split the data into two pieces, one for training and one for testing (validation set)
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

# avoid assumptions about the length of all_positive_tweets
train_y = np.append(np.ones(len(train_pos)), np.zeros(len(train_neg)))
test_y = np.append(np.ones(len(test_pos)), np.zeros(len(test_neg)))

# %% [markdown]
# # Preprocesamiento de los datos
#
# Para cualquier proyecto de aprendizaje automático, una vez que se haya recopilado los datos, el primer paso es el preprocesamiento.
#
# - **Eliminar el ruido**: eliminar las palabras que no dicen mucho sobre el contenido. Estos incluyen todas las palabras comunes como 'I, you, are, is, etc...' que no nos darían suficiente información sobre el sentimiento.
# - También eliminaremos los tickers del mercado de valores, los símbolos de retuits, los hipervínculos y los hashtags porque no pueden brindarle mucha información sobre el sentimiento.
# - También hay que eliminar toda la puntuación de un tweet. La razón para hacer esto es porque queremos tratar las palabras con o sin puntuación como la misma palabra, en lugar de tratar las palabras "happy", "happy?", "happy!", "happy," and "happy." como palabras diferentes.
# - Por último, desea utilizaremos la técnica de stemming para realizar un seguimiento de una sola variación de cada palabra. En otras palabras, trataremos "motivation", "motivated", y "motivate" de manera similar agrupándolos dentro de la misma raíz de "motiv-".
#
# Recuerden que ya tenemos una función para esto (`process_tweet()`)

# %%
custom_tweet = "RT @Twitter @chapagain Hello There! Have a great day. :) #good #morning http://chapagain.com.np"

# Utilizar el metodo prep
from utilss import Utilities as prep
obj_prep = prep()
print(obj_prep.process_tweet(custom_tweet))
# Out:
# This is the Utilities Constructor
# ['hello', 'great', 'day', ':)', 'good', 'morn']

# %% [markdown]
# ## Funciones de ayuda
#
# Para entrenar el modelo, necesitaremos construir un diccionario donde las claves sean una tupla (word, label) y los valores sean la frecuencia correspondiente. Tenga en cuenta que las etiquetas que usaremos aquí son 1 para positivo y 0 para negativo.
#
# Implementaremos la función `lookup()` que toma del diccionario `freqs` una palabra y una etiqueta (1 or 0) y retorna el número de veces que la palabra y esa etiqueta aparecen en la collección de tweets.
#
# Por ejemplo: Dado una lista de sentencias en los tweets: `["i am rather excited", "you are rather happy"]` y la etiqueta 1, la función regresara el diccionario que contiene lo siguiente:
#
# {
#     ("rather", 1): 2
#     ("happi", 1) : 1
#     ("excit", 1) : 1
# }
#
# - Observe cómo para cada palabra en la cadena dada, se asigna la misma etiqueta 1 a cada palabra.
# - Observe cómo las palabras "i" y "am" no se guardan, ya que fue eliminada por process_tweet porque es una stopword.
# - Observe cómo la palabra "rather" aparece dos veces en la lista de tweets, por lo que su valor de recuento es 2.
#
# Crearemos una función `count_tweets()` que toma una lista de tweets como entrada, las limpia, y regresa un diccionario.
#
# - La clave en el diccionario es una tupla que contiene la palabra despues del stemming y su etiqueta de clase, Ej. ("happi", 1).
# - El valor del key, será la cantidad de veces que esta palabra aparece en la colección de tweets dada (un número entero).

# %%
def count_tweets(result, tweets, ys):
    '''
    Input:
    result: un diccionaio que nos va servir para mapear las frecuencias de las palabras
    tweets: la lista de tweets
    ys: el sentimiento (positivo->1, negativo->0)
    output:
    result
    '''

    for y, tweet in zip(ys, tweets):
      for word in obj_prep.process_tweet(tweet):
        #definir el key, el cual es la palabra y la etiqueta en una tupla
        pair = (word, y)

        # si el key existe en el diccionario, hay que incrementar el conteo
        if pair in result:
          result[pair] +=1
        else:
          result[pair] = 1

    return result

# %%
results = {}
tweets = ['I am happy', "I am tricked", "I am sad", 'I am tired']
ys = [1, 0, 0, 0]

# %%
# Testing your function
r = count_tweets(results, tweets, ys)
r
# Out:
# {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 1}

# %% [markdown]
# ## Entrenar el modelo usando Naive Bayes
#
# Naive bayes es un algoritmo que se puede usar para aplicaciones como el análisis de sentimientos.
#
#
# #### ¿Cómo entrenamos un clasificador con Naive Bayes ?
#
# - La primera parte del entrenamiento de un clasificador Naive Bayes es identificar el número de clases que tiene.
# - Crearemos una probabilidad para cada clase.
#
#
# $P(D_{pos})$ denota la probabilidad que el documento sea positivo.
# $P(D_{neg})$ denota la probabilidad que el documento sea negativo.
#
# Utilizaremos las fórmulas de la siguiente manera y almacenaremos los valores en un diccionario:
#
# $$P(D_{pos}) = \frac{D_{pos}}{D}\tag{1}$$
#
# $$P(D_{neg}) = \frac{D_{neg}}{D}\tag{2}$$
#
# Donde $ D $ es el número total de documentos, o tweets en este caso, $ D_ {pos} $ es el número total de tweets positivos y $ D_ {neg} $ es el número total de tweets negativos.

# %% [markdown]
# #### Prior y Logprior
#
# La probabilidad previa (prior) representa la probabilidad subyacente de la población (tweets) de que un tweet sea positivo frente a uno negativo. En otras palabras, si no tuviéramos información específica y seleccionáramos a ciegas un tweet del conjunto de la población, ¿cuál es la probabilidad de que sea positivo frente a que sea negativo? Ese es el "previo".
#
# El "prior" es el ratio de las probabilidades $\frac{P(D_{pos})}{P(D_{neg})}$. Podemos tomar el logaritmo del "prior" para cambiar su escala, y lo llamaremos logprior.
#
#
# $$\text{logprior} = log \left( \frac{P(D_{pos})}{P(D_{neg})} \right) = log \left( \frac{D_{pos}}{D_{neg}} \right)$$.
#
# Note que $log(\frac{A}{B})$ es igual a $log(A) - log(B)$.  Por lo tanto logprior puede calcularse como la diferencia de dos logaritmos (propiedad de logaritmos).
#
#
# $$\text{logprior} = \log (P(D_{pos})) - \log (P(D_{neg})) = \log (D_{pos}) - \log (D_{neg})\tag{3}$$

# %% [markdown]
# #### Probabilidad positiva y negativa de una palabra
# Para calcular la probabilidad positiva y la probabilidad negativa de una palabra específica en el vocabulario, usaremos las siguientes notaciones:
#
# - $freq_{pos}$ y $freq_{neg}$ son las frecuencias de esa palabra específica en la clase positiva o negativa. En otras palabras, la frecuencia positiva de una palabra es el número de veces que se cuenta la palabra con la etiqueta 1.
# - $ N_ {pos} $ y $ N_ {neg} $ son el número total de palabras positivas y negativas para todos los documentos (para todos los tweets), respectivamente.
#
# - $V$ es el número de palabras únicas en todo el conjunto de documentos, para todas las clases, ya sean positivas o negativas.
#
# Los usaremos para calcular la probabilidad positiva y negativa de una palabra específica usando la fórmula:
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# Note que añadimos "+1" en el numerador para el smoothing aditivo.  Este [artículo](https://en.wikipedia.org/wiki/Additive_smoothing) explica detalladamente sobre el smoothing aditivo.

# %% [markdown]
# #### Log likelihood
# Para calcular la loglikelihood (probabilidad mínima) de esa misma palabra, podemos implementar las siguientes ecuaciones:
#
# $$\text{loglikelihood} = \log \left(\frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$$

# %% [markdown]
# ##### Creación del diccionario de  frecuencias (`freqs` )
# - Dada la función `count_tweets ()`, podemos calcular un diccionario llamado `freqs` que contiene todas las frecuencias.
# - En este diccionario `freqs`, la clave es la tupla (word,label)
# - El valor es el número de veces que ha aparecido.

# %%
#obtener el diccionario
freqs = count_tweets({}, train_x, train_y)

# %%
freqs
# Out:
# {('followfriday', 1.0): 23,
#  ('top', 1.0): 30,
#  ('engag', 1.0): 7,
#  ('member', 1.0): 14,
#  ('commun', 1.0): 27,
#  ('week', 1.0): 72,
#  (':)', 1.0): 2847,
#  ('hey', 1.0): 60,
#  ('jame', 1.0): 7,
#  ('odd', 1.0): 2,
#  (':/', 1.0): 5,
#  ('pleas', 1.0): 80,
#  ('call', 1.0): 27,
#  ('contact', 1.0): 4,
#  ('centr', 1.0): 1,
#  ('02392441234', 1.0): 1,
#  ('abl', 1.0): 6,
#  ('assist', 1.0): 1,
#  ('mani', 1.0): 28,
#  ('thank', 1.0): 504,
#  ('listen', 1.0): 14,
#  ('last', 1.0): 39,
#  ('night', 1.0): 55,
#  ('bleed', 1.0): 2,
#  ('amaz', 1.0): 41,
#  ('track', 1.0): 5,
#  ('scotland', 1.0): 2,
#  ('congrat', 1.0): 15,
#  ('yeaaah', 1.0): 1,
#  ('yipppi', 1.0): 1,
#  ('accnt', 1.0): 2,
#  ('verifi', 1.0): 2,
#  ('rqst', 1.0): 1,
#  ('succeed', 1.0): 1,
#  ('got', 1.0): 57,
#  ('blue', 1.0): 8,
#  ('tick', 1.0): 1,
#  ('mark', 1.0): 1,
#  ('fb', 1.0): 4,
#  ('profil', 1.0): 2,
#  ('15', 1.0): 4,
#  ('day', 1.0): 187,
#  ('one', 1.0): 90,
#  ('irresist', 1.0): 2,
#  ('flipkartfashionfriday', 1.0): 16,
#  ('like', 1.0): 187,
#  ('keep', 1.0): 55,
#  ('love', 1.0): 336,
#  ('custom', 1.0): 4,
#  ('wait', 1.0): 55,
#  ('long', 1.0): 27,
#  ('hope', 1.0): 113,
#  ('enjoy', 1.0): 57,
#  ('happi', 1.0): 161,
#  ('friday', 1.0): 91,
#  ('lwwf', 1.0): 1,
#  ('second', 1.0): 8,
#  ('thought', 1.0): 21,
#  ('’', 1.0): 17,
#  ('enough', 1.0): 16,
#  ('time', 1.0): 100,
#  ('dd', 1.0): 1,
#  ('new', 1.0): 111,
#  ('short', 1.0): 6,
#  ('enter', 1.0): 9,
#  ('system', 1.0): 2,
#  ('sheep', 1.0): 1,
#  ('must', 1.0): 14,
#  ('buy', 1.0): 9,
#  ('jgh', 1.0): 4,
#  ('go', 1.0): 120,
#  ('bayan', 1.0): 1,
#  (':d', 1.0): 498,
#  ('bye', 1.0): 5,
#  ('act', 1.0): 6,
#  ('mischiev', 1.0): 1,
#  ('etl', 1.0): 1,
#  ('layer', 1.0): 1,
#  ('in-hous', 1.0): 1,
#  ('wareh', 1.0): 1,
#  ('app', 1.0): 12,
#  ('katamari', 1.0): 1,
#  ('well', 1.0): 66,
#  ('…', 1.0): 31,
#  ('name', 1.0): 12,
#  ('impli', 1.0): 1,
#  (':p', 1.0): 104,
#  ('influenc', 1.0): 16,
#  ('big', 1.0): 27,
#  ('...', 1.0): 227,
#  ('juici', 1.0): 3,
#  ('selfi', 1.0): 11,
#  ('follow', 1.0): 319,
#  ('perfect', 1.0): 17,
#  ('alreadi', 1.0): 19,
#  ('know', 1.0): 120,
#  ("what'", 1.0): 14,
#  ('great', 1.0): 134,
#  ('opportun', 1.0): 17,
#  ('junior', 1.0): 2,
#  ('triathlet', 1.0): 1,
#  ('age', 1.0): 2,
#  ('12', 1.0): 5,
#  ('13', 1.0): 5,
#  ('gatorad', 1.0): 1,
#  ('seri', 1.0): 4,
#  ('get', 1.0): 164,
#  ('entri', 1.0): 3,
#  ('lay', 1.0): 3,
#  ('greet', 1.0): 4,
#  ('card', 1.0): 6,
#  ('rang', 1.0): 2,
#  ('print', 1.0): 3,
#  ('today', 1.0): 86,
#  ('job', 1.0): 34,
#  (':-)', 1.0): 543,
#  ("friend'", 1.0): 3,
#  ('lunch', 1.0): 3,
#  ('yummm', 1.0): 1,
#  ('nostalgia', 1.0): 1,
#  ('tb', 1.0): 1,
#  ('ku', 1.0): 1,
#  ('id', 1.0): 8,
#  ('conflict', 1.0): 1,
#  ('help', 1.0): 37,
#  ("here'", 1.0): 20,
#  ('screenshot', 1.0): 2,
#  ('work', 1.0): 88,
#  ('hi', 1.0): 154,
#  ('liv', 1.0): 2,
#  ('hello', 1.0): 49,
#  ('need', 1.0): 62,
#  ('someth', 1.0): 25,
#  ('u', 1.0): 136,
#  ('fm', 1.0): 2,
#  ('twitter', 1.0): 25,
#  ('—', 1.0): 22,
#  ('sure', 1.0): 37,
#  ('thing', 1.0): 48,
#  ('dm', 1.0): 34,
#  ('x', 1.0): 50,
#  ("i'v", 1.0): 25,
#  ('heard', 1.0): 9,
#  ('four', 1.0): 5,
#  ('season', 1.0): 5,
#  ('pretti', 1.0): 17,
#  ('dope', 1.0): 2,
#  ('penthous', 1.0): 1,
#  ('obv', 1.0): 1,
#  ('gobigorgohom', 1.0): 1,
#  ('fun', 1.0): 45,
#  ("y'all", 1.0): 3,
#  ('yeah', 1.0): 30,
#  ('suppos', 1.0): 6,
#  ('lol', 1.0): 48,
#  ('chat', 1.0): 9,
#  ('bit', 1.0): 16,
#  ('youth', 1.0): 14,
#  ('💅🏽', 1.0): 1,
#  ('💋', 1.0): 2,
#  ('seen', 1.0): 6,
#  ('year', 1.0): 33,
#  ('rest', 1.0): 9,
#  ('goe', 1.0): 4,
#  ('quickli', 1.0): 3,
#  ('bed', 1.0): 8,
#  ('music', 1.0): 15,
#  ('fix', 1.0): 6,
#  ('dream', 1.0): 17,
#  ('spiritu', 1.0): 1,
#  ('ritual', 1.0): 1,
#  ('festiv', 1.0): 7,
#  ('népal', 1.0): 1,
#  ('begin', 1.0): 4,
#  ('line-up', 1.0): 4,
#  ('left', 1.0): 10,
#  ('see', 1.0): 156,
#  ('sarah', 1.0): 4,
#  ('send', 1.0): 17,
#  ('us', 1.0): 91,
#  ('email', 1.0): 22,
#  ('bitsy@bitdefender.com', 1.0): 1,
#  ("we'll", 1.0): 12,
#  ('asap', 1.0): 5,
#  ('kik', 1.0): 16,
#  ('hatessuc', 1.0): 1,
#  ('32429', 1.0): 1,
#  ('kikm', 1.0): 1,
#  ('lgbt', 1.0): 2,
#  ('tinder', 1.0): 1,
#  ('nsfw', 1.0): 1,
#  ('akua', 1.0): 1,
#  ('cumshot', 1.0): 1,
#  ('come', 1.0): 63,
#  ('hous', 1.0): 5,
#  ('nsn_supplement', 1.0): 1,
#  ('effect', 1.0): 2,
#  ('press', 1.0): 1,
#  ('releas', 1.0): 11,
#  ('distribut', 1.0): 1,
#  ('result', 1.0): 2,
#  ('link', 1.0): 13,
#  ('remov', 1.0): 3,
#  ('pressreleas', 1.0): 1,
#  ('newsdistribut', 1.0): 1,
#  ('bam', 1.0): 44,
#  ('bestfriend', 1.0): 50,
#  ('lot', 1.0): 80,
#  ('warsaw', 1.0): 44,
#  ('<3', 1.0): 118,
#  ('x46', 1.0): 1,
#  ('everyon', 1.0): 45,
#  ('watch', 1.0): 32,
#  ('documentari', 1.0): 1,
#  ('earthl', 1.0): 1,
#  ('youtub', 1.0): 8,
#  ('support', 1.0): 25,
#  ('buuut', 1.0): 1,
#  ('oh', 1.0): 44,
#  ('look', 1.0): 109,
#  ('forward', 1.0): 20,
#  ('visit', 1.0): 25,
#  ('next', 1.0): 37,
#  ('letsgetmessi', 1.0): 1,
#  ('jo', 1.0): 1,
#  ('make', 1.0): 69,
#  ('feel', 1.0): 33,
#  ('better', 1.0): 40,
#  ('never', 1.0): 31,
#  ('anyon', 1.0): 7,
#  ('kpop', 1.0): 1,
#  ('flesh', 1.0): 1,
#  ('good', 1.0): 191,
#  ('girl', 1.0): 34,
#  ('best', 1.0): 49,
#  ('wish', 1.0): 29,
#  ('reason', 1.0): 10,
#  ('epic', 1.0): 1,
#  ('soundtrack', 1.0): 1,
#  ('shout', 1.0): 11,
#  ('ad', 1.0): 10,
#  ('video', 1.0): 29,
#  ('playlist', 1.0): 5,
#  ('would', 1.0): 70,
#  ('dear', 1.0): 15,
#  ('jordan', 1.0): 1,
#  ('okay', 1.0): 31,
#  ('fake', 1.0): 1,
#  ('gameplay', 1.0): 1,
#  (';)', 1.0): 22,
#  ('haha', 1.0): 44,
#  ('im', 1.0): 38,
#  ('kid', 1.0): 13,
#  ('stuff', 1.0): 11,
#  ('exactli', 1.0): 5,
#  ('product', 1.0): 11,
#  ('line', 1.0): 6,
#  ('etsi', 1.0): 1,
#  ('shop', 1.0): 12,
#  ('check', 1.0): 38,
#  ('vacat', 1.0): 5,
#  ('recharg', 1.0): 1,
#  ('normal', 1.0): 5,
#  ('charger', 1.0): 2,
#  ('asleep', 1.0): 7,
#  ('talk', 1.0): 37,
#  ('sooo', 1.0): 6,
#  ('someon', 1.0): 29,
#  ('text', 1.0): 12,
#  ('ye', 1.0): 60,
#  ('bet', 1.0): 6,
#  ("he'll", 1.0): 2,
#  ('fit', 1.0): 2,
#  ('hear', 1.0): 24,
#  ('speech', 1.0): 1,
#  ('piti', 1.0): 2,
#  ('green', 1.0): 2,
#  ('garden', 1.0): 5,
#  ('midnight', 1.0): 1,
#  ('sun', 1.0): 6,
#  ('beauti', 1.0): 45,
#  ('canal', 1.0): 1,
#  ('dasvidaniya', 1.0): 1,
#  ('till', 1.0): 16,
#  ('scout', 1.0): 1,
#  ('sg', 1.0): 1,
#  ('futur', 1.0): 9,
#  ('wlan', 1.0): 1,
#  ('pro', 1.0): 4,
#  ('confer', 1.0): 1,
#  ('asia', 1.0): 1,
#  ('chang', 1.0): 20,
#  ('lollipop', 1.0): 1,
#  ('🍭', 1.0): 1,
#  ('nez', 1.0): 1,
#  ('agnezmo', 1.0): 1,
#  ('oley', 1.0): 1,
#  ('mama', 1.0): 1,
#  ('stand', 1.0): 6,
#  ('stronger', 1.0): 1,
#  ('god', 1.0): 14,
#  ('misti', 1.0): 1,
#  ('babi', 1.0): 17,
#  ('cute', 1.0): 21,
#  ('woohoo', 1.0): 3,
#  ("can't", 1.0): 31,
#  ('sign', 1.0): 9,
#  ('yet', 1.0): 12,
#  ('still', 1.0): 37,
#  ('think', 1.0): 48,
#  ('mka', 1.0): 5,
#  ('liam', 1.0): 5,
#  ('access', 1.0): 3,
#  ('welcom', 1.0): 54,
#  ('stat', 1.0): 51,
#  ('arriv', 1.0): 57,
#  ('1', 1.0): 60,
#  ('unfollow', 1.0): 53,
#  ('via', 1.0): 60,
#  ('surpris', 1.0): 10,
#  ('figur', 1.0): 5,
#  ('happybirthdayemilybett', 1.0): 1,
#  ('sweet', 1.0): 16,
#  ('talent', 1.0): 4,
#  ('2', 1.0): 41,
#  ('plan', 1.0): 21,
#  ('drain', 1.0): 1,
#  ('gotta', 1.0): 4,
#  ('timezon', 1.0): 1,
#  ('parent', 1.0): 4,
#  ('proud', 1.0): 11,
#  ('least', 1.0): 14,
#  ('mayb', 1.0): 17,
#  ('sometim', 1.0): 11,
#  ('grade', 1.0): 4,
#  ('al', 1.0): 3,
#  ('grand', 1.0): 4,
#  ('manila_bro', 1.0): 1,
#  ('chosen', 1.0): 1,
#  ('let', 1.0): 57,
#  ('around', 1.0): 14,
#  ('..', 1.0): 100,
#  ('side', 1.0): 13,
#  ('world', 1.0): 23,
#  ('eh', 1.0): 2,
#  ('take', 1.0): 30,
#  ('care', 1.0): 12,
#  ('final', 1.0): 24,
#  ('fuck', 1.0): 20,
#  ('weekend', 1.0): 61,
#  ('real', 1.0): 18,
#  ('x45', 1.0): 1,
#  ('join', 1.0): 21,
#  ('hushedcallwithfraydo', 1.0): 1,
#  ('gift', 1.0): 7,
#  ('yeahhh', 1.0): 1,
#  ('hushedpinwithsammi', 1.0): 2,
#  ('event', 1.0): 7,
#  ('might', 1.0): 21,
#  ('luv', 1.0): 4,
#  ('realli', 1.0): 66,
#  ('appreci', 1.0): 28,
#  ('share', 1.0): 41,
#  ('wow', 1.0): 14,
#  ('tom', 1.0): 5,
#  ('gym', 1.0): 3,
#  ('monday', 1.0): 7,
#  ('invit', 1.0): 15,
#  ('scope', 1.0): 5,
#  ('friend', 1.0): 40,
#  ('nude', 1.0): 1,
#  ('sleep', 1.0): 35,
#  ('birthday', 1.0): 53,
#  ('want', 1.0): 69,
#  ('t-shirt', 1.0): 2,
#  ('cool', 1.0): 29,
#  ('haw', 1.0): 1,
#  ('phela', 1.0): 1,
#  ('mom', 1.0): 7,
#  ('obvious', 1.0): 1,
#  ('princ', 1.0): 1,
#  ('charm', 1.0): 1,
#  ('stage', 1.0): 2,
#  ('luck', 1.0): 26,
#  ('tyler', 1.0): 1,
#  ('hipster', 1.0): 1,
#  ('glass', 1.0): 3,
#  ('marti', 1.0): 2,
#  ('glad', 1.0): 41,
#  ('done', 1.0): 40,
#  ('afternoon', 1.0): 7,
#  ('read', 1.0): 27,
#  ('kahfi', 1.0): 1,
#  ('finish', 1.0): 15,
#  ('ohmyg', 1.0): 1,
#  ('yaya', 1.0): 3,
#  ('dub', 1.0): 1,
#  ('stalk', 1.0): 2,
#  ('ig', 1.0): 3,
#  ('gondooo', 1.0): 1,
#  ('moo', 1.0): 2,
#  ('tologooo', 1.0): 1,
#  ('becom', 1.0): 8,
#  ('detail', 1.0): 8,
#  ('zzz', 1.0): 1,
#  ('xx', 1.0): 33,
#  ('physiotherapi', 1.0): 1,
#  ('hashtag', 1.0): 3,
#  ('💪', 1.0): 1,
#  ('monica', 1.0): 1,
#  ('miss', 1.0): 17,
#  ('sound', 1.0): 20,
#  ('morn', 1.0): 68,
#  ("that'", 1.0): 49,
#  ('x43', 1.0): 1,
#  ('definit', 1.0): 20,
#  ('tri', 1.0): 34,
#  ('tonight', 1.0): 15,
#  ('took', 1.0): 7,
#  ('advic', 1.0): 6,
#  ('treviso', 1.0): 1,
#  ('concert', 1.0): 23,
#  ('citi', 1.0): 26,
#  ('countri', 1.0): 22,
#  ("i'll", 1.0): 73,
#  ('start', 1.0): 56,
#  ('fine', 1.0): 7,
#  ('gorgeou', 1.0): 9,
#  ('xo', 1.0): 2,
#  ('oven', 1.0): 2,
#  ('roast', 1.0): 1,
#  ('garlic', 1.0): 1,
#  ('oliv', 1.0): 1,
#  ('oil', 1.0): 4,
#  ('dri', 1.0): 4,
#  ('tomato', 1.0): 1,
#  ('basil', 1.0): 1,
#  ('centuri', 1.0): 1,
#  ('tuna', 1.0): 1,
#  ('right', 1.0): 38,
#  ('back', 1.0): 74,
#  ('atchya', 1.0): 1,
#  ('even', 1.0): 26,
#  ('almost', 1.0): 8,
#  ('chanc', 1.0): 3,
#  ('cheer', 1.0): 17,
#  ('po', 1.0): 3,
#  ('ice', 1.0): 6,
#  ('cream', 1.0): 6,
#  ('agre', 1.0): 13,
#  ('100', 1.0): 6,
#  ('heheheh', 1.0): 2,
#  ('that', 1.0): 10,
#  ('point', 1.0): 11,
#  ('stay', 1.0): 20,
#  ('home', 1.0): 20,
#  ('soon', 1.0): 38,
#  ('promis', 1.0): 4,
#  ('web', 1.0): 4,
#  ('whatsapp', 1.0): 3,
#  ('volta', 1.0): 1,
#  ('funcionar', 1.0): 1,
#  ('com', 1.0): 2,
#  ('iphon', 1.0): 7,
#  ('jailbroken', 1.0): 1,
#  ('later', 1.0): 11,
#  ('34', 1.0): 3,
#  ('min', 1.0): 7,
#  ('leia', 1.0): 1,
#  ('appear', 1.0): 3,
#  ('hologram', 1.0): 1,
#  ('r2d2', 1.0): 1,
#  ('w', 1.0): 16,
#  ('messag', 1.0): 9,
#  ('obi', 1.0): 1,
#  ('wan', 1.0): 1,
#  ('sit', 1.0): 7,
#  ('luke', 1.0): 4,
#  ('inter', 1.0): 1,
#  ('3', 1.0): 25,
#  ('ucl', 1.0): 1,
#  ('arsen', 1.0): 2,
#  ('small', 1.0): 1,
#  ('team', 1.0): 24,
#  ('pass', 1.0): 10,
#  ('🚂', 1.0): 1,
#  ('dewsburi', 1.0): 2,
#  ('railway', 1.0): 1,
#  ('station', 1.0): 4,
#  ('dew', 1.0): 1,
#  ('west', 1.0): 1,
#  ('yorkshir', 1.0): 2,
#  ('430', 1.0): 1,
#  ('smh', 1.0): 2,
#  ('9:25', 1.0): 1,
#  ('live', 1.0): 21,
#  ('strang', 1.0): 4,
#  ('imagin', 1.0): 5,
#  ('megan', 1.0): 1,
#  ('masaantoday', 1.0): 4,
#  ('a4', 1.0): 3,
#  ('shweta', 1.0): 1,
#  ('tripathi', 1.0): 1,
#  ('5', 1.0): 15,
#  ('20', 1.0): 5,
#  ('kurta', 1.0): 3,
#  ('half', 1.0): 6,
#  ('number', 1.0): 11,
#  ('wsalelov', 1.0): 14,
#  ('ah', 1.0): 12,
#  ('larri', 1.0): 3,
#  ('anyway', 1.0): 14,
#  ('kinda', 1.0): 12,
#  ('goood', 1.0): 1,
#  ('life', 1.0): 36,
#  ('enn', 1.0): 1,
#  ('could', 1.0): 25,
#  ('warmup', 1.0): 1,
#  ('15th', 1.0): 2,
#  ('bath', 1.0): 6,
#  ('dum', 1.0): 2,
#  ('andar', 1.0): 1,
#  ('ram', 1.0): 1,
#  ('sampath', 1.0): 1,
#  ('sona', 1.0): 1,
#  ('mohapatra', 1.0): 1,
#  ('samantha', 1.0): 1,
#  ('edward', 1.0): 1,
#  ('mein', 1.0): 1,
#  ('tulan', 1.0): 1,
#  ('razi', 1.0): 2,
#  ('wah', 1.0): 2,
#  ('josh', 1.0): 1,
#  ('alway', 1.0): 48,
#  ('smile', 1.0): 47,
#  ('pictur', 1.0): 7,
#  ('16.20', 1.0): 1,
#  ('giveitup', 1.0): 1,
#  ('given', 1.0): 3,
#  ('ga', 1.0): 3,
#  ('subsidi', 1.0): 1,
#  ('initi', 1.0): 2,
#  ('propos', 1.0): 3,
#  ('delight', 1.0): 4,
#  ('yesterday', 1.0): 4,
#  ('x42', 1.0): 1,
#  ('lmaoo', 1.0): 2,
#  ('song', 1.0): 16,
#  ('ever', 1.0): 19,
#  ('shall', 1.0): 5,
#  ('littl', 1.0): 29,
#  ('throwback', 1.0): 3,
#  ('outli', 1.0): 1,
#  ('island', 1.0): 2,
#  ('cheung', 1.0): 1,
#  ('chau', 1.0): 1,
#  ('mui', 1.0): 1,
#  ('wo', 1.0): 1,
#  ('total', 1.0): 5,
#  ('differ', 1.0): 10,
#  ('kfckitchentour', 1.0): 2,
#  ('kitchen', 1.0): 3,
#  ('clean', 1.0): 1,
#  ("i'm", 1.0): 140,
#  ('cusp', 1.0): 1,
#  ('test', 1.0): 7,
#  ('water', 1.0): 7,
#  ('reward', 1.0): 1,
#  ('arummzz', 1.0): 2,
#  ("let'", 1.0): 18,
#  ('drive', 1.0): 9,
#  ('travel', 1.0): 19,
#  ('yogyakarta', 1.0): 3,
#  ('jeep', 1.0): 3,
#  ('indonesia', 1.0): 3,
#  ('instamood', 1.0): 3,
#  ('wanna', 1.0): 23,
#  ('skype', 1.0): 3,
#  ('may', 1.0): 16,
#  ('nice', 1.0): 70,
#  ('friendli', 1.0): 1,
#  ('pretend', 1.0): 2,
#  ('film', 1.0): 8,
#  ('congratul', 1.0): 9,
#  ('winner', 1.0): 3,
#  ('cheesydelight', 1.0): 1,
#  ('contest', 1.0): 5,
#  ('address', 1.0): 8,
#  ('guy', 1.0): 48,
#  ('market', 1.0): 5,
#  ('24/7', 1.0): 1,
#  ('14', 1.0): 1,
#  ('hour', 1.0): 24,
#  ('leav', 1.0): 11,
#  ('without', 1.0): 9,
#  ('delay', 1.0): 1,
#  ('actual', 1.0): 13,
#  ('easi', 1.0): 7,
#  ('guess', 1.0): 8,
#  ('train', 1.0): 7,
#  ('wd', 1.0): 1,
#  ('shift', 1.0): 4,
#  ('engin', 1.0): 1,
#  ('etc', 1.0): 2,
#  ('sunburn', 1.0): 1,
#  ('peel', 1.0): 2,
#  ('blog', 1.0): 27,
#  ('huge', 1.0): 9,
#  ('warm', 1.0): 4,
#  ('☆', 1.0): 3,
#  ('complet', 1.0): 10,
#  ('triangl', 1.0): 2,
#  ('northern', 1.0): 1,
#  ('ireland', 1.0): 2,
#  ('sight', 1.0): 1,
#  ('smthng', 1.0): 2,
#  ('fr', 1.0): 3,
#  ('hug', 1.0): 11,
#  ('xoxo', 1.0): 3,
#  ('uu', 1.0): 1,
#  ('jaann', 1.0): 1,
#  ('topnewfollow', 1.0): 2,
#  ('connect', 1.0): 13,
#  ('wonder', 1.0): 26,
#  ('made', 1.0): 38,
#  ('fluffi', 1.0): 1,
#  ('insid', 1.0): 7,
#  ('pirouett', 1.0): 1,
#  ('moos', 1.0): 1,
#  ('trip', 1.0): 12,
#  ('philli', 1.0): 1,
#  ('decemb', 1.0): 2,
#  ("i'd", 1.0): 13,
#  ('dude', 1.0): 6,
#  ('x41', 1.0): 1,
#  ('question', 1.0): 15,
#  ('flaw', 1.0): 1,
#  ('pain', 1.0): 8,
#  ('negat', 1.0): 1,
#  ('strength', 1.0): 2,
#  ('went', 1.0): 10,
#  ('solo', 1.0): 4,
#  ('move', 1.0): 9,
#  ('fav', 1.0): 11,
#  ('nirvana', 1.0): 1,
#  ('smell', 1.0): 2,
#  ('teen', 1.0): 3,
#  ('spirit', 1.0): 1,
#  ('rip', 1.0): 3,
#  ('ami', 1.0): 4,
#  ('winehous', 1.0): 1,
#  ('coupl', 1.0): 5,
#  ('tomhiddleston', 1.0): 1,
#  ('elizabetholsen', 1.0): 1,
#  ('yaytheylookgreat', 1.0): 1,
#  ('goodnight', 1.0): 18,
#  ('vid', 1.0): 8,
#  ('wake', 1.0): 10,
#  ('gonna', 1.0): 16,
#  ('shoot', 1.0): 5,
#  ('itti', 1.0): 2,
#  ('bitti', 1.0): 2,
#  ('teeni', 1.0): 2,
#  ('bikini', 1.0): 3,
#  ('much', 1.0): 73,
#  ('4th', 1.0): 4,
#  ('togeth', 1.0): 6,
#  ('end', 1.0): 13,
#  ('xfile', 1.0): 1,
#  ('content', 1.0): 3,
#  ('rain', 1.0): 18,
#  ('fabul', 1.0): 4,
#  ('fantast', 1.0): 8,
#  ('♡', 1.0): 12,
#  ('jb', 1.0): 1,
#  ('forev', 1.0): 5,
#  ('belieb', 1.0): 3,
#  ('nighti', 1.0): 1,
#  ('bug', 1.0): 2,
#  ('bite', 1.0): 1,
#  ('bracelet', 1.0): 2,
#  ('idea', 1.0): 23,
#  ('foundri', 1.0): 1,
#  ('game', 1.0): 23,
#  ('sens', 1.0): 6,
#  ('pic', 1.0): 21,
#  ('ef', 1.0): 1,
#  ('phone', 1.0): 16,
#  ('woot', 1.0): 2,
#  ('derek', 1.0): 1,
#  ('use', 1.0): 32,
#  ('parkshar', 1.0): 1,
#  ('gloucestershir', 1.0): 1,
#  ('aaaahhh', 1.0): 1,
#  ('man', 1.0): 16,
#  ('traffic', 1.0): 2,
#  ('stress', 1.0): 4,
#  ('reliev', 1.0): 1,
#  ("how'r", 1.0): 1,
#  ('arbeloa', 1.0): 1,
#  ('turn', 1.0): 13,
#  ('17', 1.0): 2,
#  ('omg', 1.0): 13,
#  ('say', 1.0): 43,
#  ('europ', 1.0): 1,
#  ('rise', 1.0): 2,
#  ('find', 1.0): 20,
#  ('hard', 1.0): 9,
#  ('believ', 1.0): 7,
#  ('uncount', 1.0): 1,
#  ('coz', 1.0): 2,
#  ('unlimit', 1.0): 1,
#  ('cours', 1.0): 11,
#  ('teamposit', 1.0): 1,
#  ('aldub', 1.0): 2,
#  ('☕', 1.0): 3,
#  ('rita', 1.0): 2,
#  ('info', 1.0): 10,
#  ("we'd", 1.0): 4,
#  ('way', 1.0): 34,
#  ('boy', 1.0): 13,
#  ('x40', 1.0): 1,
#  ('true', 1.0): 19,
#  ('sethi', 1.0): 2,
#  ('high', 1.0): 6,
#  ('exe', 1.0): 1,
#  ('skeem', 1.0): 1,
#  ('saam', 1.0): 1,
#  ('peopl', 1.0): 42,
#  ('polit', 1.0): 2,
#  ('izzat', 1.0): 1,
#  ('wese', 1.0): 1,
#  ('trust', 1.0): 7,
#  ('khawateen', 1.0): 1,
#  ('k', 1.0): 8,
#  ('sath', 1.0): 2,
#  ('mana', 1.0): 1,
#  ('kar', 1.0): 1,
#  ('deya', 1.0): 1,
#  ('sort', 1.0): 7,
#  ('smart', 1.0): 5,
#  ('hair', 1.0): 7,
#  ('tbh', 1.0): 5,
#  ('jacob', 1.0): 2,
#  ('g', 1.0): 7,
#  ('upgrad', 1.0): 2,
#  ('tee', 1.0): 2,
#  ('famili', 1.0): 14,
#  ('person', 1.0): 14,
#  ('two', 1.0): 15,
#  ('convers', 1.0): 6,
#  ('onlin', 1.0): 4,
#  ('mclaren', 1.0): 1,
#  ('fridayfeel', 1.0): 5,
#  ('tgif', 1.0): 8,
#  ('squar', 1.0): 1,
#  ('enix', 1.0): 1,
#  ('bissmillah', 1.0): 1,
#  ('ya', 1.0): 19,
#  ('allah', 1.0): 3,
#  ("we'r", 1.0): 25,
#  ('socent', 1.0): 1,
#  ('startup', 1.0): 2,
#  ('drop', 1.0): 9,
#  ('your', 1.0): 3,
#  ('arnd', 1.0): 1,
#  ('town', 1.0): 3,
#  ('basic', 1.0): 4,
#  ('piss', 1.0): 2,
#  ('cup', 1.0): 4,
#  ('also', 1.0): 28,
#  ('terribl', 1.0): 2,
#  ('complic', 1.0): 1,
#  ('discuss', 1.0): 2,
#  ('snapchat', 1.0): 31,
#  ('lynettelow', 1.0): 1,
#  ('kikmenow', 1.0): 2,
#  ('snapm', 1.0): 1,
#  ('hot', 1.0): 20,
#  ('amazon', 1.0): 1,
#  ('kikmeguy', 1.0): 2,
#  ('defin', 1.0): 2,
#  ('grow', 1.0): 6,
#  ('sport', 1.0): 4,
#  ('rt', 1.0): 9,
#  ('rakyat', 1.0): 1,
#  ('write', 1.0): 11,
#  ('sinc', 1.0): 11,
#  ('mention', 1.0): 18,
#  ('fli', 1.0): 5,
#  ('fish', 1.0): 3,
#  ('promot', 1.0): 3,
#  ('post', 1.0): 16,
#  ('cyber', 1.0): 1,
#  ('ourdaughtersourprid', 1.0): 3,
#  ('mypapamyprid', 1.0): 2,
#  ('papa', 1.0): 1,
#  ('coach', 1.0): 2,
#  ('posit', 1.0): 3,
#  ('kha', 1.0): 1,
#  ('atleast', 1.0): 2,
#  ('x39', 1.0): 1,
#  ('mango', 1.0): 1,
#  ("lassi'", 1.0): 1,
#  ("monty'", 1.0): 1,
#  ('marvel', 1.0): 2,
#  ('though', 1.0): 16,
#  ('suspect', 1.0): 3,
#  ('meant', 1.0): 2,
#  ('24', 1.0): 3,
#  ('hr', 1.0): 2,
#  ('touch', 1.0): 7,
#  ('kepler', 1.0): 3,
#  ('452b', 1.0): 4,
#  ('chalna', 1.0): 1,
#  ('hai', 1.0): 7,
#  ('thankyou', 1.0): 12,
#  ('hazel', 1.0): 1,
#  ('food', 1.0): 6,
#  ('brooklyn', 1.0): 1,
#  ('pta', 1.0): 2,
#  ('awak', 1.0): 8,
#  ('okayi', 1.0): 2,
#  ('awww', 1.0): 12,
#  ('ha', 1.0): 18,
#  ('doc', 1.0): 1,
#  ('splendid', 1.0): 1,
#  ('spam', 1.0): 1,
#  ('folder', 1.0): 1,
#  ('amount', 1.0): 1,
#  ('nigeria', 1.0): 1,
#  ('claim', 1.0): 1,
#  ('rted', 1.0): 1,
#  ('leg', 1.0): 3,
#  ('hurt', 1.0): 4,
#  ('bad', 1.0): 14,
#  ('mine', 1.0): 11,
#  ('saturday', 1.0): 5,
#  ('thaaank', 1.0): 1,
#  ('puhon', 1.0): 1,
#  ('happinesss', 1.0): 1,
#  ('tnc', 1.0): 1,
#  ('prior', 1.0): 1,
#  ('notif', 1.0): 2,
#  ('fat', 1.0): 1,
#  ('co', 1.0): 1,
#  ('probabl', 1.0): 7,
#  ('ate', 1.0): 4,
#  ('yuna', 1.0): 2,
#  ('tamesid', 1.0): 1,
#  ('´', 1.0): 3,
#  ('googl', 1.0): 5,
#  ('account', 1.0): 17,
#  ('scouser', 1.0): 1,
#  ('everyth', 1.0): 10,
#  ('zoe', 1.0): 1,
#  ('mate', 1.0): 5,
#  ('liter', 1.0): 5,
#  ("they'r", 1.0): 10,
#  ('samee', 1.0): 1,
#  ('edgar', 1.0): 1,
#  ('updat', 1.0): 12,
#  ('log', 1.0): 3,
#  ('bring', 1.0): 12,
#  ('abe', 1.0): 1,
#  ('meet', 1.0): 26,
#  ('x38', 1.0): 1,
#  ('sigh', 1.0): 3,
#  ('dreamili', 1.0): 1,
#  ('pout', 1.0): 1,
#  ('eye', 1.0): 12,
#  ('quacketyquack', 1.0): 6,
#  ('funni', 1.0): 15,
#  ('happen', 1.0): 13,
#  ('phil', 1.0): 1,
#  ('em', 1.0): 2,
#  ('del', 1.0): 1,
#  ('rodder', 1.0): 1,
#  ('els', 1.0): 8,
#  ('play', 1.0): 37,
#  ('newest', 1.0): 1,
#  ('gamejam', 1.0): 1,
#  ('irish', 1.0): 2,
#  ('literatur', 1.0): 2,
#  ('inaccess', 1.0): 2,
#  ("kareena'", 1.0): 2,
#  ('fan', 1.0): 21,
#  ('brain', 1.0): 10,
#  ('dot', 1.0): 8,
#  ('braindot', 1.0): 8,
#  ('fair', 1.0): 4,
#  ('rush', 1.0): 1,
#  ('either', 1.0): 10,
#  ('brandi', 1.0): 1,
#  ('18', 1.0): 5,
#  ('carniv', 1.0): 1,
#  ('men', 1.0): 8,
#  ('put', 1.0): 11,
#  ('mask', 1.0): 2,
#  ('xavier', 1.0): 1,
#  ('forneret', 1.0): 1,
#  ('jennif', 1.0): 1,
#  ('site', 1.0): 7,
#  ('free', 1.0): 31,
#  ('50.000', 1.0): 3,
#  ('8', 1.0): 10,
#  ('ball', 1.0): 7,
#  ('pool', 1.0): 5,
#  ('coin', 1.0): 5,
#  ('edit', 1.0): 6,
#  ('trish', 1.0): 1,
#  ('♥', 1.0): 13,
#  ('grate', 1.0): 5,
#  ('three', 1.0): 8,
#  ('comment', 1.0): 7,
#  ('wakeup', 1.0): 1,
#  ('besid', 1.0): 2,
#  ('dirti', 1.0): 2,
#  ('sex', 1.0): 4,
#  ('lmaooo', 1.0): 1,
#  ('😤', 1.0): 2,
#  ('loui', 1.0): 4,
#  ("he'", 1.0): 10,
#  ('throw', 1.0): 3,
#  ('caus', 1.0): 11,
#  ('inspir', 1.0): 6,
#  ('ff', 1.0): 40,
#  ('twoof', 1.0): 3,
#  ('gr8', 1.0): 1,
#  ('wkend', 1.0): 3,
#  ('kind', 1.0): 22,
#  ('exhaust', 1.0): 2,
#  ('word', 1.0): 17,
#  ('cheltenham', 1.0): 1,
#  ('area', 1.0): 4,
#  ('kale', 1.0): 1,
#  ('crisp', 1.0): 1,
#  ('ruin', 1.0): 5,
#  ('x37', 1.0): 1,
#  ('open', 1.0): 12,
#  ('worldwid', 1.0): 2,
#  ('outta', 1.0): 1,
#  ('sfvbeta', 1.0): 1,
#  ('vantast', 1.0): 1,
#  ('xcylin', 1.0): 1,
#  ('bundl', 1.0): 1,
#  ('show', 1.0): 20,
#  ('internet', 1.0): 2,
#  ('price', 1.0): 3,
#  ('realisticli', 1.0): 1,
#  ('pay', 1.0): 8,
#  ('net', 1.0): 1,
#  ('educ', 1.0): 1,
#  ('power', 1.0): 6,
#  ('weapon', 1.0): 1,
#  ('nelson', 1.0): 1,
#  ('mandela', 1.0): 1,
#  ('recent', 1.0): 8,
#  ('j', 1.0): 2,
#  ('chenab', 1.0): 1,
#  ('flow', 1.0): 5,
#  ('pakistan', 1.0): 1,
#  ('incredibleindia', 1.0): 1,
#  ('teenchoic', 1.0): 7,
#  ('choiceinternationalartist', 1.0): 7,
#  ('superjunior', 1.0): 7,
#  ('caught', 1.0): 4,
#  ('first', 1.0): 41,
#  ('salmon', 1.0): 1,
#  ('super-blend', 1.0): 1,
#  ('project', 1.0): 6,
#  ('youth@bipolaruk.org.uk', 1.0): 1,
#  ('awesom', 1.0): 35,
#  ('stream', 1.0): 12,
#  ('alma', 1.0): 1,
#  ('mater', 1.0): 1,
#  ('highschoolday', 1.0): 1,
#  ('clientvisit', 1.0): 1,
#  ('faith', 1.0): 3,
#  ('christian', 1.0): 1,
#  ('school', 1.0): 9,
#  ('lizaminnelli', 1.0): 1,
#  ('upcom', 1.0): 2,
#  ('uk', 1.0): 4,
#  ('😄', 1.0): 3,
#  ('singl', 1.0): 4,
#  ('hill', 1.0): 4,
#  ('everi', 1.0): 23,
#  ('beat', 1.0): 7,
#  ('wrong', 1.0): 9,
#  ('readi', 1.0): 22,
#  ('natur', 1.0): 1,
#  ('pefumeri', 1.0): 1,
#  ('workshop', 1.0): 2,
#  ('neal', 1.0): 1,
#  ('yard', 1.0): 1,
#  ('covent', 1.0): 1,
#  ('tomorrow', 1.0): 31,
#  ('fback', 1.0): 26,
#  ('indo', 1.0): 1,
#  ...}

# %% [markdown]
# ### Pipeline para la creación de la función  `train_naive_bayes`
# Dado un diccionario de frecuencias, `train_x` (una lista de tweets) y un` train_y` (una lista de etiquetas para cada tweet), implementaremos un clasificador Naive Bayes.
#
# ##### Calcular $V$
# - Podemos calcular el número de palabras únicas que aparecen en el diccionario `freqs` para obtener $ V $ (usando la función` set`).
#
# ##### Calcular $freq_{pos}$ y $freq_{neg}$
# - Usando el diccionario `freqs`, se puede calcular la frecuencia positiva y negativa de cada palabra $ freq_ {pos} $ y $ freq_ {neg} $.
#
# ##### Calcular $N_{pos}$ y $N_{neg}$
# - Usando el diccionario `freqs`, también puede calcular el número total de palabras positivas y el número total de palabras negativas $ N_ {pos} $ y $ N_ {neg} $.
#
# ##### Calcular $D$, $D_{pos}$, $D_{neg}$
# - Usando la lista de etiquetas de entrada `train_y`, calcularemos el número de documentos (tweets) $ D $, así como el número de documentos positivos (tweets) $ D_ {pos} $ y el número de documentos negativos (tweets) $ D_ { neg} $.
# - Calcularemos la probabilidad de que un documento (tweet) sea positivo $ P (D_ {pos}) $, y la probabilidad de que un documento (tweet) sea negativo $ P (D_ {neg}) $
#
# ##### Calcularemos el logprior
# -  $log(D_{pos}) - log(D_{neg})$
#
# ##### Calculate log likelihood
# - Finalmente, iteramos sobre cada palabra en el vocabulario, usaremos la función `lookup` para obtener las frecuencias positivas, $ freq_ {pos} $, y las frecuencias negativas, $ freq_ {neg} $, para esa palabra específica.
# - Calcularemos la probabilidad positiva de cada palabra $ P (W_ {pos}) $, la probabilidad negativa de cada palabra $ P (W_ {neg}) $ usando las ecuaciones 4 y 5.
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# **Note:** Usaremos un diccionario para almacenar los loglikelihoods de cada palabra. La clave será la palabra, el valor será la probabilidad logarítmica de esa palabra).
#
# - se puede calcular la loglikelihood: $log \left( \frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$.

# %%
[pair[0] for pair in freqs.keys()]
# Out:
# ['followfriday',
#  'top',
#  'engag',
#  'member',
#  'commun',
#  'week',
#  ':)',
#  'hey',
#  'jame',
#  'odd',
#  ':/',
#  'pleas',
#  'call',
#  'contact',
#  'centr',
#  '02392441234',
#  'abl',
#  'assist',
#  'mani',
#  'thank',
#  'listen',
#  'last',
#  'night',
#  'bleed',
#  'amaz',
#  'track',
#  'scotland',
#  'congrat',
#  'yeaaah',
#  'yipppi',
#  'accnt',
#  'verifi',
#  'rqst',
#  'succeed',
#  'got',
#  'blue',
#  'tick',
#  'mark',
#  'fb',
#  'profil',
#  '15',
#  'day',
#  'one',
#  'irresist',
#  'flipkartfashionfriday',
#  'like',
#  'keep',
#  'love',
#  'custom',
#  'wait',
#  'long',
#  'hope',
#  'enjoy',
#  'happi',
#  'friday',
#  'lwwf',
#  'second',
#  'thought',
#  '’',
#  'enough',
#  'time',
#  'dd',
#  'new',
#  'short',
#  'enter',
#  'system',
#  'sheep',
#  'must',
#  'buy',
#  'jgh',
#  'go',
#  'bayan',
#  ':d',
#  'bye',
#  'act',
#  'mischiev',
#  'etl',
#  'layer',
#  'in-hous',
#  'wareh',
#  'app',
#  'katamari',
#  'well',
#  '…',
#  'name',
#  'impli',
#  ':p',
#  'influenc',
#  'big',
#  '...',
#  'juici',
#  'selfi',
#  'follow',
#  'perfect',
#  'alreadi',
#  'know',
#  "what'",
#  'great',
#  'opportun',
#  'junior',
#  'triathlet',
#  'age',
#  '12',
#  '13',
#  'gatorad',
#  'seri',
#  'get',
#  'entri',
#  'lay',
#  'greet',
#  'card',
#  'rang',
#  'print',
#  'today',
#  'job',
#  ':-)',
#  "friend'",
#  'lunch',
#  'yummm',
#  'nostalgia',
#  'tb',
#  'ku',
#  'id',
#  'conflict',
#  'help',
#  "here'",
#  'screenshot',
#  'work',
#  'hi',
#  'liv',
#  'hello',
#  'need',
#  'someth',
#  'u',
#  'fm',
#  'twitter',
#  '—',
#  'sure',
#  'thing',
#  'dm',
#  'x',
#  "i'v",
#  'heard',
#  'four',
#  'season',
#  'pretti',
#  'dope',
#  'penthous',
#  'obv',
#  'gobigorgohom',
#  'fun',
#  "y'all",
#  'yeah',
#  'suppos',
#  'lol',
#  'chat',
#  'bit',
#  'youth',
#  '💅🏽',
#  '💋',
#  'seen',
#  'year',
#  'rest',
#  'goe',
#  'quickli',
#  'bed',
#  'music',
#  'fix',
#  'dream',
#  'spiritu',
#  'ritual',
#  'festiv',
#  'népal',
#  'begin',
#  'line-up',
#  'left',
#  'see',
#  'sarah',
#  'send',
#  'us',
#  'email',
#  'bitsy@bitdefender.com',
#  "we'll",
#  'asap',
#  'kik',
#  'hatessuc',
#  '32429',
#  'kikm',
#  'lgbt',
#  'tinder',
#  'nsfw',
#  'akua',
#  'cumshot',
#  'come',
#  'hous',
#  'nsn_supplement',
#  'effect',
#  'press',
#  'releas',
#  'distribut',
#  'result',
#  'link',
#  'remov',
#  'pressreleas',
#  'newsdistribut',
#  'bam',
#  'bestfriend',
#  'lot',
#  'warsaw',
#  '<3',
#  'x46',
#  'everyon',
#  'watch',
#  'documentari',
#  'earthl',
#  'youtub',
#  'support',
#  'buuut',
#  'oh',
#  'look',
#  'forward',
#  'visit',
#  'next',
#  'letsgetmessi',
#  'jo',
#  'make',
#  'feel',
#  'better',
#  'never',
#  'anyon',
#  'kpop',
#  'flesh',
#  'good',
#  'girl',
#  'best',
#  'wish',
#  'reason',
#  'epic',
#  'soundtrack',
#  'shout',
#  'ad',
#  'video',
#  'playlist',
#  'would',
#  'dear',
#  'jordan',
#  'okay',
#  'fake',
#  'gameplay',
#  ';)',
#  'haha',
#  'im',
#  'kid',
#  'stuff',
#  'exactli',
#  'product',
#  'line',
#  'etsi',
#  'shop',
#  'check',
#  'vacat',
#  'recharg',
#  'normal',
#  'charger',
#  'asleep',
#  'talk',
#  'sooo',
#  'someon',
#  'text',
#  'ye',
#  'bet',
#  "he'll",
#  'fit',
#  'hear',
#  'speech',
#  'piti',
#  'green',
#  'garden',
#  'midnight',
#  'sun',
#  'beauti',
#  'canal',
#  'dasvidaniya',
#  'till',
#  'scout',
#  'sg',
#  'futur',
#  'wlan',
#  'pro',
#  'confer',
#  'asia',
#  'chang',
#  'lollipop',
#  '🍭',
#  'nez',
#  'agnezmo',
#  'oley',
#  'mama',
#  'stand',
#  'stronger',
#  'god',
#  'misti',
#  'babi',
#  'cute',
#  'woohoo',
#  "can't",
#  'sign',
#  'yet',
#  'still',
#  'think',
#  'mka',
#  'liam',
#  'access',
#  'welcom',
#  'stat',
#  'arriv',
#  '1',
#  'unfollow',
#  'via',
#  'surpris',
#  'figur',
#  'happybirthdayemilybett',
#  'sweet',
#  'talent',
#  '2',
#  'plan',
#  'drain',
#  'gotta',
#  'timezon',
#  'parent',
#  'proud',
#  'least',
#  'mayb',
#  'sometim',
#  'grade',
#  'al',
#  'grand',
#  'manila_bro',
#  'chosen',
#  'let',
#  'around',
#  '..',
#  'side',
#  'world',
#  'eh',
#  'take',
#  'care',
#  'final',
#  'fuck',
#  'weekend',
#  'real',
#  'x45',
#  'join',
#  'hushedcallwithfraydo',
#  'gift',
#  'yeahhh',
#  'hushedpinwithsammi',
#  'event',
#  'might',
#  'luv',
#  'realli',
#  'appreci',
#  'share',
#  'wow',
#  'tom',
#  'gym',
#  'monday',
#  'invit',
#  'scope',
#  'friend',
#  'nude',
#  'sleep',
#  'birthday',
#  'want',
#  't-shirt',
#  'cool',
#  'haw',
#  'phela',
#  'mom',
#  'obvious',
#  'princ',
#  'charm',
#  'stage',
#  'luck',
#  'tyler',
#  'hipster',
#  'glass',
#  'marti',
#  'glad',
#  'done',
#  'afternoon',
#  'read',
#  'kahfi',
#  'finish',
#  'ohmyg',
#  'yaya',
#  'dub',
#  'stalk',
#  'ig',
#  'gondooo',
#  'moo',
#  'tologooo',
#  'becom',
#  'detail',
#  'zzz',
#  'xx',
#  'physiotherapi',
#  'hashtag',
#  '💪',
#  'monica',
#  'miss',
#  'sound',
#  'morn',
#  "that'",
#  'x43',
#  'definit',
#  'tri',
#  'tonight',
#  'took',
#  'advic',
#  'treviso',
#  'concert',
#  'citi',
#  'countri',
#  "i'll",
#  'start',
#  'fine',
#  'gorgeou',
#  'xo',
#  'oven',
#  'roast',
#  'garlic',
#  'oliv',
#  'oil',
#  'dri',
#  'tomato',
#  'basil',
#  'centuri',
#  'tuna',
#  'right',
#  'back',
#  'atchya',
#  'even',
#  'almost',
#  'chanc',
#  'cheer',
#  'po',
#  'ice',
#  'cream',
#  'agre',
#  '100',
#  'heheheh',
#  'that',
#  'point',
#  'stay',
#  'home',
#  'soon',
#  'promis',
#  'web',
#  'whatsapp',
#  'volta',
#  'funcionar',
#  'com',
#  'iphon',
#  'jailbroken',
#  'later',
#  '34',
#  'min',
#  'leia',
#  'appear',
#  'hologram',
#  'r2d2',
#  'w',
#  'messag',
#  'obi',
#  'wan',
#  'sit',
#  'luke',
#  'inter',
#  '3',
#  'ucl',
#  'arsen',
#  'small',
#  'team',
#  'pass',
#  '🚂',
#  'dewsburi',
#  'railway',
#  'station',
#  'dew',
#  'west',
#  'yorkshir',
#  '430',
#  'smh',
#  '9:25',
#  'live',
#  'strang',
#  'imagin',
#  'megan',
#  'masaantoday',
#  'a4',
#  'shweta',
#  'tripathi',
#  '5',
#  '20',
#  'kurta',
#  'half',
#  'number',
#  'wsalelov',
#  'ah',
#  'larri',
#  'anyway',
#  'kinda',
#  'goood',
#  'life',
#  'enn',
#  'could',
#  'warmup',
#  '15th',
#  'bath',
#  'dum',
#  'andar',
#  'ram',
#  'sampath',
#  'sona',
#  'mohapatra',
#  'samantha',
#  'edward',
#  'mein',
#  'tulan',
#  'razi',
#  'wah',
#  'josh',
#  'alway',
#  'smile',
#  'pictur',
#  '16.20',
#  'giveitup',
#  'given',
#  'ga',
#  'subsidi',
#  'initi',
#  'propos',
#  'delight',
#  'yesterday',
#  'x42',
#  'lmaoo',
#  'song',
#  'ever',
#  'shall',
#  'littl',
#  'throwback',
#  'outli',
#  'island',
#  'cheung',
#  'chau',
#  'mui',
#  'wo',
#  'total',
#  'differ',
#  'kfckitchentour',
#  'kitchen',
#  'clean',
#  "i'm",
#  'cusp',
#  'test',
#  'water',
#  'reward',
#  'arummzz',
#  "let'",
#  'drive',
#  'travel',
#  'yogyakarta',
#  'jeep',
#  'indonesia',
#  'instamood',
#  'wanna',
#  'skype',
#  'may',
#  'nice',
#  'friendli',
#  'pretend',
#  'film',
#  'congratul',
#  'winner',
#  'cheesydelight',
#  'contest',
#  'address',
#  'guy',
#  'market',
#  '24/7',
#  '14',
#  'hour',
#  'leav',
#  'without',
#  'delay',
#  'actual',
#  'easi',
#  'guess',
#  'train',
#  'wd',
#  'shift',
#  'engin',
#  'etc',
#  'sunburn',
#  'peel',
#  'blog',
#  'huge',
#  'warm',
#  '☆',
#  'complet',
#  'triangl',
#  'northern',
#  'ireland',
#  'sight',
#  'smthng',
#  'fr',
#  'hug',
#  'xoxo',
#  'uu',
#  'jaann',
#  'topnewfollow',
#  'connect',
#  'wonder',
#  'made',
#  'fluffi',
#  'insid',
#  'pirouett',
#  'moos',
#  'trip',
#  'philli',
#  'decemb',
#  "i'd",
#  'dude',
#  'x41',
#  'question',
#  'flaw',
#  'pain',
#  'negat',
#  'strength',
#  'went',
#  'solo',
#  'move',
#  'fav',
#  'nirvana',
#  'smell',
#  'teen',
#  'spirit',
#  'rip',
#  'ami',
#  'winehous',
#  'coupl',
#  'tomhiddleston',
#  'elizabetholsen',
#  'yaytheylookgreat',
#  'goodnight',
#  'vid',
#  'wake',
#  'gonna',
#  'shoot',
#  'itti',
#  'bitti',
#  'teeni',
#  'bikini',
#  'much',
#  '4th',
#  'togeth',
#  'end',
#  'xfile',
#  'content',
#  'rain',
#  'fabul',
#  'fantast',
#  '♡',
#  'jb',
#  'forev',
#  'belieb',
#  'nighti',
#  'bug',
#  'bite',
#  'bracelet',
#  'idea',
#  'foundri',
#  'game',
#  'sens',
#  'pic',
#  'ef',
#  'phone',
#  'woot',
#  'derek',
#  'use',
#  'parkshar',
#  'gloucestershir',
#  'aaaahhh',
#  'man',
#  'traffic',
#  'stress',
#  'reliev',
#  "how'r",
#  'arbeloa',
#  'turn',
#  '17',
#  'omg',
#  'say',
#  'europ',
#  'rise',
#  'find',
#  'hard',
#  'believ',
#  'uncount',
#  'coz',
#  'unlimit',
#  'cours',
#  'teamposit',
#  'aldub',
#  '☕',
#  'rita',
#  'info',
#  "we'd",
#  'way',
#  'boy',
#  'x40',
#  'true',
#  'sethi',
#  'high',
#  'exe',
#  'skeem',
#  'saam',
#  'peopl',
#  'polit',
#  'izzat',
#  'wese',
#  'trust',
#  'khawateen',
#  'k',
#  'sath',
#  'mana',
#  'kar',
#  'deya',
#  'sort',
#  'smart',
#  'hair',
#  'tbh',
#  'jacob',
#  'g',
#  'upgrad',
#  'tee',
#  'famili',
#  'person',
#  'two',
#  'convers',
#  'onlin',
#  'mclaren',
#  'fridayfeel',
#  'tgif',
#  'squar',
#  'enix',
#  'bissmillah',
#  'ya',
#  'allah',
#  "we'r",
#  'socent',
#  'startup',
#  'drop',
#  'your',
#  'arnd',
#  'town',
#  'basic',
#  'piss',
#  'cup',
#  'also',
#  'terribl',
#  'complic',
#  'discuss',
#  'snapchat',
#  'lynettelow',
#  'kikmenow',
#  'snapm',
#  'hot',
#  'amazon',
#  'kikmeguy',
#  'defin',
#  'grow',
#  'sport',
#  'rt',
#  'rakyat',
#  'write',
#  'sinc',
#  'mention',
#  'fli',
#  'fish',
#  'promot',
#  'post',
#  'cyber',
#  'ourdaughtersourprid',
#  'mypapamyprid',
#  'papa',
#  'coach',
#  'posit',
#  'kha',
#  'atleast',
#  'x39',
#  'mango',
#  "lassi'",
#  "monty'",
#  'marvel',
#  'though',
#  'suspect',
#  'meant',
#  '24',
#  'hr',
#  'touch',
#  'kepler',
#  '452b',
#  'chalna',
#  'hai',
#  'thankyou',
#  'hazel',
#  'food',
#  'brooklyn',
#  'pta',
#  'awak',
#  'okayi',
#  'awww',
#  'ha',
#  'doc',
#  'splendid',
#  'spam',
#  'folder',
#  'amount',
#  'nigeria',
#  'claim',
#  'rted',
#  'leg',
#  'hurt',
#  'bad',
#  'mine',
#  'saturday',
#  'thaaank',
#  'puhon',
#  'happinesss',
#  'tnc',
#  'prior',
#  'notif',
#  'fat',
#  'co',
#  'probabl',
#  'ate',
#  'yuna',
#  'tamesid',
#  '´',
#  'googl',
#  'account',
#  'scouser',
#  'everyth',
#  'zoe',
#  'mate',
#  'liter',
#  "they'r",
#  'samee',
#  'edgar',
#  'updat',
#  'log',
#  'bring',
#  'abe',
#  'meet',
#  'x38',
#  'sigh',
#  'dreamili',
#  'pout',
#  'eye',
#  'quacketyquack',
#  'funni',
#  'happen',
#  'phil',
#  'em',
#  'del',
#  'rodder',
#  'els',
#  'play',
#  'newest',
#  'gamejam',
#  'irish',
#  'literatur',
#  'inaccess',
#  "kareena'",
#  'fan',
#  'brain',
#  'dot',
#  'braindot',
#  'fair',
#  'rush',
#  'either',
#  'brandi',
#  '18',
#  'carniv',
#  'men',
#  'put',
#  'mask',
#  'xavier',
#  'forneret',
#  'jennif',
#  'site',
#  'free',
#  '50.000',
#  '8',
#  'ball',
#  'pool',
#  'coin',
#  'edit',
#  'trish',
#  '♥',
#  'grate',
#  'three',
#  'comment',
#  'wakeup',
#  'besid',
#  'dirti',
#  'sex',
#  'lmaooo',
#  '😤',
#  'loui',
#  "he'",
#  'throw',
#  'caus',
#  'inspir',
#  'ff',
#  'twoof',
#  'gr8',
#  'wkend',
#  'kind',
#  'exhaust',
#  'word',
#  'cheltenham',
#  'area',
#  'kale',
#  'crisp',
#  'ruin',
#  'x37',
#  'open',
#  'worldwid',
#  'outta',
#  'sfvbeta',
#  'vantast',
#  'xcylin',
#  'bundl',
#  'show',
#  'internet',
#  'price',
#  'realisticli',
#  'pay',
#  'net',
#  'educ',
#  'power',
#  'weapon',
#  'nelson',
#  'mandela',
#  'recent',
#  'j',
#  'chenab',
#  'flow',
#  'pakistan',
#  'incredibleindia',
#  'teenchoic',
#  'choiceinternationalartist',
#  'superjunior',
#  'caught',
#  'first',
#  'salmon',
#  'super-blend',
#  'project',
#  'youth@bipolaruk.org.uk',
#  'awesom',
#  'stream',
#  'alma',
#  'mater',
#  'highschoolday',
#  'clientvisit',
#  'faith',
#  'christian',
#  'school',
#  'lizaminnelli',
#  'upcom',
#  'uk',
#  '😄',
#  'singl',
#  'hill',
#  'everi',
#  'beat',
#  'wrong',
#  'readi',
#  'natur',
#  'pefumeri',
#  'workshop',
#  'neal',
#  'yard',
#  'covent',
#  'tomorrow',
#  'fback',
#  'indo',
#  ...]

# %%
vocab = set([pair[0] for pair in freqs.keys()])
vocab
# Out:
# {'siguro',
#  'minha',
#  'dey',
#  'impair',
#  'follow',
#  '😉',
#  'netizen',
#  'nathanielhinanakit',
#  'except',
#  "year'",
#  'thunderstorm',
#  'hahah',
#  'uuughhh',
#  'movement',
#  'cauliflow',
#  'write',
#  'tologooo',
#  'elf',
#  'thistlelov',
#  'song',
#  'gw',
#  'planner',
#  'weloveyounamjoon',
#  'owww',
#  'veggi',
#  'clinton',
#  'boi',
#  'scroll',
#  'vandag',
#  'aspetti',
#  'olli',
#  'carolin',
#  'confid',
#  '🎀',
#  'ign',
#  'previou',
#  'hash',
#  '.\n.\n.',
#  'gryph',
#  'romanc',
#  'honest',
#  'superdri',
#  '318',
#  'holborn',
#  'non-mapbox',
#  'bastard',
#  'gay',
#  '💜',
#  'rihanna',
#  'creak',
#  'addmeonbbm',
#  'mwa',
#  'pleass',
#  'bear',
#  'kita',
#  'sponsor',
#  'ng',
#  'seven',
#  'infront',
#  'vandr',
#  'gobigorgohom',
#  'oitnb',
#  'carriag',
#  'ho',
#  'kca',
#  'search',
#  'yhm',
#  'shine',
#  'centr',
#  'one',
#  'franc',
#  'kristin',
#  'inc',
#  '2ish',
#  'anonym',
#  'day',
#  'op',
#  'pinkeu',
#  'airforc',
#  'froze',
#  '3:02',
#  'quickest',
#  'besok',
#  'akana',
#  '26week',
#  'campaign',
#  'hotti',
#  'hotel',
#  'famou',
#  'ink',
#  'smashingbook',
#  'selen',
#  'stretch',
#  'face',
#  'iirc',
#  'bahari',
#  '590',
#  'barsostay',
#  'ob',
#  'alter',
#  '✨',
#  'ii',
#  'arr',
#  'ayex',
#  'fe14',
#  'choroo',
#  'internet',
#  '17',
#  'hon',
#  'pleasur',
#  'g',
#  'quietli',
#  '1hr',
#  'disciplin',
#  'equal',
#  'mr',
#  'thq',
#  '”',
#  'thanksss',
#  'lupet',
#  'unlimit',
#  'tommorow',
#  'wacha',
#  'rodwel',
#  'happycustom',
#  'approach',
#  'digitalexet',
#  'bathtub',
#  'ella',
#  'unneed',
#  'ny',
#  'decor',
#  'foundri',
#  'blond',
#  '2k',
#  'tasteless',
#  'read',
#  '👆🏻',
#  'nanci',
#  'mee',
#  'intent',
#  'walk',
#  'totem',
#  'edward',
#  'merced',
#  'chinua',
#  'invest',
#  '</3',
#  'sins',
#  'shithous',
#  'whsmith',
#  'heheheh',
#  'a5',
#  'ayemso',
#  'cheltenham',
#  'sayhernam',
#  '24th',
#  'choiceinternationalartist',
#  'vist',
#  'bakal',
#  'vc',
#  'jailbroken',
#  'otw',
#  'idiot',
#  'major',
#  'sheeran',
#  '13',
#  'exe',
#  'birthdaygirl',
#  'yeeeyyy',
#  '452096',
#  'theaccidentalcoupl',
#  'tompolo',
#  'slip',
#  'liceooo',
#  'practic',
#  'jame',
#  'kumpul',
#  'hotfmnoaidilforariana',
#  'luckyyi',
#  'iren',
#  'ftw',
#  'editor',
#  'reunit',
#  'buttsex',
#  'injur',
#  'hide',
#  'brain',
#  'noodl',
#  'tb',
#  '190cr',
#  'bcz',
#  'els',
#  'happen',
#  'rogerwatch',
#  'rp',
#  'watch',
#  'foiegra',
#  'liquid',
#  'yasu',
#  'zokay',
#  'alix',
#  'foodiefriday',
#  'je',
#  'nominier',
#  'mother',
#  'spoil',
#  'teeth',
#  'rice',
#  'mcfloat',
#  'qatarday',
#  '🚖',
#  'stooop',
#  'action',
#  'ohmyg',
#  "mine'",
#  'kfckitchentour',
#  'star',
#  'flat',
#  'pero',
#  'fur-trim',
#  'weddingflow',
#  'progrmr',
#  'sel',
#  'pass',
#  '33',
#  'xxx',
#  'yahoo',
#  'build',
#  'save',
#  'christian',
#  'shouldeeerr',
#  '78x',
#  'murugan',
#  'target',
#  'dunwan',
#  'pod',
#  '642',
#  'cake',
#  '2-4',
#  'harana',
#  'sw',
#  'sunggyu',
#  'choregraph',
#  "i'mo",
#  'erm',
#  'decemb',
#  'hmu',
#  'vocal',
#  'hahaah',
#  'chu',
#  'journal',
#  'hihihi',
#  'leicaq',
#  'uber',
#  'explan',
#  'maggi',
#  'dishoom',
#  'titan',
#  '26',
#  'mohr',
#  'fail',
#  'stare',
#  'talaga',
#  'dirti',
#  'lisah',
#  'kelli',
#  'briefli',
#  'nosmet',
#  '73',
#  'laro',
#  'april',
#  'board',
#  'tio',
#  'suk',
#  'bottl',
#  'bless',
#  'yun',
#  'sp',
#  'pech',
#  'jong',
#  'laugh',
#  'pehli',
#  'kamiss',
#  'bna',
#  'bayan',
#  'check',
#  '423',
#  'accnt',
#  'screw',
#  'vikk',
#  'rubi',
#  'huvvft',
#  'graphic',
#  'school',
#  '31',
#  'wwooo',
#  'badlif',
#  'nichola',
#  'nowww',
#  'hunger',
#  'stay',
#  'houston',
#  'tomato',
#  'paperboy',
#  '1tb',
#  'outboard',
#  'nou',
#  'b4',
#  '╰',
#  '911',
#  'fahrenheit',
#  'mine',
#  'kany',
#  'huhuhuhu',
#  'justgotkanekifi',
#  'hen',
#  'jdjdjdjd',
#  'ey',
#  'rxthedailysurveyvot',
#  'poorli',
#  'bruh',
#  'congrat',
#  'x-ray',
#  'roma',
#  'hopeless',
#  'finish',
#  'hbdme',
#  'fm',
#  'confisc',
#  'daal',
#  'embrac',
#  'lost',
#  'subdivis',
#  'surgeri',
#  'place',
#  'fabian',
#  'medic',
#  'darlen',
#  'abstin',
#  'deathli',
#  'cupcak',
#  'woe',
#  'immigr',
#  'ketchup',
#  'bad',
#  'all-clear',
#  'jummapray',
#  'amount',
#  'sunnah',
#  'wknd',
#  'trainer',
#  'heiya',
#  'nj',
#  'diffici',
#  'donetsk',
#  'sambal',
#  'samosa',
#  'explorealberta',
#  'male',
#  'giveaway',
#  'viber',
#  'whack',
#  'commun',
#  'peregrin',
#  'cardi',
#  'drew',
#  'docopenhagen',
#  'x46',
#  'retail',
#  'wind',
#  'lesbian',
#  'firm',
#  'todayyy',
#  'visit',
#  'ukrain',
#  'imran',
#  'gandhi',
#  'okayi',
#  'nixu',
#  'asf',
#  'everett',
#  'ate',
#  'yaytheylookgreat',
#  'spend',
#  'chorong',
#  'tweepsmatchout',
#  'rockfish',
#  'jamie-le',
#  'milo',
#  'henc',
#  'confer',
#  'icecream',
#  'task',
#  'tau',
#  'carpet',
#  'webz',
#  'critic',
#  'jenna',
#  'isra',
#  'within',
#  'fingers-cross',
#  'menu',
#  'ride',
#  'busier',
#  'weekendofmad',
#  'abt',
#  'akooo',
#  'respectlost',
#  'nknkkpagpapakumbaba',
#  'basic',
#  'schade',
#  'aaahhh',
#  'nightmar',
#  'georg',
#  'retain',
#  '♥',
#  'krystoria',
#  'weather',
#  'fridg',
#  'depend',
#  'adida',
#  'thaaat',
#  'dewsburi',
#  'fest',
#  'scar',
#  'hmph',
#  'zzz',
#  'pregnanc',
#  'hidden',
#  'ux',
#  'argu',
#  'noon',
#  'brotheeerrr',
#  'har',
#  '23rd',
#  'youthcelebr',
#  'color',
#  'goin',
#  'vall',
#  'town',
#  'meet',
#  'renam',
#  'yan',
#  'enix',
#  'streak',
#  'obyun',
#  'acorn',
#  'eonni',
#  'hierro',
#  'rofl',
#  '🐢',
#  'hola',
#  'tak',
#  'buddyyi',
#  'hannib',
#  '330',
#  'neat-o',
#  'vscocousin',
#  'dale',
#  'lee',
#  'fcking',
#  'kernel',
#  'hay',
#  'bibl',
#  'tack',
#  'faith',
#  '70685',
#  'design',
#  'ht',
#  'crew',
#  'blain',
#  'rlli',
#  'impress',
#  'risk',
#  'fuckin',
#  'creation',
#  "they'd",
#  'exec',
#  'joyc',
#  'nikeorigin',
#  'fotoset',
#  'tall',
#  'met',
#  'doli',
#  'client_amends_edit',
#  'luci',
#  '🍤',
#  'unluckiest',
#  'spain',
#  'respect',
#  'rumbl',
#  'junmyeon',
#  'l4l',
#  'ship',
#  'snob',
#  'vianey',
#  'beonknockknock',
#  'extraordinari',
#  'dkt',
#  'garden',
#  'therealgolden',
#  'wgm',
#  'later',
#  'guilti',
#  'china',
#  'ki',
#  'bein',
#  'good',
#  'regret',
#  "y'all",
#  'transfer',
#  'lorenangel',
#  'girlfriendsmya',
#  'minut',
#  'math',
#  'ctto',
#  'gig',
#  'embarrass',
#  'pr',
#  'gh',
#  'kingfish',
#  'bring',
#  'even',
#  'emphasi',
#  'sho',
#  '⅛',
#  'hammi',
#  'finddjderek',
#  'news',
#  'hpc',
#  'chant',
#  'easili',
#  'yester',
#  'yipppi',
#  'rettweet',
#  '10am',
#  'aww',
#  'pdf',
#  'zzzz',
#  'hd',
#  'audienc',
#  'takraw',
#  'notr',
#  'sweat',
#  'accident',
#  'brows',
#  'tutori',
#  'nirvana',
#  'lootcrat',
#  'mb',
#  'crisi',
#  'bdayt',
#  'societi',
#  'repath',
#  'younger',
#  'old-porridg',
#  'xpress',
#  'sandwich',
#  'glasgow',
#  'greater',
#  'noseble',
#  'sorrri',
#  'aw',
#  'yuna',
#  'tmr',
#  'theater',
#  'fowl',
#  'given',
#  'nathann',
#  'spam',
#  '..',
#  'shahid',
#  'refin',
#  'resid',
#  'superday',
#  '22pic',
#  'rob',
#  'fantasi',
#  'guncontrol',
#  '💅🏽',
#  'soniii',
#  'sampl',
#  'common',
#  'suuuper',
#  'yeh',
#  'istanya',
#  '1-0',
#  'ब',
#  'fear',
#  'scienc',
#  'glass',
#  'fron',
#  'fss',
#  'soprano',
#  'switch',
#  'puppi',
#  '9',
#  'mamayang',
#  'b2aa',
#  'stay_bless',
#  'bissmillah',
#  'dough',
#  'inde',
#  'learnt',
#  'cotton',
#  'bebii',
#  'heed',
#  'use',
#  'crop',
#  'likewis',
#  'hypocrit',
#  'man.h',
#  'chap',
#  'contrast',
#  'nvr',
#  'heart',
#  'chaddi',
#  'anxiou',
#  'welcom',
#  'digitalmarket',
#  'annual',
#  'hsm',
#  'puddl',
#  'tline',
#  'aahhh',
#  'contractu',
#  'balm',
#  'research',
#  'circl',
#  'advaddict',
#  '2suppli',
#  'cruel',
#  'pleasee',
#  'interraci',
#  'dipoppo',
#  'smooth',
#  'danger',
#  'gua',
#  'letshavecocktailsafternuclai',
#  'lollipop',
#  'screencap',
#  'walang',
#  'geer',
#  'worth',
#  'os',
#  'parisa',
#  'mka',
#  'came',
#  'mombasa',
#  'kami',
#  'offens',
#  'compliment',
#  'need',
#  'bobbl',
#  'orang',
#  'weh',
#  '😄',
#  'guess',
#  '2cope',
#  'leader',
#  'season',
#  'hahay',
#  'arond',
#  'heechul',
#  'nutella',
#  'hmmm',
#  'veeerri',
#  'cope',
#  'selamathariraya',
#  'misss',
#  'sneaker',
#  'ginger',
#  'taknottem',
#  'highvalu',
#  'line',
#  '80',
#  'suppos',
#  'obakeng',
#  'theocrat',
#  'prefer',
#  'sakura',
#  'philli',
#  'tdif',
#  'satya',
#  'fridayfeel',
#  'daddi',
#  'hear',
#  'robe',
#  'demo',
#  'pillar',
#  'amm',
#  'lip',
#  'lab',
#  'gray',
#  'stylish',
#  'kgola',
#  'migrant',
#  'loop',
#  'sharethelov',
#  'warmest',
#  'hind',
#  'unreal',
#  'burnt',
#  'unknown',
#  'rakyat',
#  'ufff',
#  'close',
#  'ubusi',
#  'nintendo',
#  'debat',
#  'round',
#  'sake',
#  'gran',
#  'snow',
#  'hungrrryyi',
#  'tub',
#  'jaspernationalpark',
#  'unwind',
#  '┓',
#  '345',
#  'wednesday',
#  'birth',
#  'buzz',
#  'sweetan',
#  '009',
#  'pict',
#  'kandekj',
#  'buttonhol',
#  'latinhous',
#  'taco',
#  'ego',
#  'energi',
#  'icon',
#  'xpax',
#  'elvena',
#  'iamamonst',
#  'sleeep',
#  'mark',
#  'cover',
#  'grumbl',
#  'rrp',
#  'might',
#  'jasmingarrick',
#  'suck',
#  "sod'",
#  'über',
#  '∠',
#  'toma',
#  'couldv',
#  'boner',
#  '<---',
#  'hologram',
#  'worst',
#  'yass',
#  'specialist',
#  'hale',
#  'belgium',
#  'comp',
#  'tan',
#  '💦',
#  'teamposit',
#  'masaan',
#  'happyyi',
#  'seen',
#  'problemmm',
#  'ahaha',
#  'smi',
#  'groan',
#  'phrase',
#  'spare',
#  'wayanadan',
#  'georgi',
#  'thnk',
#  'coach',
#  'x30',
#  'lie',
#  'step',
#  'panga',
#  'treat',
#  'shoulder',
#  'pano',
#  'toler',
#  '340',
#  'mayday',
#  'idea',
#  'asap',
#  '💫',
#  'sensibl',
#  'memor',
#  'olymp',
#  'distrub',
#  'askaman',
#  'dislik',
#  'countthecost',
#  'hogan',
#  'on-pack',
#  'greatli',
#  'incompleta',
#  'bittersweet',
#  'rehears',
#  'plugin',
#  'piggin',
#  'physiqu',
#  'mwf',
#  'hangout',
#  'estat',
#  'notgonnabeactivefor',
#  'razzist',
#  'carol',
#  'sanda',
#  'mental',
#  'pesaro',
#  'ifeely',
#  'elgin',
#  'lockscreen',
#  '★',
#  'heaven',
#  'drug',
#  ';p',
#  'sholong',
#  'punt',
#  'surajettan',
#  '4yr',
#  'claim',
#  'long-dist',
#  'lyka',
#  'inshallah',
#  '2week',
#  'courgett',
#  'tou',
#  'snake',
#  '61',
#  '💓',
#  '10,000',
#  'volta',
#  'bali',
#  'ju',
#  'debt',
#  'stash',
#  'border',
#  'detail',
#  'elah',
#  'aftenoon',
#  'mon',
#  'dah',
#  'yell',
#  '16.20',
#  'bugatti',
#  '91',
#  'manuel',
#  'milf',
#  'gear',
#  'pebbl',
#  'rachel',
#  "o'neal",
#  'twin',
#  'parad',
#  'caus',
#  'vishaya',
#  'struggl',
#  'juli',
#  'confess',
#  "josephine'",
#  'tla',
#  'extrem',
#  'will',
#  'resourc',
#  'trouser',
#  'bandana',
#  'squar',
#  'peachyloan',
#  'stem',
#  'ariana',
#  'creta',
#  'exclus',
#  'expand',
#  'claw',
#  'xenophob',
#  'wii',
#  '327',
#  'besi',
#  'cow',
#  'tradit',
#  'sakit',
#  'x37',
#  'kapatidkongpogi',
#  'outsid',
#  'jabongatpumaurbanstamped',
#  'preciou',
#  'wound',
#  'clapham',
#  'oliv',
#  'yhooo',
#  'bb',
#  'guest',
#  'monday',
#  'deya',
#  'nooop',
#  'wakeup',
#  'arriv',
#  'takeaway',
#  'colder',
#  'im',
#  'junhe',
#  'assur',
#  'mid-end',
#  'itv',
#  'privaci',
#  'sath',
#  'driver',
#  'fb',
#  'ooouch',
#  'mussel',
#  'directx',
#  'junjou',
#  'standrew',
#  'gosh',
#  'mui',
#  'x22',
#  'montoya',
#  'legibl',
#  'pop',
#  'christ',
#  '♬',
#  'clich',
#  'da',
#  '6th',
#  'ramadhan',
#  'bcu',
#  'solar',
#  'entp',
#  'eagerli',
#  'section',
#  'billion',
#  "harry'",
#  'sarcasm',
#  'ek',
#  'park',
#  'jersey',
#  'advisori',
#  'barkin',
#  'cayton',
#  'juudiciari',
#  'throw',
#  'woohyun',
#  'act',
#  'fricken',
#  'cyber',
#  'consider',
#  'santorini',
#  'jet',
#  'mi',
#  '00962778381',
#  'sneak',
#  'scheme',
#  'sofa',
#  'et',
#  'fiend',
#  'whatsapp',
#  'translat',
#  'booo',
#  'cock',
#  'bowwowchicawowwow',
#  'peac',
#  'bueno',
#  'tom',
#  'naaan',
#  'shit',
#  '000',
#  'tattoo',
#  'domesticviol',
#  '=d',
#  'youtub',
#  'beast',
#  'stori',
#  'lani',
#  'cool',
#  'encourag',
#  'nic',
#  'minist',
#  'alek',
#  'sheffield',
#  'offroad',
#  'diagnos',
#  'babyyi',
#  '0ne',
#  'wa',
#  "lady'",
#  '349',
#  'soobin',
#  'pandimension',
#  'bandz',
#  'condit',
#  'truli',
#  'yt',
#  'babi',
#  'ape',
#  'mac',
#  'whenev',
#  ...}

# %%
def train_naive_bayes(freqs, train_x, train_y):
    '''
    inputs:
    freqs: un diccionario con (w,l) y con el key con la frecuencia que aparece la palabra en ese tweet
    train_x: lista de tweets para el entrenamiento
    train_y: lista de las etiquetas de los tweets(0,1)

    outputs:
    logprior: lo prior (log(Dpos) - log(Dneg))
    loglikelihood: es el loglikelihood de la ecuación de naive bayes log(P(Wpos)/P(Wneg))
    '''

    loglikelihood = {}
    logprior = 0

    # 1.- calcular V, el número de valores únicos en el vocabulario
    vocab = set([pair[0] for pair in freqs.keys()])
    V=len(vocab)

    #2.- Calcular N_pos, n_neg
    N_pos = N_neg = 0
    for pair in freqs.keys():
      #si la etiqueta es positiva mayor a 0
      if pair[1] > 0:
        N_pos += freqs[pair] #incrementar el número de palabras positivas en el conteo de (w,l)
      else:  #La etiqueta es negativa
        N_neg += freqs[pair] #incrementar el número de palabras negativas por el conteo de (w,l)

    #Calcular el valor de D, el número de tweets (documentos)
    D = len(train_y)

    # Calcular D_pos, el número de documentos positivos
    D_pos = len(list(filter(lambda x: x>0, train_y)))

    # Calcular D_neg, el número de documentos negativos
    D_neg = D - D_pos

    # Calcular el logprior
    logprior = np.log(D_pos) - np.log(D_neg)

    #Calcular loglikelihood
    for word in vocab:
      #obtener las frecuencias positivas y negativas de cada palabra
      freq_pos = lookup(freqs, word, 1)
      freq_neg = lookup(freqs, word, 0)

      # Calcular la probabilidad de que cada palabra sea un sentimiento positivo, y lo mismo para el sentimiento negativo
      # Suavizado
      p_w_pos = (freq_pos + 1) / (N_pos + V)
      p_w_neg = (freq_neg + 1) / (N_neg + V)

      #Calculamos el likelihood de cada palabra
      loglikelihood[word] = np.log(p_w_pos/p_w_neg)

    return logprior, loglikelihood

# %%
# probar train
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)

# %%
print(logprior)
# Out:
# 0.0

# %%
len(loglikelihood)
# Out:
# 9085

# %%
loglikelihood
# Out:
# {'siguro': 0.6982557485026679,
#  'minha': -0.6880386126172228,
#  'dey': -1.0935037207253873,
#  'impair': 0.6982557485026679,
#  'follow': 0.2680980278041318,
#  '😉': 0.41057367605088696,
#  'netizen': 0.6982557485026679,
#  'nathanielhinanakit': -0.6880386126172228,
#  'except': -0.6880386126172228,
#  "year'": 1.1037208566108323,
#  'thunderstorm': 0.6982557485026679,
#  'hahah': -1.7866509012853324,
#  'uuughhh': -0.6880386126172228,
#  'movement': -0.6880386126172228,
#  'cauliflow': 0.6982557485026679,
#  'write': 0.2927906403945036,
#  'tologooo': 0.6982557485026679,
#  'elf': 0.00510856794272258,
#  'thistlelov': 0.6982557485026679,
#  'song': -0.4197746260225436,
#  'gw': -0.6880386126172228,
#  'planner': -0.6880386126172228,
#  'weloveyounamjoon': 0.00510856794272258,
#  'owww': -0.4003565401654419,
#  'veggi': 0.6982557485026679,
#  'clinton': 0.6982557485026679,
#  'boi': 0.6982557485026679,
#  'scroll': -0.6880386126172228,
#  'vandag': -0.6880386126172228,
#  'aspetti': 0.6982557485026679,
#  'olli': 1.1037208566108323,
#  'carolin': 0.41057367605088696,
#  'confid': -0.6880386126172228,
#  '🎀': -0.6880386126172228,
#  'ign': 1.1037208566108323,
#  'previou': -1.0935037207253873,
#  'hash': 0.6982557485026679,
#  '.\n.\n.': 0.6982557485026679,
#  'gryph': 1.391402929062613,
#  'romanc': 0.6982557485026679,
#  'honest': 1.1037208566108323,
#  'superdri': 0.6982557485026679,
#  '318': -0.6880386126172228,
#  'holborn': 0.6982557485026679,
#  'non-mapbox': 0.6982557485026679,
#  'bastard': -1.0935037207253873,
#  'gay': -0.5545072199927001,
#  '💜': 0.00510856794272258,
#  'rihanna': -0.6880386126172228,
#  'creak': 0.6982557485026679,
#  'addmeonbbm': 0.6982557485026679,
#  'mwa': -0.6880386126172228,
#  'pleass': 0.00510856794272258,
#  'bear': 0.00510856794272258,
#  'kita': -1.0935037207253873,
#  'sponsor': 0.2927906403945034,
#  'ng': 0.41057367605088696,
#  'seven': 1.1037208566108323,
#  'infront': -1.0935037207253873,
#  'vandr': 0.6982557485026679,
#  'gobigorgohom': 0.6982557485026679,
#  'oitnb': 0.00510856794272258,
#  'carriag': -0.6880386126172228,
#  'ho': -0.4003565401654419,
#  'kca': 0.6982557485026679,
#  'search': -1.381185793177168,
#  'yhm': -0.6880386126172228,
#  'shine': 0.6982557485026679,
#  'centr': -0.4003565401654419,
#  'one': -0.25471655000609217,
#  'franc': 1.7968680371707775,
#  'kristin': 0.6982557485026679,
#  'inc': -0.4003565401654419,
#  '2ish': 0.6982557485026679,
#  'anonym': 0.6982557485026679,
#  'day': 0.4966184024094215,
#  'op': 0.41057367605088696,
#  'pinkeu': 0.6982557485026679,
#  'airforc': 0.6982557485026679,
#  'froze': -0.6880386126172228,
#  '3:02': 1.1037208566108323,
#  'quickest': -0.6880386126172228,
#  'besok': 0.6982557485026679,
#  'akana': -0.6880386126172228,
#  '26week': -0.6880386126172228,
#  'campaign': 0.00510856794272258,
#  'hotti': -0.6880386126172228,
#  'hotel': 0.00510856794272258,
#  'famou': -0.9111821639314325,
#  'ink': -1.0935037207253873,
#  'smashingbook': 0.6982557485026679,
#  'selen': -0.6880386126172228,
#  'stretch': -0.6880386126172228,
#  'face': -0.9393530408981289,
#  'iirc': 0.6982557485026679,
#  'bahari': 0.6982557485026679,
#  '590': -0.6880386126172228,
#  'barsostay': 0.6982557485026679,
#  'ob': -0.6880386126172228,
#  'alter': 0.00510856794272258,
#  '✨': 0.9213992998168774,
#  'ii': -0.6880386126172228,
#  'arr': 0.6982557485026679,
#  'ayex': -0.6880386126172228,
#  'fe14': -0.6880386126172228,
#  'choroo': 0.6982557485026679,
#  'internet': -0.9757206850690037,
#  '17': 1.1037208566108323,
#  'hon': 0.6982557485026679,
#  'pleasur': 2.403003840741093,
#  'g': 0.00510856794272258,
#  'quietli': -1.0935037207253873,
#  '1hr': 0.6982557485026679,
#  'disciplin': -1.0935037207253873,
#  'equal': 1.1037208566108323,
#  'mr': -0.2825735045090583,
#  'thq': 0.6982557485026679,
#  '”': -0.6880386126172228,
#  'thanksss': 0.00510856794272258,
#  'lupet': 0.6982557485026679,
#  'unlimit': 0.6982557485026679,
#  'tommorow': 1.391402929062613,
#  'wacha': -0.6880386126172228,
#  'rodwel': -0.6880386126172228,
#  'happycustom': 0.6982557485026679,
#  'approach': -0.6880386126172228,
#  'digitalexet': 0.6982557485026679,
#  'bathtub': -0.6880386126172228,
#  'ella': -0.6880386126172228,
#  'unneed': 0.6982557485026679,
#  'ny': -1.0935037207253873,
#  'decor': 0.6982557485026679,
#  'foundri': 0.6982557485026679,
#  'blond': 0.00510856794272258,
#  '2k': 0.6982557485026679,
#  'tasteless': -0.6880386126172228,
#  'read': 0.5647243558781452,
#  '👆🏻': -1.0935037207253873,
#  'nanci': 0.6982557485026679,
#  'mee': -0.6880386126172228,
#  'intent': -0.6880386126172228,
#  'walk': 0.45709369168577973,
#  'totem': 0.6982557485026679,
#  'edward': 0.00510856794272258,
#  'merced': 0.6982557485026679,
#  'chinua': 0.6982557485026679,
#  'invest': 0.00510856794272258,
#  '</3': -1.0935037207253873,
#  'sins': -0.6880386126172228,
#  'shithous': -0.6880386126172228,
#  'whsmith': 0.6982557485026679,
#  'heheheh': 1.1037208566108323,
#  'a5': 0.6982557485026679,
#  'ayemso': -0.6880386126172228,
#  'cheltenham': 0.6982557485026679,
#  'sayhernam': -0.6880386126172228,
#  '24th': 0.6982557485026679,
#  'choiceinternationalartist': 0.2927906403945034,
#  'vist': -0.6880386126172228,
#  'bakal': 0.6982557485026679,
#  'vc': 0.6982557485026679,
#  'jailbroken': 0.6982557485026679,
#  'otw': 0.00510856794272258,
#  'idiot': 0.6982557485026679,
#  'major': -0.4003565401654419,
#  'sheeran': -0.6880386126172228,
#  '13': 0.6982557485026679,
#  'exe': 0.6982557485026679,
#  'birthdaygirl': 0.6982557485026679,
#  'yeeeyyy': 0.6982557485026679,
#  '452096': 0.6982557485026679,
#  'theaccidentalcoupl': -0.6880386126172228,
#  'tompolo': 0.6982557485026679,
#  'slip': 0.6982557485026679,
#  'liceooo': -0.6880386126172228,
#  'practic': 0.41057367605088696,
#  'jame': 0.6982557485026679,
#  'kumpul': 0.6982557485026679,
#  'hotfmnoaidilforariana': -1.0935037207253873,
#  'luckyyi': -0.6880386126172228,
#  'iren': -1.0935037207253873,
#  'ftw': -1.0935037207253873,
#  'editor': -0.6880386126172228,
#  'reunit': 0.00510856794272258,
#  'buttsex': -0.6880386126172228,
#  'injur': -1.9408015811125907,
#  'hide': -0.2825735045090583,
#  'brain': 1.3043915520729832,
#  'noodl': -0.6880386126172228,
#  'tb': 0.6982557485026679,
#  '190cr': 0.6982557485026679,
#  'bcz': -0.6880386126172228,
#  'els': 0.5928952328448415,
#  'happen': -1.14002373636028,
#  'rogerwatch': -0.6880386126172228,
#  'rp': 0.00510856794272258,
#  'watch': -0.5588268811372166,
#  'foiegra': 1.1037208566108323,
#  'liquid': 0.6982557485026679,
#  'yasu': 0.6982557485026679,
#  'zokay': -0.6880386126172228,
#  'alix': 0.6982557485026679,
#  'foodiefriday': 0.6982557485026679,
#  'je': -0.6880386126172228,
#  'nominier': 0.6982557485026679,
#  'mother': 0.00510856794272258,
#  'spoil': 0.6982557485026679,
#  'teeth': -1.0935037207253873,
#  'rice': -0.6880386126172228,
#  'mcfloat': 0.6982557485026679,
#  'qatarday': 0.6982557485026679,
#  '🚖': -0.6880386126172228,
#  'stooop': -0.6880386126172228,
#  'action': 0.00510856794272258,
#  'ohmyg': 0.6982557485026679,
#  "mine'": -0.6880386126172228,
#  'kfckitchentour': 1.1037208566108323,
#  'star': 0.8160387841590513,
#  'flat': 0.41057367605088696,
#  'pero': -1.381185793177168,
#  'fur-trim': -0.6880386126172228,
#  'weddingflow': -0.6880386126172228,
#  'progrmr': 0.6982557485026679,
#  'sel': -0.6880386126172228,
#  'pass': -0.16194551672044383,
#  '33': 1.1037208566108323,
#  'xxx': 0.44694132022176175,
#  'yahoo': -1.0935037207253873,
#  'build': 0.9213992998168774,
#  'save': 0.2927906403945034,
#  'christian': 0.6982557485026679,
#  'shouldeeerr': -0.6880386126172228,
#  '78x': 0.6982557485026679,
#  'murugan': -0.6880386126172228,
#  'target': 0.41057367605088696,
#  'dunwan': -0.6880386126172228,
#  'pod': -0.6880386126172228,
#  '642': 0.6982557485026679,
#  'cake': -0.11267446771366091,
#  '2-4': -0.6880386126172228,
#  'harana': 0.6982557485026679,
#  'sw': 0.6982557485026679,
#  'sunggyu': -1.7866509012853324,
#  'choregraph': -0.6880386126172228,
#  "i'mo": -0.6880386126172228,
#  'erm': 0.00510856794272258,
#  'decemb': 0.00510856794272258,
#  'hmu': 1.1037208566108323,
#  'vocal': 0.00510856794272258,
#  'hahaah': -0.6880386126172228,
#  'chu': 0.6982557485026679,
#  'journal': 0.6982557485026679,
#  'hihihi': 0.6982557485026679,
#  'leicaq': 0.6982557485026679,
#  'uber': 0.00510856794272258,
#  'explan': 1.1037208566108323,
#  'maggi': 0.6982557485026679,
#  'dishoom': 0.6982557485026679,
#  'titan': -0.6880386126172228,
#  '26': -3.0394138697807005,
#  'mohr': 0.6982557485026679,
#  'fail': -0.4648950613030132,
#  'stare': 0.6982557485026679,
#  'talaga': -0.6880386126172228,
#  'dirti': 1.1037208566108323,
#  'lisah': -1.0935037207253873,
#  'kelli': 0.6982557485026679,
#  'briefli': -0.6880386126172228,
#  'nosmet': 0.6982557485026679,
#  '73': -1.0935037207253873,
#  'laro': 0.6982557485026679,
#  'april': 0.00510856794272258,
#  'board': 1.1037208566108323,
#  'tio': 0.6982557485026679,
#  'suk': -1.0935037207253873,
#  'bottl': 0.00510856794272258,
#  'bless': 1.5091859647189967,
#  'yun': -0.6880386126172228,
#  'sp': -0.6880386126172228,
#  'pech': 0.6982557485026679,
#  'jong': -0.6880386126172228,
#  'laugh': -0.14904211188453576,
#  'pehli': 0.6982557485026679,
#  'kamiss': -0.6880386126172228,
#  'bna': -0.6880386126172228,
#  'bayan': 0.6982557485026679,
#  'check': 0.8354568700161528,
#  '423': -0.6880386126172228,
#  'accnt': 1.1037208566108323,
#  'screw': -0.9111821639314325,
#  'vikk': 0.6982557485026679,
#  'rubi': -0.6880386126172228,
#  'huvvft': -0.6880386126172228,
#  'graphic': 1.1037208566108323,
#  'school': -0.8278005549923816,
#  '31': -0.4003565401654419,
#  'wwooo': 0.6982557485026679,
#  'badlif': -0.6880386126172228,
#  'nichola': 1.1037208566108323,
#  'nowww': -0.6880386126172228,
#  'hunger': 0.6982557485026679,
#  'stay': -0.04141144769217031,
#  'houston': 0.6982557485026679,
#  'tomato': 0.00510856794272258,
#  'paperboy': 0.6982557485026679,
#  '1tb': 0.6982557485026679,
#  'outboard': 0.6982557485026679,
#  'nou': -0.6880386126172228,
#  'b4': -0.6880386126172228,
#  '╰': 1.391402929062613,
#  '911': -0.6880386126172228,
#  'fahrenheit': 0.6982557485026679,
#  'mine': 0.0921199449323522,
#  'kany': -0.6880386126172228,
#  'huhuhuhu': -0.6880386126172228,
#  'justgotkanekifi': -0.6880386126172228,
#  'hen': -0.6880386126172228,
#  'jdjdjdjd': -0.6880386126172228,
#  'ey': 0.6982557485026679,
#  'rxthedailysurveyvot': 0.6982557485026679,
#  'poorli': -1.6043293444913778,
#  'bruh': -1.381185793177168,
#  'congrat': 1.679085001514394,
#  'x-ray': -0.6880386126172228,
#  'roma': -0.6880386126172228,
#  'hopeless': -1.0935037207253873,
#  'finish': 0.37980201738413316,
#  'hbdme': 0.6982557485026679,
#  'fm': 1.1037208566108323,
#  'confisc': -0.6880386126172228,
#  'daal': -1.0935037207253873,
#  'embrac': 0.6982557485026679,
#  'lost': -2.9906237056112683,
#  'subdivis': -0.6880386126172228,
#  'surgeri': -1.381185793177168,
#  'place': 0.43589148403517664,
#  'fabian': -1.0935037207253873,
#  'medic': 0.00510856794272258,
#  'darlen': -0.6880386126172228,
#  'abstin': 0.6982557485026679,
#  'deathli': 0.6982557485026679,
#  'cupcak': -1.0935037207253873,
#  'woe': -1.381185793177168,
#  'immigr': 0.6982557485026679,
#  'ketchup': -0.6880386126172228,
#  'bad': -1.2941744161875384,
#  'all-clear': 0.6982557485026679,
#  'jummapray': 0.6982557485026679,
#  'amount': 0.6982557485026679,
#  'sunnah': 0.6982557485026679,
#  'wknd': 0.6982557485026679,
#  'trainer': 0.6982557485026679,
#  'heiya': 1.1037208566108323,
#  'nj': 0.6982557485026679,
#  'diffici': -0.6880386126172228,
#  'donetsk': 0.6982557485026679,
#  'sambal': 0.6982557485026679,
#  'samosa': 0.6982557485026679,
#  'explorealberta': -0.6880386126172228,
#  'male': 0.00510856794272258,
#  'giveaway': 0.22825211925693206,
#  'viber': -0.6880386126172228,
#  'whack': -0.6880386126172228,
#  'commun': 2.644165897557981,
#  'peregrin': -0.6880386126172228,
#  'cardi': 0.6982557485026679,
#  'drew': 1.391402929062613,
#  'docopenhagen': -0.6880386126172228,
#  'x46': 0.6982557485026679,
#  'retail': 1.6145464803768226,
#  'wind': 1.1037208566108323,
#  'lesbian': -0.4003565401654419,
#  'firm': 0.6982557485026679,
#  'todayyy': 0.6982557485026679,
#  'visit': 0.865309833165834,
#  'ukrain': 0.6982557485026679,
#  'imran': 0.00510856794272258,
#  'gandhi': 0.6982557485026679,
#  'okayi': 1.1037208566108323,
#  'nixu': 0.6982557485026679,
#  'asf': -0.6880386126172228,
#  'everett': 0.6982557485026679,
#  'ate': -0.7833487924215478,
#  'yaytheylookgreat': 0.6982557485026679,
#  'spend': -1.2476544005526455,
#  'chorong': 0.00510856794272258,
#  'tweepsmatchout': -0.6880386126172228,
#  'rockfish': 0.6982557485026679,
#  'jamie-le': 0.6982557485026679,
#  'milo': 0.6982557485026679,
#  'henc': 0.6982557485026679,
#  'confer': -0.4003565401654419,
#  'icecream': 0.41057367605088696,
#  'task': 0.41057367605088696,
#  'tau': 0.6982557485026679,
#  'carpet': 0.6982557485026679,
#  'webz': 0.6982557485026679,
#  'critic': -0.6880386126172228,
#  'jenna': 0.6982557485026679,
#  'isra': -0.6880386126172228,
#  'within': 0.9213992998168774,
#  'fingers-cross': 0.6982557485026679,
#  'menu': 0.6982557485026679,
#  'ride': 0.6982557485026679,
#  'busier': -0.6880386126172228,
#  'weekendofmad': -0.6880386126172228,
#  'abt': 0.00510856794272258,
#  'akooo': -0.6880386126172228,
#  'respectlost': -0.6880386126172228,
#  'nknkkpagpapakumbaba': 0.6982557485026679,
#  'basic': 0.5159341917087131,
#  'schade': -1.0935037207253873,
#  'aaahhh': 0.00510856794272258,
#  'nightmar': -2.0743329737371132,
#  'georg': -0.6880386126172228,
#  'retain': -0.6880386126172228,
#  '♥': -0.40035654016544175,
#  'krystoria': -0.6880386126172228,
#  'weather': -1.1735464283989239,
#  'fridg': 1.1037208566108323,
#  'depend': 0.00510856794272258,
#  'adida': -0.6880386126172228,
#  'thaaat': -0.6880386126172228,
#  'dewsburi': 1.1037208566108323,
#  'fest': -0.6880386126172228,
#  'scar': 0.6982557485026679,
#  'hmph': -0.6880386126172228,
#  'zzz': -0.4003565401654419,
#  'pregnanc': -0.6880386126172228,
#  'hidden': 0.6982557485026679,
#  'ux': 0.6982557485026679,
#  'argu': 0.6982557485026679,
#  'noon': -1.381185793177168,
#  'brotheeerrr': 0.6982557485026679,
#  'har': -1.381185793177168,
#  '23rd': -0.6880386126172228,
#  'youthcelebr': 0.6982557485026679,
#  'color': 1.391402929062613,
#  'goin': 0.00510856794272258,
#  'vall': 0.6982557485026679,
#  'town': -1.0935037207253873,
#  'meet': 0.16545121801790186,
#  'renam': 0.6982557485026679,
#  'yan': 0.00510856794272258,
#  'enix': 0.6982557485026679,
#  'streak': -0.6880386126172228,
#  'obyun': -0.6880386126172228,
#  'acorn': 0.6982557485026679,
#  'eonni': 0.00510856794272258,
#  'hierro': -0.6880386126172228,
#  'rofl': 1.391402929062613,
#  '🐢': 1.1037208566108323,
#  'hola': 0.6982557485026679,
#  'tak': -0.4003565401654419,
#  'buddyyi': -0.6880386126172228,
#  'hannib': 0.2927906403945034,
#  '330': -0.6880386126172228,
#  'neat-o': -0.6880386126172228,
#  'vscocousin': 0.6982557485026679,
#  'dale': 0.6982557485026679,
#  'lee': 0.6982557485026679,
#  'fcking': -0.6880386126172228,
#  'kernel': 0.6982557485026679,
#  'hay': -2.0743329737371132,
#  'bibl': 0.6982557485026679,
#  'tack': 0.6982557485026679,
#  'faith': 0.6982557485026679,
#  '70685': 0.6982557485026679,
#  'design': 1.5632531859892722,
#  'ht': 0.6982557485026679,
#  'crew': 1.1037208566108323,
#  'blain': -1.0935037207253873,
#  'rlli': -0.6880386126172228,
#  'impress': 1.1037208566108323,
#  'risk': -1.0935037207253873,
#  'fuckin': -0.6880386126172228,
#  'creation': -0.6880386126172228,
#  "they'd": -1.0935037207253873,
#  'exec': 0.6982557485026679,
#  'joyc': -0.6880386126172228,
#  'nikeorigin': 0.6982557485026679,
#  'fotoset': 0.6982557485026679,
#  'tall': -1.0935037207253873,
#  'met': -0.4003565401654419,
#  'doli': 0.6982557485026679,
#  'client_amends_edit': 0.6982557485026679,
#  'luci': 0.6982557485026679,
#  '🍤': 1.6145464803768226,
#  'unluckiest': -0.6880386126172228,
#  'spain': -0.9111821639314325,
#  'respect': -0.4003565401654419,
#  'rumbl': -0.6880386126172228,
#  'junmyeon': -0.6880386126172228,
#  'l4l': 1.1037208566108323,
#  'ship': 0.4751121971884581,
#  'snob': -0.6880386126172228,
#  'vianey': 0.6982557485026679,
#  'beonknockknock': 0.6982557485026679,
#  'extraordinari': 0.6982557485026679,
#  'dkt': 0.6982557485026679,
#  'garden': 0.6982557485026679,
#  'therealgolden': 0.6982557485026679,
#  'wgm': 0.6982557485026679,
#  'later': 0.0921199449323522,
#  'guilti': -0.6880386126172228,
#  'china': 1.1037208566108323,
#  'ki': -0.4003565401654419,
#  'bein': -0.6880386126172228,
#  'good': 0.8317871411271907,
#  'regret': 0.00510856794272258,
#  "y'all": 0.2927906403945034,
#  'transfer': -1.381185793177168,
#  'lorenangel': 0.6982557485026679,
#  'girlfriendsmya': 0.6982557485026679,
#  'minut': -0.14904211188453576,
#  'math': 0.00510856794272258,
#  'ctto': -0.6880386126172228,
#  'gig': -0.6880386126172228,
#  'embarrass': -1.0935037207253873,
#  'pr': -0.6880386126172228,
#  'gh': -0.6880386126172228,
#  'kingfish': 0.6982557485026679,
#  'bring': 0.37283334806803986,
#  'even': -0.6693464796050703,
#  'emphasi': -0.6880386126172228,
#  'sho': 0.6982557485026679,
#  '⅛': 0.6982557485026679,
#  'hammi': 0.6982557485026679,
#  'finddjderek': -0.6880386126172228,
#  'news': -0.106117067167502,
#  'hpc': 0.6982557485026679,
#  'chant': 1.1037208566108323,
#  'easili': -0.4003565401654419,
#  'yester': -0.6880386126172228,
#  'yipppi': 0.6982557485026679,
#  'rettweet': 1.391402929062613,
#  '10am': 1.1037208566108323,
#  'aww': -0.7421058338874986,
#  'pdf': 0.6982557485026679,
#  'zzzz': -0.6880386126172228,
#  'hd': -1.0935037207253873,
#  'audienc': 0.00510856794272258,
#  'takraw': -0.6880386126172228,
#  'notr': -0.6880386126172228,
#  'sweat': -1.0935037207253873,
#  'accident': -0.6880386126172228,
#  'brows': 0.6982557485026679,
#  'tutori': -0.6880386126172228,
#  'nirvana': 0.6982557485026679,
#  'lootcrat': -0.6880386126172228,
#  'mb': 0.00510856794272258,
#  'crisi': -1.0935037207253873,
#  'bdayt': 0.6982557485026679,
#  'societi': 1.1037208566108323,
#  'repath': 1.1037208566108323,
#  'younger': 0.5159341917087131,
#  'old-porridg': 0.6982557485026679,
#  'xpress': -0.6880386126172228,
#  'sandwich': -1.6043293444913778,
#  'glasgow': 1.1037208566108323,
#  'greater': 0.6982557485026679,
#  'noseble': -0.6880386126172228,
#  'sorrri': -0.6880386126172228,
#  'aw': -2.330266347874314,
#  'yuna': 1.1037208566108323,
#  'tmr': -0.6880386126172228,
#  'theater': -0.6880386126172228,
#  'fowl': 0.6982557485026679,
#  'given': 0.6982557485026679,
#  'nathann': -0.6880386126172228,
#  'spam': -1.0935037207253873,
#  '..': 0.12041941445371684,
#  'shahid': 0.6982557485026679,
#  'refin': 0.6982557485026679,
#  'resid': 1.1037208566108323,
#  'superday': 0.6982557485026679,
#  '22pic': 0.6982557485026679,
#  'rob': 0.00510856794272258,
#  'fantasi': 1.1037208566108323,
#  'guncontrol': -0.6880386126172228,
#  '💅🏽': 0.6982557485026679,
#  'soniii': -0.6880386126172228,
#  'sampl': -0.6880386126172228,
#  'common': -0.9111821639314325,
#  'suuuper': -0.6880386126172228,
#  'yeh': -0.6880386126172228,
#  'istanya': -0.6880386126172228,
#  '1-0': -0.6880386126172228,
#  'ब': 0.6982557485026679,
#  'fear': 0.00510856794272258,
#  'scienc': 1.1037208566108323,
#  'glass': 0.2927906403945034,
#  'fron': 0.6982557485026679,
#  'fss': 0.6982557485026679,
#  'soprano': 0.6982557485026679,
#  'switch': -0.6880386126172228,
#  'puppi': 0.00510856794272258,
#  '9': -0.6880386126172228,
#  'mamayang': 0.6982557485026679,
#  'b2aa': -0.6880386126172228,
#  'stay_bless': 0.6982557485026679,
#  'bissmillah': 0.6982557485026679,
#  'dough': 0.6982557485026679,
#  'inde': 1.9510187169980358,
#  'learnt': 0.6982557485026679,
#  'cotton': -0.6880386126172228,
#  'bebii': -0.6880386126172228,
#  'heed': -1.0935037207253873,
#  'use': 0.035880226609476096,
#  'crop': 0.41057367605088696,
#  'likewis': 0.9213992998168774,
#  'hypocrit': 0.6982557485026679,
#  'man.h': 0.6982557485026679,
#  'chap': -0.6880386126172228,
#  'contrast': 0.6982557485026679,
#  'nvr': -0.6880386126172228,
#  'heart': -1.1844754989311137,
#  'chaddi': 0.6982557485026679,
#  'anxiou': 0.00510856794272258,
#  'welcom': 2.2206822839471383,
#  'digitalmarket': 0.6982557485026679,
#  'annual': 0.6982557485026679,
#  'hsm': -0.6880386126172228,
#  'puddl': -1.0935037207253873,
#  'tline': -0.6880386126172228,
#  'aahhh': -0.6880386126172228,
#  'contractu': 0.6982557485026679,
#  'balm': -0.6880386126172228,
#  'research': 0.00510856794272258,
#  'circl': 0.00510856794272258,
#  'advaddict': 0.6982557485026679,
#  '2suppli': -0.6880386126172228,
#  'cruel': -0.6880386126172228,
#  'pleasee': -0.4003565401654419,
#  'interraci': -0.6880386126172228,
#  'dipoppo': -0.6880386126172228,
#  'smooth': -0.6880386126172228,
#  'danger': 0.6982557485026679,
#  'gua': -0.6880386126172228,
#  'letshavecocktailsafternuclai': 0.6982557485026679,
#  'lollipop': 0.6982557485026679,
#  'screencap': 0.6982557485026679,
#  'walang': -0.6880386126172228,
#  'geer': 0.6982557485026679,
#  'worth': 1.2090813722686584,
#  'os': 0.00510856794272258,
#  'parisa': 0.6982557485026679,
#  'mka': 1.7968680371707775,
#  'came': -0.7486632344336577,
#  'mombasa': 0.6982557485026679,
#  'kami': 0.6982557485026679,
#  'offens': -1.0935037207253873,
#  'compliment': 0.6982557485026679,
#  'need': -0.3176648243203286,
#  'bobbl': -0.6880386126172228,
#  'orang': -1.0935037207253873,
#  'weh': -0.6880386126172228,
#  '😄': 0.6982557485026679,
#  'guess': -0.4367241843363166,
#  '2cope': -0.6880386126172228,
#  'leader': 0.6982557485026679,
#  'season': -0.2825735045090583,
#  'hahay': -0.6880386126172228,
#  'arond': 0.6982557485026679,
#  'heechul': 0.6982557485026679,
#  'nutella': -0.6880386126172228,
#  'hmmm': 0.9213992998168774,
#  'veeerri': -0.6880386126172228,
#  'cope': -1.381185793177168,
#  'selamathariraya': 0.6982557485026679,
#  'misss': -1.0935037207253873,
#  'sneaker': 0.6982557485026679,
#  'ginger': 0.6982557485026679,
#  'taknottem': -0.6880386126172228,
#  'highvalu': 1.1037208566108323,
#  'line': -0.1284228246818001,
#  '80': 0.41057367605088696,
#  'suppos': 0.3415808045639355,
#  'obakeng': 0.6982557485026679,
#  'theocrat': 0.6982557485026679,
#  'prefer': -0.4003565401654419,
#  'sakura': -0.6880386126172228,
#  'philli': 0.6982557485026679,
#  'tdif': 0.6982557485026679,
#  'satya': -0.6880386126172228,
#  'fridayfeel': 1.1037208566108323,
#  'daddi': -0.4003565401654419,
#  'hear': -0.07185247319340585,
#  'robe': -0.6880386126172228,
#  'demo': 1.1037208566108323,
#  'pillar': 1.1037208566108323,
#  'amm': 0.6982557485026679,
#  'lip': -0.4003565401654419,
#  'lab': 0.00510856794272258,
#  'gray': -0.6880386126172228,
#  'stylish': 0.6982557485026679,
#  'kgola': -0.6880386126172228,
#  'migrant': -0.6880386126172228,
#  'loop': -0.6880386126172228,
#  'sharethelov': 1.1037208566108323,
#  'warmest': -0.6880386126172228,
#  'hind': -0.6880386126172228,
#  'unreal': 0.6982557485026679,
#  'burnt': 0.00510856794272258,
#  'unknown': -0.4003565401654419,
#  'rakyat': 0.6982557485026679,
#  'ufff': -0.6880386126172228,
#  'close': -0.26315541865195685,
#  'ubusi': -0.6880386126172228,
#  'nintendo': -1.0935037207253873,
#  'debat': 1.1037208566108323,
#  'round': 0.00510856794272258,
#  'sake': -0.6880386126172228,
#  'gran': -0.4003565401654419,
#  'snow': -0.6880386126172228,
#  'hungrrryyi': -0.6880386126172228,
#  'tub': -0.6880386126172228,
#  'jaspernationalpark': -0.6880386126172228,
#  'unwind': 0.6982557485026679,
#  '┓': 1.1037208566108323,
#  '345': -0.6880386126172228,
#  'wednesday': -1.0935037207253873,
#  'birth': 0.6982557485026679,
#  'buzz': 1.1037208566108323,
#  'sweetan': 0.6982557485026679,
#  '009': 0.6982557485026679,
#  'pict': 0.00510856794272258,
#  'kandekj': -0.6880386126172228,
#  'buttonhol': 0.6982557485026679,
#  'latinhous': 0.6982557485026679,
#  'taco': 0.00510856794272258,
#  'ego': 0.6982557485026679,
#  'energi': -1.381185793177168,
#  'icon': 0.00510856794272258,
#  'xpax': 0.6982557485026679,
#  'elvena': 0.6982557485026679,
#  'iamamonst': 0.6982557485026679,
#  'sleeep': -1.381185793177168,
#  'mark': -0.4003565401654419,
#  'cover': 0.9859378209544487,
#  'grumbl': -0.6880386126172228,
#  'rrp': 0.6982557485026679,
#  'might': 0.6982557485026677,
#  'jasmingarrick': -0.6880386126172228,
#  'suck': -0.842189292444481,
#  "sod'": -0.6880386126172228,
#  'über': -0.6880386126172228,
#  '∠': -1.0935037207253873,
#  'toma': 0.6982557485026679,
#  'couldv': -0.6880386126172228,
#  'boner': -0.6880386126172228,
#  '<---': 1.1037208566108323,
#  'hologram': 0.6982557485026679,
#  'worst': -1.0064923437357574,
#  'yass': -0.6880386126172228,
#  'specialist': 0.6982557485026679,
#  'hale': 0.6982557485026679,
#  'belgium': -1.6043293444913778,
#  'comp': 0.6982557485026679,
#  'tan': -1.381185793177168,
#  '💦': -0.6880386126172228,
#  'teamposit': 0.6982557485026679,
#  'masaan': -0.6880386126172228,
#  'happyyi': 0.6982557485026679,
#  'seen': -0.8215700052417454,
#  'problemmm': 0.6982557485026679,
#  'ahaha': -0.6880386126172228,
#  'smi': -0.6880386126172228,
#  'groan': -0.6880386126172228,
#  'phrase': -0.6880386126172228,
#  'spare': 0.00510856794272258,
#  'wayanadan': 0.6982557485026679,
#  'georgi': 0.00510856794272258,
#  'thnk': 0.6982557485026679,
#  'coach': 0.00510856794272258,
#  'x30': 0.6982557485026679,
#  'lie': -0.6880386126172228,
#  'step': -0.2180349833714872,
#  'panga': -0.6880386126172228,
#  'treat': -0.1772129888512322,
#  'shoulder': -0.4003565401654419,
#  'pano': -0.6880386126172228,
#  'toler': -0.6880386126172228,
#  '340': -0.6880386126172228,
#  'mayday': -0.6880386126172228,
#  'idea': 0.9859378209544488,
#  'asap': 0.6982557485026679,
#  '💫': -0.6880386126172228,
#  'sensibl': -0.6880386126172228,
#  'memor': -0.6880386126172228,
#  'olymp': -0.6880386126172228,
#  'distrub': 0.6982557485026679,
#  'askaman': 0.6982557485026679,
#  'dislik': -0.6880386126172228,
#  'countthecost': -0.6880386126172228,
#  'hogan': -1.0935037207253873,
#  'on-pack': 0.6982557485026679,
#  'greatli': 0.6982557485026679,
#  'incompleta': -0.6880386126172228,
#  'bittersweet': -0.6880386126172228,
#  'rehears': 0.00510856794272258,
#  'plugin': 0.6982557485026679,
#  'piggin': 0.6982557485026679,
#  'physiqu': 0.6982557485026679,
#  'mwf': 0.6982557485026679,
#  'hangout': -1.0935037207253873,
#  'estat': -0.6880386126172228,
#  'notgonnabeactivefor': -0.6880386126172228,
#  'razzist': -0.6880386126172228,
#  'carol': 1.1037208566108323,
#  'sanda': 0.6982557485026679,
#  'mental': -0.9111821639314325,
#  'pesaro': -0.6880386126172228,
#  'ifeely': -0.6880386126172228,
#  'elgin': -0.6880386126172228,
#  'lockscreen': 0.6982557485026679,
#  '★': 1.7968680371707775,
#  'heaven': 1.1037208566108323,
#  'drug': 0.00510856794272258,
#  ';p': 0.6982557485026679,
#  'sholong': -0.6880386126172228,
#  'punt': 0.6982557485026679,
#  'surajettan': 0.6982557485026679,
#  '4yr': 0.6982557485026679,
#  'claim': -0.6880386126172228,
#  'long-dist': 0.6982557485026679,
#  'lyka': 0.6982557485026679,
#  'inshallah': 0.6982557485026679,
#  '2week': 0.00510856794272258,
#  'courgett': 0.6982557485026679,
#  'tou': 0.00510856794272258,
#  'snake': -0.6880386126172228,
#  '61': -0.6880386126172228,
#  '💓': 0.6982557485026679,
#  '10,000': 0.6982557485026679,
#  'volta': 0.6982557485026679,
#  'bali': -0.6880386126172228,
#  'ju': 0.6982557485026679,
#  'debt': 1.1037208566108323,
#  'stash': 1.1037208566108323,
#  'border': 0.6982557485026679,
#  'detail': 0.8160387841590513,
#  'elah': 0.6982557485026679,
#  'aftenoon': -0.6880386126172228,
#  'mon': 1.391402929062613,
#  'dah': 1.1037208566108323,
#  'yell': 0.00510856794272258,
#  '16.20': 0.6982557485026679,
#  'bugatti': 0.6982557485026679,
#  '91': 1.1037208566108323,
#  'manuel': 0.6982557485026679,
#  'milf': -0.6880386126172228,
#  'gear': -0.6880386126172228,
#  'pebbl': 0.6982557485026679,
#  'rachel': -0.6880386126172228,
#  "o'neal": 0.6982557485026679,
#  'twin': -0.6880386126172228,
#  'parad': -0.6880386126172228,
#  'caus': 0.0921199449323522,
#  'vishaya': -0.6880386126172228,
#  'struggl': -1.6043293444913778,
#  'juli': -0.07493413973081395,
#  'confess': 0.6982557485026679,
#  "josephine'": 0.6982557485026679,
#  'tla': -0.6880386126172228,
#  'extrem': 0.00510856794272258,
#  'will': 0.6982557485026679,
#  'resourc': -0.6880386126172228,
#  'trouser': -0.6880386126172228,
#  'bandana': -0.6880386126172228,
#  'squar': 0.6982557485026679,
#  'peachyloan': 0.6982557485026679,
#  'stem': 0.6982557485026679,
#  'ariana': 1.1037208566108323,
#  'creta': 0.6982557485026679,
#  'exclus': -0.6880386126172228,
#  'expand': 1.1037208566108323,
#  'claw': 0.6982557485026679,
#  'xenophob': -0.6880386126172228,
#  'wii': -1.0935037207253873,
#  '327': -0.6880386126172228,
#  'besi': 0.6982557485026679,
#  'cow': -0.6880386126172228,
#  'tradit': -0.6880386126172228,
#  'sakit': -1.0935037207253873,
#  'x37': 0.6982557485026679,
#  'kapatidkongpogi': -0.6880386126172228,
#  'outsid': -0.8058216482736063,
#  'jabongatpumaurbanstamped': 0.9213992998168774,
#  'preciou': -1.381185793177168,
#  'wound': -0.6880386126172228,
#  'clapham': -0.6880386126172228,
#  'oliv': 0.6982557485026679,
#  'yhooo': 0.6982557485026679,
#  'bb': -0.33136366867849054,
#  'guest': -0.4003565401654419,
#  'monday': 0.00510856794272258,
#  'deya': 0.6982557485026679,
#  'nooop': -0.6880386126172228,
#  'wakeup': 0.6982557485026679,
#  'arriv': 2.4561136660550416,
#  'takeaway': 0.6982557485026679,
#  'colder': -0.6880386126172228,
#  'im': -1.0226776681567749,
#  'junhe': -0.6880386126172228,
#  'assur': 0.6982557485026679,
#  'mid-end': -0.6880386126172228,
#  'itv': 0.6982557485026679,
#  'privaci': 0.6982557485026679,
#  'sath': 1.1037208566108323,
#  'driver': -0.6880386126172228,
#  'fb': 0.005108567942722359,
#  'ooouch': -0.6880386126172228,
#  'mussel': 0.6982557485026679,
#  'directx': -0.6880386126172228,
#  'junjou': -1.0935037207253873,
#  'standrew': 0.6982557485026679,
#  'gosh': -0.5057170558232682,
#  'mui': 0.6982557485026679,
#  'x22': 0.6982557485026679,
#  'montoya': 0.6982557485026679,
#  'legibl': -1.0935037207253873,
#  'pop': 0.41057367605088696,
#  'christ': -0.6880386126172228,
#  '♬': 0.6982557485026679,
#  'clich': -0.6880386126172228,
#  'da': -0.1772129888512322,
#  '6th': -0.6880386126172228,
#  'ramadhan': -0.6880386126172228,
#  'bcu': 0.6982557485026679,
#  'solar': 0.6982557485026679,
#  'entp': 0.6982557485026679,
#  'eagerli': 0.6982557485026679,
#  'section': 0.41057367605088696,
#  'billion': 0.00510856794272258,
#  "harry'": -1.0935037207253873,
#  'sarcasm': 0.6982557485026679,
#  'ek': 0.6982557485026679,
#  'park': -0.842189292444481,
#  'jersey': -1.0935037207253873,
#  'advisori': -0.6880386126172228,
#  'barkin': 0.6982557485026679,
#  'cayton': -0.6880386126172228,
#  'juudiciari': -0.6880386126172228,
#  'throw': 0.2927906403945034,
#  'woohyun': -1.0935037207253873,
#  'act': 0.8524064283299261,
#  'fricken': -0.6880386126172228,
#  'cyber': 0.00510856794272258,
#  'consider': 0.6982557485026679,
#  'santorini': 0.6982557485026679,
#  'jet': -0.6880386126172228,
#  'mi': 0.5159341917087131,
#  '00962778381': 0.6982557485026679,
#  'sneak': -0.2825735045090583,
#  'scheme': -1.0935037207253873,
#  'sofa': 0.6982557485026679,
#  'et': -1.0935037207253873,
#  'fiend': 0.6982557485026679,
#  'whatsapp': 0.6982557485026679,
#  'translat': -0.4003565401654419,
#  'booo': -1.0935037207253873,
#  'cock': -0.6880386126172228,
#  'bowwowchicawowwow': 0.6982557485026679,
#  'peac': 0.5928952328448415,
#  'bueno': -0.6880386126172228,
#  'tom': 0.41057367605088696,
#  'naaan': -0.6880386126172228,
#  'shit': -0.8058216482736063,
#  '000': 0.6982557485026679,
#  'tattoo': 1.391402929062613,
#  'domesticviol': -0.6880386126172228,
#  '=d': 1.1037208566108323,
#  'youtub': 0.5928952328448415,
#  'beast': -0.6880386126172228,
#  'stori': -0.08190280904690739,
#  'lani': 0.6982557485026679,
#  'cool': 1.7968680371707775,
#  'encourag': 1.391402929062613,
#  'nic': 1.1037208566108323,
#  'minist': 1.1037208566108323,
#  'alek': 0.6982557485026679,
#  'sheffield': 0.00510856794272258,
#  'offroad': -0.6880386126172228,
#  'diagnos': -0.6880386126172228,
#  'babyyi': 0.6982557485026679,
#  '0ne': 1.1037208566108323,
#  'wa': -0.6880386126172228,
#  "lady'": 0.6982557485026679,
#  '349': -0.6880386126172228,
#  'soobin': -0.6880386126172228,
#  'pandimension': 0.6982557485026679,
#  'bandz': 0.6982557485026679,
#  'condit': 0.00510856794272258,
#  'truli': -1.381185793177168,
#  'yt': -0.2825735045090583,
#  'babi': -0.7421058338874986,
#  'ape': 0.6982557485026679,
#  'mac': -0.6880386126172228,
#  'whenev': -0.2825735045090583,
#  ...}

# %% [markdown]
# # Probando el modelo de Naive Bayes
#
# Ahora que tenemos `logprior` y` loglikelihood`, podemos probar el modelo de Naive Bayes para predecir algunos tweets.
#
# #### Implementación de  `naive_bayes_predict`
#
# Implementaremos la función `naive_bayes_predict` para hacer predicciones de tweets.
#
# * La función toma como entrada el `tweet`,` logprior`, y `loglikelihood`.
# * Devuelve la probabilidad de que el tweet pertenezca a la clase positiva o negativa.
# * Para cada tweet, se sumarán las probabilidades de cada palabra en el tweet.
# * También se agregará el logprior de esta suma para obtener la predicción de sentimiento del tweet
#
# $$ p = logprior + \sum_i^N (loglikelihood_i)$$
#
# #### Nota
#
# Tenga en cuenta que calculamos el "prior" a partir de los datos de entrenamiento y que los datos de entrenamiento se dividen uniformemente entre etiquetas positivas y negativas (4000 tweets positivos y 4000 negativos). Esto significa que el ratio de positivo a negativo 1, y el logprior es 0.
#
# El valor de 0.0 significa que cuando agregamos el logprior al likelihood, simplemente estamos agregando un valor de cero a la probabilidad logarítmica. Sin embargo, recuerde incluir el logprior, porque siempre que los datos no estén perfectamente equilibrados, el logprior será un valor distinto de cero.

# %%
def naive_bayes_predict(tweet, logprior, loglikelihood):
    '''
    input:
    tweet: una cadena de caracteres
    logprior. un número (0 si el dataset está balanceado)
    loglikelihood: es un diccionario de palabras que mapean a números
    output:
    p: la suma de todos los loglikelihoods de cada palabra en el tweet
    '''

    #preprocesamiento del tweet
    word_l = process_tweet(tweet)

    p = 0
    #Añadir a p, el logprior
    p += logprior

    for word in word_l:
      #Checar si la palabra existe en el loglikelihood (el diccionario)
      if word in loglikelihood:
        #añadimos el valor a la probabilidad de p
        p +=loglikelihood[word]
    return p

# %%
#predecir
my_tweet = "she Smiled a lot"
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
p
# Out:
# 3.0288432293052887

# %%
my_tweet = "yor are so bad"
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
p
# Out:
# -1.2941744161875384

# %%
x_tweet = 'A thousand planets. One mission to save them all. Watch the new #Valerian trailer and like this Tweet to explore more. In theaters July 21'
p = naive_bayes_predict(x_tweet, logprior, loglikelihood)
p
# Out:
# 2.814785778290656

# %% [markdown]
# #### Implementando  test_naive_bayes
#
# * Implementaremos `test_naive_bayes` la función para ver el accuracy de las predicciones.
# * La función toma de `test_x`, `test_y`,el log_prior, y el loglikelihood
# * Regresa el ccuracy del modelo
# * Primeramente, usaremos la función `naive_bayes_predict` para hacer las predicciones para cada tweet en text_x.

# %%
def test_naive_bayes(test_x, test_y, logprior, loglikelihood):
    '''
    Input:
    test_x. lista de tweets a entrenar
    test_y: las etiquetas de positivos y negativos
    logprior: el logprior (log(Dpos) - log(Dneg))
    loglikelihood. diccionario con las palabras y el loglikelihood

    '''
    accuracy=0

    y_hats = []
    for tweet in test_x:
      if naive_bayes_predict(tweet, logprior, loglikelihood) >0:
        #el tweet pertece a un sentimiento positivo
        y_hats.append(1)
      else:
        #el tweet pertenece a un sentimiento negativo o neutro
        y_hats.append(0)

    error = np.mean(np.absolute(y_hats - test_y))

    accuracy = 1- error
    return accuracy

# %%
print('Accuracy: ', test_naive_bayes(test_x, test_y, logprior, loglikelihood))
# Out:
# Accuracy:  0.994

# %%
tweets=['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']
for tweet in tweets:
  p = naive_bayes_predict(tweet, logprior, loglikelihood)
  print(f'{tweet} ----> {p:2f}')
# Out:
# I am happy ----> 2.148266
# I am bad ----> -1.294174
# this movie should have been great. ----> 2.142903
# great ----> 2.137795
# great great ----> 4.275589
# great great great ----> 6.413384
# great great great great ----> 8.551178

# %% [markdown]
# ### Predecir un tweet propio

# %%
# Feel free to check the sentiment of your own tweet below

# %% [markdown]
# # Filtrado de palabras por ratios positivos y negativos
#
# - Algunas palabras tienen un conteo de etiquetas más positivos que otras y pueden considerarse "más positivas". Asimismo, algunas palabras pueden considerarse más negativas que otras.
#
# - Una forma de definir el nivel de positividad o negatividad, sin calcular la probabilidad logarítmica, es comparar la frecuencia positiva con la negativa de la palabra.
#
#     - Tenga en cuenta que también podemos utilizar los cálculos de probabilidad logarítmica para comparar la positividad o negatividad relativa de las palabras.
#
# - Podemos calcular el ratio de las frecuencias positivas y negativas de una palabra.
# - Una vez que podamos calcular estos ratios, también podemos filtrar un subconjunto de palabras que tengan una proporción mínima de positividad / negatividad o superior.
# - De manera similar, también podemos filtrar un subconjunto de palabras que tienen una proporción máxima de positividad / negatividad o menor (palabras que son menos negativas, o incluso más negativas que un umbral dado).
#
# #### Implementación `get_ratio()`
#
# - Dado el diccionario de palabras `freqs` y una palabra en particular, usaremos` lookup (freqs, word, 1) `para obtener el recuento positivo de la palabra.
# - De manera similar, usaremos la función `lookup ()` para obtener el recuento negativo de esa palabra.
# - Calcularemos la proporción de positivo dividido por conteos negativos.
#
# $$ ratio = \frac{\text{pos_words} + 1}{\text{neg_words} + 1} $$
#
# Where pos_words and neg_words correspond to the frequency of the words in their respective classes.
# <table>
#     <tr>
#         <td>
#             <b>Words</b>
#         </td>
#         <td>
#         Positive word count
#         </td>
#          <td>
#         Negative Word Count
#         </td>
#   </tr>
#     <tr>
#         <td>
#         glad
#         </td>
#          <td>
#         41
#         </td>
#     <td>
#         2
#         </td>
#   </tr>
#     <tr>
#         <td>
#         arriv
#         </td>
#          <td>
#         57
#         </td>
#     <td>
#         4
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :(
#         </td>
#          <td>
#         1
#         </td>
#     <td>
#         3663
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :-(
#         </td>
#          <td>
#         0
#         </td>
#     <td>
#         378
#         </td>
#   </tr>
# </table>

# %%
def get_ratio(freqs, word):
    '''
    Input:
    freqs : el diccionario que contienne las palabras
    word: la palabra a buscar
    Output:
    pos_neg_ratio: un diccionario con los keys 'positivos', 'negativos' y 'ratio
    ej: {'positivo':0, 'negativo':0, 'ratio': 0}
    '''

    pos_neg_ratio = {'positivo': 0, 'negativo': 0, 'ratio': 0.0}

    #usar el método lookup() para encontrar el conteo de las palabras que son negativas
    pos_neg_ratio['negativo'] = lookup(freqs,word, 0)

    #usar el método lookup() para encontrar el conteo de las palabras que son positivas
    pos_neg_ratio['positivo'] = lookup(freqs,word, 1)

    pos_neg_ratio['ratio'] = (pos_neg_ratio['positivo'] + 1)/(pos_neg_ratio['negativo'] + 1)

    return pos_neg_ratio

# %%
get_ratio(freqs, 'happi')
# Out:
# {'positivo': 161, 'negativo': 18, 'ratio': 8.526315789473685}

# %% [markdown]
# #### Implementación `get_words_by_threshold(freqs,label,threshold)`
#
# * Si establecemos label en 1, buscaremos todas las palabras cuyo umbral de positivo / negativo sea mayoy o igual al umbral.
# * Si establecemos la etiqueta en 0, buscaremos todas las palabras cuyo umbral de positivo / negativo sea menor o igual al umbral.
# * Utilizaremos la función `get_ratio ()` para obtener un diccionario que contenga el recuento positivo, el recuento negativo y la proporción de recuentos positivos y negativos.
# * Agregaremos un diccionario a una lista, donde la clave es la palabra y el diccionario es el diccionario `pos_neg_ratio` que es devuelto por la función` get_ratio () `.
#
# Un ejemplo de este diccionario sería:
# ```
# {'happi':
#     {'positive': 10, 'negative': 20, 'ratio': 0.5}
# }
# ```

# %%
def get_words_by_threshold(freqs, label, threshold):
    '''
    Input:
    freqs. diccionario de palabras con sus frecuencias
    label: etiqueta para el sentimiento (1-> positivo, 0->negativo)
    threshold: ratio que se va usar para filtrar las palabras del diccionario
    '''

    word_list = {}
    for key in freqs.keys():
      word, _ = key
      #los ratios de cada palabra (pos/neg)
      pos_neg_ratio = get_ratio(freqs, word)

      #si la etiqueta es 1 y el ratio es mayor al threshold entonces se agrefa al diccionario word_list
      if label==1 and pos_neg_ratio['ratio']>=threshold:
        word_list[word] = pos_neg_ratio
      elif label==0 and pos_neg_ratio['ratio']<threshold:
        word_list[word] =pos_neg_ratio

    return word_list

# %%
# Testear la función con etiqueta 0
get_words_by_threshold(freqs, label=0, threshold = 0.05)
# Out:
# {':(': {'positivo': 1, 'negativo': 3663, 'ratio': 0.0005458515283842794},
#  ':-(': {'positivo': 0, 'negativo': 378, 'ratio': 0.002638522427440633},
#  '26': {'positivo': 0, 'negativo': 20, 'ratio': 0.047619047619047616},
#  '>:(': {'positivo': 0, 'negativo': 43, 'ratio': 0.022727272727272728},
#  '♛': {'positivo': 0, 'negativo': 210, 'ratio': 0.004739336492890996},
#  '》': {'positivo': 0, 'negativo': 210, 'ratio': 0.004739336492890996},
#  'beli̇ev': {'positivo': 0, 'negativo': 35, 'ratio': 0.027777777777777776},
#  'wi̇ll': {'positivo': 0, 'negativo': 35, 'ratio': 0.027777777777777776},
#  'justi̇n': {'positivo': 0, 'negativo': 35, 'ratio': 0.027777777777777776},
#  'ｓｅｅ': {'positivo': 0, 'negativo': 35, 'ratio': 0.027777777777777776},
#  'ｍｅ': {'positivo': 0, 'negativo': 35, 'ratio': 0.027777777777777776}}

# %%
# Testear la función con etiqueta 1
get_words_by_threshold(freqs, label=1, threshold = 0.05)
# Out:
# {'followfriday': {'positivo': 23, 'negativo': 0, 'ratio': 24.0},
#  'top': {'positivo': 30, 'negativo': 5, 'ratio': 5.166666666666667},
#  'engag': {'positivo': 7, 'negativo': 0, 'ratio': 8.0},
#  'member': {'positivo': 14, 'negativo': 6, 'ratio': 2.142857142857143},
#  'commun': {'positivo': 27, 'negativo': 1, 'ratio': 14.0},
#  'week': {'positivo': 72, 'negativo': 47, 'ratio': 1.5208333333333333},
#  ':)': {'positivo': 2847, 'negativo': 2, 'ratio': 949.3333333333334},
#  'hey': {'positivo': 60, 'negativo': 20, 'ratio': 2.9047619047619047},
#  'jame': {'positivo': 7, 'negativo': 3, 'ratio': 2.0},
#  'odd': {'positivo': 2, 'negativo': 2, 'ratio': 1.0},
#  ':/': {'positivo': 5, 'negativo': 8, 'ratio': 0.6666666666666666},
#  'pleas': {'positivo': 80, 'negativo': 243, 'ratio': 0.3319672131147541},
#  'call': {'positivo': 27, 'negativo': 22, 'ratio': 1.2173913043478262},
#  'contact': {'positivo': 4, 'negativo': 7, 'ratio': 0.625},
#  'centr': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  '02392441234': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'abl': {'positivo': 6, 'negativo': 17, 'ratio': 0.3888888888888889},
#  'assist': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'mani': {'positivo': 28, 'negativo': 24, 'ratio': 1.16},
#  'thank': {'positivo': 504, 'negativo': 94, 'ratio': 5.315789473684211},
#  'listen': {'positivo': 14, 'negativo': 14, 'ratio': 1.0},
#  'last': {'positivo': 39, 'negativo': 51, 'ratio': 0.7692307692307693},
#  'night': {'positivo': 55, 'negativo': 33, 'ratio': 1.6470588235294117},
#  'bleed': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'amaz': {'positivo': 41, 'negativo': 12, 'ratio': 3.230769230769231},
#  'track': {'positivo': 5, 'negativo': 1, 'ratio': 3.0},
#  'scotland': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'congrat': {'positivo': 15, 'negativo': 2, 'ratio': 5.333333333333333},
#  'yeaaah': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'yipppi': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'accnt': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'verifi': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'rqst': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'succeed': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'got': {'positivo': 57, 'negativo': 90, 'ratio': 0.6373626373626373},
#  'blue': {'positivo': 8, 'negativo': 4, 'ratio': 1.8},
#  'tick': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'mark': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'fb': {'positivo': 4, 'negativo': 4, 'ratio': 1.0},
#  'profil': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  '15': {'positivo': 4, 'negativo': 8, 'ratio': 0.5555555555555556},
#  'day': {'positivo': 187, 'negativo': 114, 'ratio': 1.6347826086956523},
#  'one': {'positivo': 90, 'negativo': 117, 'ratio': 0.7711864406779662},
#  'irresist': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'flipkartfashionfriday': {'positivo': 16, 'negativo': 0, 'ratio': 17.0},
#  'like': {'positivo': 187, 'negativo': 182, 'ratio': 1.0273224043715847},
#  'keep': {'positivo': 55, 'negativo': 31, 'ratio': 1.75},
#  'love': {'positivo': 336, 'negativo': 128, 'ratio': 2.612403100775194},
#  'custom': {'positivo': 4, 'negativo': 1, 'ratio': 2.5},
#  'wait': {'positivo': 55, 'negativo': 36, 'ratio': 1.5135135135135136},
#  'long': {'positivo': 27, 'negativo': 33, 'ratio': 0.8235294117647058},
#  'hope': {'positivo': 113, 'negativo': 91, 'ratio': 1.2391304347826086},
#  'enjoy': {'positivo': 57, 'negativo': 7, 'ratio': 7.25},
#  'happi': {'positivo': 161, 'negativo': 18, 'ratio': 8.526315789473685},
#  'friday': {'positivo': 91, 'negativo': 9, 'ratio': 9.2},
#  'lwwf': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'second': {'positivo': 8, 'negativo': 3, 'ratio': 2.25},
#  'thought': {'positivo': 21, 'negativo': 28, 'ratio': 0.7586206896551724},
#  '’': {'positivo': 17, 'negativo': 20, 'ratio': 0.8571428571428571},
#  'enough': {'positivo': 16, 'negativo': 18, 'ratio': 0.8947368421052632},
#  'time': {'positivo': 100, 'negativo': 125, 'ratio': 0.8015873015873016},
#  'dd': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'new': {'positivo': 111, 'negativo': 43, 'ratio': 2.5454545454545454},
#  'short': {'positivo': 6, 'negativo': 8, 'ratio': 0.7777777777777778},
#  'enter': {'positivo': 9, 'negativo': 1, 'ratio': 5.0},
#  'system': {'positivo': 2, 'negativo': 3, 'ratio': 0.75},
#  'sheep': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'must': {'positivo': 14, 'negativo': 12, 'ratio': 1.1538461538461537},
#  'buy': {'positivo': 9, 'negativo': 11, 'ratio': 0.8333333333333334},
#  'jgh': {'positivo': 4, 'negativo': 2, 'ratio': 1.6666666666666667},
#  'go': {'positivo': 120, 'negativo': 181, 'ratio': 0.6648351648351648},
#  'bayan': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  ':d': {'positivo': 498, 'negativo': 0, 'ratio': 499.0},
#  'bye': {'positivo': 5, 'negativo': 6, 'ratio': 0.8571428571428571},
#  'act': {'positivo': 6, 'negativo': 2, 'ratio': 2.3333333333333335},
#  'mischiev': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'etl': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'layer': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'in-hous': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'wareh': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'app': {'positivo': 12, 'negativo': 12, 'ratio': 1.0},
#  'katamari': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'well': {'positivo': 66, 'negativo': 49, 'ratio': 1.34},
#  '…': {'positivo': 31, 'negativo': 14, 'ratio': 2.1333333333333333},
#  'name': {'positivo': 12, 'negativo': 13, 'ratio': 0.9285714285714286},
#  'impli': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  ':p': {'positivo': 104, 'negativo': 0, 'ratio': 105.0},
#  'influenc': {'positivo': 16, 'negativo': 0, 'ratio': 17.0},
#  'big': {'positivo': 27, 'negativo': 17, 'ratio': 1.5555555555555556},
#  '...': {'positivo': 227, 'negativo': 282, 'ratio': 0.8056537102473498},
#  'juici': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'selfi': {'positivo': 11, 'negativo': 5, 'ratio': 2.0},
#  'follow': {'positivo': 319, 'negativo': 245, 'ratio': 1.3008130081300813},
#  'perfect': {'positivo': 17, 'negativo': 2, 'ratio': 6.0},
#  'alreadi': {'positivo': 19, 'negativo': 41, 'ratio': 0.47619047619047616},
#  'know': {'positivo': 120, 'negativo': 110, 'ratio': 1.09009009009009},
#  "what'": {'positivo': 14, 'negativo': 13, 'ratio': 1.0714285714285714},
#  'great': {'positivo': 134, 'negativo': 15, 'ratio': 8.4375},
#  'opportun': {'positivo': 17, 'negativo': 1, 'ratio': 9.0},
#  'junior': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'triathlet': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'age': {'positivo': 2, 'negativo': 8, 'ratio': 0.3333333333333333},
#  '12': {'positivo': 5, 'negativo': 4, 'ratio': 1.2},
#  '13': {'positivo': 5, 'negativo': 2, 'ratio': 2.0},
#  'gatorad': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'seri': {'positivo': 4, 'negativo': 2, 'ratio': 1.6666666666666667},
#  'get': {'positivo': 164, 'negativo': 181, 'ratio': 0.9065934065934066},
#  'entri': {'positivo': 3, 'negativo': 3, 'ratio': 1.0},
#  'lay': {'positivo': 3, 'negativo': 2, 'ratio': 1.3333333333333333},
#  'greet': {'positivo': 4, 'negativo': 5, 'ratio': 0.8333333333333334},
#  'card': {'positivo': 6, 'negativo': 6, 'ratio': 1.0},
#  'rang': {'positivo': 2, 'negativo': 4, 'ratio': 0.6},
#  'print': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'today': {'positivo': 86, 'negativo': 88, 'ratio': 0.9775280898876404},
#  'job': {'positivo': 34, 'negativo': 8, 'ratio': 3.888888888888889},
#  ':-)': {'positivo': 543, 'negativo': 0, 'ratio': 544.0},
#  "friend'": {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'lunch': {'positivo': 3, 'negativo': 8, 'ratio': 0.4444444444444444},
#  'yummm': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'nostalgia': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'tb': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'ku': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'id': {'positivo': 8, 'negativo': 5, 'ratio': 1.5},
#  'conflict': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'help': {'positivo': 37, 'negativo': 44, 'ratio': 0.8444444444444444},
#  "here'": {'positivo': 20, 'negativo': 0, 'ratio': 21.0},
#  'screenshot': {'positivo': 2, 'negativo': 4, 'ratio': 0.6},
#  'work': {'positivo': 88, 'negativo': 102, 'ratio': 0.8640776699029126},
#  'hi': {'positivo': 154, 'negativo': 28, 'ratio': 5.344827586206897},
#  'liv': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'hello': {'positivo': 49, 'negativo': 8, 'ratio': 5.555555555555555},
#  'need': {'positivo': 62, 'negativo': 86, 'ratio': 0.7241379310344828},
#  'someth': {'positivo': 25, 'negativo': 21, 'ratio': 1.1818181818181819},
#  'u': {'positivo': 136, 'negativo': 151, 'ratio': 0.9013157894736842},
#  'fm': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'twitter': {'positivo': 25, 'negativo': 20, 'ratio': 1.2380952380952381},
#  '—': {'positivo': 22, 'negativo': 18, 'ratio': 1.2105263157894737},
#  'sure': {'positivo': 37, 'negativo': 26, 'ratio': 1.4074074074074074},
#  'thing': {'positivo': 48, 'negativo': 43, 'ratio': 1.1136363636363635},
#  'dm': {'positivo': 34, 'negativo': 20, 'ratio': 1.6666666666666667},
#  'x': {'positivo': 50, 'negativo': 35, 'ratio': 1.4166666666666667},
#  "i'v": {'positivo': 25, 'negativo': 64, 'ratio': 0.4},
#  'heard': {'positivo': 9, 'negativo': 5, 'ratio': 1.6666666666666667},
#  'four': {'positivo': 5, 'negativo': 3, 'ratio': 1.5},
#  'season': {'positivo': 5, 'negativo': 7, 'ratio': 0.75},
#  'pretti': {'positivo': 17, 'negativo': 12, 'ratio': 1.3846153846153846},
#  'dope': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'penthous': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'obv': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'gobigorgohom': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'fun': {'positivo': 45, 'negativo': 20, 'ratio': 2.1904761904761907},
#  "y'all": {'positivo': 3, 'negativo': 2, 'ratio': 1.3333333333333333},
#  'yeah': {'positivo': 30, 'negativo': 35, 'ratio': 0.8611111111111112},
#  'suppos': {'positivo': 6, 'negativo': 4, 'ratio': 1.4},
#  'lol': {'positivo': 48, 'negativo': 31, 'ratio': 1.53125},
#  'chat': {'positivo': 9, 'negativo': 5, 'ratio': 1.6666666666666667},
#  'bit': {'positivo': 16, 'negativo': 12, 'ratio': 1.3076923076923077},
#  'youth': {'positivo': 14, 'negativo': 0, 'ratio': 15.0},
#  '💅🏽': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  '💋': {'positivo': 2, 'negativo': 2, 'ratio': 1.0},
#  'seen': {'positivo': 6, 'negativo': 15, 'ratio': 0.4375},
#  'year': {'positivo': 33, 'negativo': 37, 'ratio': 0.8947368421052632},
#  'rest': {'positivo': 9, 'negativo': 17, 'ratio': 0.5555555555555556},
#  'goe': {'positivo': 4, 'negativo': 4, 'ratio': 1.0},
#  'quickli': {'positivo': 3, 'negativo': 1, 'ratio': 2.0},
#  'bed': {'positivo': 8, 'negativo': 10, 'ratio': 0.8181818181818182},
#  'music': {'positivo': 15, 'negativo': 12, 'ratio': 1.2307692307692308},
#  'fix': {'positivo': 6, 'negativo': 6, 'ratio': 1.0},
#  'dream': {'positivo': 17, 'negativo': 17, 'ratio': 1.0},
#  'spiritu': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'ritual': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'festiv': {'positivo': 7, 'negativo': 2, 'ratio': 2.6666666666666665},
#  'népal': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'begin': {'positivo': 4, 'negativo': 2, 'ratio': 1.6666666666666667},
#  'line-up': {'positivo': 4, 'negativo': 0, 'ratio': 5.0},
#  'left': {'positivo': 10, 'negativo': 22, 'ratio': 0.4782608695652174},
#  'see': {'positivo': 156, 'negativo': 104, 'ratio': 1.4952380952380953},
#  'sarah': {'positivo': 4, 'negativo': 0, 'ratio': 5.0},
#  'send': {'positivo': 17, 'negativo': 7, 'ratio': 2.25},
#  'us': {'positivo': 91, 'negativo': 33, 'ratio': 2.7058823529411766},
#  'email': {'positivo': 22, 'negativo': 10, 'ratio': 2.090909090909091},
#  'bitsy@bitdefender.com': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  "we'll": {'positivo': 12, 'negativo': 6, 'ratio': 1.8571428571428572},
#  'asap': {'positivo': 5, 'negativo': 2, 'ratio': 2.0},
#  'kik': {'positivo': 16, 'negativo': 55, 'ratio': 0.30357142857142855},
#  'hatessuc': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  '32429': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'kikm': {'positivo': 1, 'negativo': 7, 'ratio': 0.25},
#  'lgbt': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'tinder': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'nsfw': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'akua': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'cumshot': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'come': {'positivo': 63, 'negativo': 72, 'ratio': 0.8767123287671232},
#  'hous': {'positivo': 5, 'negativo': 12, 'ratio': 0.46153846153846156},
#  'nsn_supplement': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'effect': {'positivo': 2, 'negativo': 3, 'ratio': 0.75},
#  'press': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'releas': {'positivo': 11, 'negativo': 5, 'ratio': 2.0},
#  'distribut': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'result': {'positivo': 2, 'negativo': 3, 'ratio': 0.75},
#  'link': {'positivo': 13, 'negativo': 9, 'ratio': 1.4},
#  'remov': {'positivo': 3, 'negativo': 2, 'ratio': 1.3333333333333333},
#  'pressreleas': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'newsdistribut': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'bam': {'positivo': 44, 'negativo': 0, 'ratio': 45.0},
#  'bestfriend': {'positivo': 50, 'negativo': 6, 'ratio': 7.285714285714286},
#  'lot': {'positivo': 80, 'negativo': 18, 'ratio': 4.2631578947368425},
#  'warsaw': {'positivo': 44, 'negativo': 0, 'ratio': 45.0},
#  '<3': {'positivo': 118, 'negativo': 19, 'ratio': 5.95},
#  'x46': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'everyon': {'positivo': 45, 'negativo': 18, 'ratio': 2.4210526315789473},
#  'watch': {'positivo': 32, 'negativo': 57, 'ratio': 0.5689655172413793},
#  'documentari': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'earthl': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'youtub': {'positivo': 8, 'negativo': 4, 'ratio': 1.8},
#  'support': {'positivo': 25, 'negativo': 24, 'ratio': 1.04},
#  'buuut': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'oh': {'positivo': 44, 'negativo': 78, 'ratio': 0.569620253164557},
#  'look': {'positivo': 109, 'negativo': 79, 'ratio': 1.375},
#  'forward': {'positivo': 20, 'negativo': 5, 'ratio': 3.5},
#  'visit': {'positivo': 25, 'negativo': 10, 'ratio': 2.3636363636363638},
#  'next': {'positivo': 37, 'negativo': 31, 'ratio': 1.1875},
#  'letsgetmessi': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'jo': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'make': {'positivo': 69, 'negativo': 90, 'ratio': 0.7692307692307693},
#  'feel': {'positivo': 33, 'negativo': 131, 'ratio': 0.25757575757575757},
#  'better': {'positivo': 40, 'negativo': 31, 'ratio': 1.28125},
#  'never': {'positivo': 31, 'negativo': 42, 'ratio': 0.7441860465116279},
#  'anyon': {'positivo': 7, 'negativo': 14, 'ratio': 0.5333333333333333},
#  'kpop': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'flesh': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'good': {'positivo': 191, 'negativo': 83, 'ratio': 2.2857142857142856},
#  'girl': {'positivo': 34, 'negativo': 17, 'ratio': 1.9444444444444444},
#  'best': {'positivo': 49, 'negativo': 16, 'ratio': 2.9411764705882355},
#  'wish': {'positivo': 29, 'negativo': 63, 'ratio': 0.46875},
#  'reason': {'positivo': 10, 'negativo': 3, 'ratio': 2.75},
#  'epic': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'soundtrack': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'shout': {'positivo': 11, 'negativo': 0, 'ratio': 12.0},
#  'ad': {'positivo': 10, 'negativo': 1, 'ratio': 5.5},
#  'video': {'positivo': 29, 'negativo': 20, 'ratio': 1.4285714285714286},
#  'playlist': {'positivo': 5, 'negativo': 2, 'ratio': 2.0},
#  'would': {'positivo': 70, 'negativo': 54, 'ratio': 1.290909090909091},
#  'dear': {'positivo': 15, 'negativo': 11, 'ratio': 1.3333333333333333},
#  'jordan': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'okay': {'positivo': 31, 'negativo': 29, 'ratio': 1.0666666666666667},
#  'fake': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'gameplay': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  ';)': {'positivo': 22, 'negativo': 0, 'ratio': 23.0},
#  'haha': {'positivo': 44, 'negativo': 24, 'ratio': 1.8},
#  'im': {'positivo': 38, 'negativo': 108, 'ratio': 0.3577981651376147},
#  'kid': {'positivo': 13, 'negativo': 16, 'ratio': 0.8235294117647058},
#  'stuff': {'positivo': 11, 'negativo': 8, 'ratio': 1.3333333333333333},
#  'exactli': {'positivo': 5, 'negativo': 5, 'ratio': 1.0},
#  'product': {'positivo': 11, 'negativo': 3, 'ratio': 3.0},
#  'line': {'positivo': 6, 'negativo': 7, 'ratio': 0.875},
#  'etsi': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'shop': {'positivo': 12, 'negativo': 8, 'ratio': 1.4444444444444444},
#  'check': {'positivo': 38, 'negativo': 16, 'ratio': 2.2941176470588234},
#  'vacat': {'positivo': 5, 'negativo': 2, 'ratio': 2.0},
#  'recharg': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'normal': {'positivo': 5, 'negativo': 5, 'ratio': 1.0},
#  'charger': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'asleep': {'positivo': 7, 'negativo': 17, 'ratio': 0.4444444444444444},
#  'talk': {'positivo': 37, 'negativo': 40, 'ratio': 0.926829268292683},
#  'sooo': {'positivo': 6, 'negativo': 12, 'ratio': 0.5384615384615384},
#  'someon': {'positivo': 29, 'negativo': 39, 'ratio': 0.75},
#  'text': {'positivo': 12, 'negativo': 13, 'ratio': 0.9285714285714286},
#  'ye': {'positivo': 60, 'negativo': 39, 'ratio': 1.525},
#  'bet': {'positivo': 6, 'negativo': 8, 'ratio': 0.7777777777777778},
#  "he'll": {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'fit': {'positivo': 2, 'negativo': 2, 'ratio': 1.0},
#  'hear': {'positivo': 24, 'negativo': 26, 'ratio': 0.9259259259259259},
#  'speech': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'piti': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'green': {'positivo': 2, 'negativo': 7, 'ratio': 0.375},
#  'garden': {'positivo': 5, 'negativo': 2, 'ratio': 2.0},
#  'midnight': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'sun': {'positivo': 6, 'negativo': 8, 'ratio': 0.7777777777777778},
#  'beauti': {'positivo': 45, 'negativo': 10, 'ratio': 4.181818181818182},
#  'canal': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'dasvidaniya': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'till': {'positivo': 16, 'negativo': 6, 'ratio': 2.4285714285714284},
#  'scout': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'sg': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'futur': {'positivo': 9, 'negativo': 4, 'ratio': 2.0},
#  'wlan': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'pro': {'positivo': 4, 'negativo': 0, 'ratio': 5.0},
#  'confer': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'asia': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'chang': {'positivo': 20, 'negativo': 23, 'ratio': 0.875},
#  'lollipop': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  '🍭': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'nez': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'agnezmo': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'oley': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'mama': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'stand': {'positivo': 6, 'negativo': 6, 'ratio': 1.0},
#  'stronger': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'god': {'positivo': 14, 'negativo': 13, 'ratio': 1.0714285714285714},
#  'misti': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'babi': {'positivo': 17, 'negativo': 37, 'ratio': 0.47368421052631576},
#  'cute': {'positivo': 21, 'negativo': 37, 'ratio': 0.5789473684210527},
#  'woohoo': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  "can't": {'positivo': 31, 'negativo': 148, 'ratio': 0.21476510067114093},
#  'sign': {'positivo': 9, 'negativo': 8, 'ratio': 1.1111111111111112},
#  'yet': {'positivo': 12, 'negativo': 29, 'ratio': 0.43333333333333335},
#  'still': {'positivo': 37, 'negativo': 104, 'ratio': 0.3619047619047619},
#  'think': {'positivo': 48, 'negativo': 64, 'ratio': 0.7538461538461538},
#  'mka': {'positivo': 5, 'negativo': 0, 'ratio': 6.0},
#  'liam': {'positivo': 5, 'negativo': 1, 'ratio': 3.0},
#  'access': {'positivo': 3, 'negativo': 1, 'ratio': 2.0},
#  'welcom': {'positivo': 54, 'negativo': 5, 'ratio': 9.166666666666666},
#  'stat': {'positivo': 51, 'negativo': 0, 'ratio': 52.0},
#  'arriv': {'positivo': 57, 'negativo': 4, 'ratio': 11.6},
#  '1': {'positivo': 60, 'negativo': 19, 'ratio': 3.05},
#  'unfollow': {'positivo': 53, 'negativo': 8, 'ratio': 6.0},
#  'via': {'positivo': 60, 'negativo': 1, 'ratio': 30.5},
#  'surpris': {'positivo': 10, 'negativo': 5, 'ratio': 1.8333333333333333},
#  'figur': {'positivo': 5, 'negativo': 5, 'ratio': 1.0},
#  'happybirthdayemilybett': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'sweet': {'positivo': 16, 'negativo': 5, 'ratio': 2.8333333333333335},
#  'talent': {'positivo': 4, 'negativo': 2, 'ratio': 1.6666666666666667},
#  '2': {'positivo': 41, 'negativo': 33, 'ratio': 1.2352941176470589},
#  'plan': {'positivo': 21, 'negativo': 13, 'ratio': 1.5714285714285714},
#  'drain': {'positivo': 1, 'negativo': 3, 'ratio': 0.5},
#  'gotta': {'positivo': 4, 'negativo': 7, 'ratio': 0.625},
#  'timezon': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'parent': {'positivo': 4, 'negativo': 7, 'ratio': 0.625},
#  'proud': {'positivo': 11, 'negativo': 8, 'ratio': 1.3333333333333333},
#  'least': {'positivo': 14, 'negativo': 13, 'ratio': 1.0714285714285714},
#  'mayb': {'positivo': 17, 'negativo': 19, 'ratio': 0.9},
#  'sometim': {'positivo': 11, 'negativo': 15, 'ratio': 0.75},
#  'grade': {'positivo': 4, 'negativo': 1, 'ratio': 2.5},
#  'al': {'positivo': 3, 'negativo': 4, 'ratio': 0.8},
#  'grand': {'positivo': 4, 'negativo': 1, 'ratio': 2.5},
#  'manila_bro': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'chosen': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'let': {'positivo': 57, 'negativo': 31, 'ratio': 1.8125},
#  'around': {'positivo': 14, 'negativo': 17, 'ratio': 0.8333333333333334},
#  '..': {'positivo': 100, 'negativo': 89, 'ratio': 1.1222222222222222},
#  'side': {'positivo': 13, 'negativo': 6, 'ratio': 2.0},
#  'world': {'positivo': 23, 'negativo': 15, 'ratio': 1.5},
#  'eh': {'positivo': 2, 'negativo': 3, 'ratio': 0.75},
#  'take': {'positivo': 30, 'negativo': 37, 'ratio': 0.8157894736842105},
#  'care': {'positivo': 12, 'negativo': 13, 'ratio': 0.9285714285714286},
#  'final': {'positivo': 24, 'negativo': 32, 'ratio': 0.7575757575757576},
#  'fuck': {'positivo': 20, 'negativo': 47, 'ratio': 0.4375},
#  'weekend': {'positivo': 61, 'negativo': 21, 'ratio': 2.8181818181818183},
#  'real': {'positivo': 18, 'negativo': 17, 'ratio': 1.0555555555555556},
#  'x45': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'join': {'positivo': 21, 'negativo': 4, 'ratio': 4.4},
#  'hushedcallwithfraydo': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'gift': {'positivo': 7, 'negativo': 9, 'ratio': 0.8},
#  'yeahhh': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'hushedpinwithsammi': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'event': {'positivo': 7, 'negativo': 2, 'ratio': 2.6666666666666665},
#  'might': {'positivo': 21, 'negativo': 10, 'ratio': 2.0},
#  'luv': {'positivo': 4, 'negativo': 2, 'ratio': 1.6666666666666667},
#  'realli': {'positivo': 66, 'negativo': 103, 'ratio': 0.6442307692307693},
#  'appreci': {'positivo': 28, 'negativo': 2, 'ratio': 9.666666666666666},
#  'share': {'positivo': 41, 'negativo': 8, 'ratio': 4.666666666666667},
#  'wow': {'positivo': 14, 'negativo': 4, 'ratio': 3.0},
#  'tom': {'positivo': 5, 'negativo': 3, 'ratio': 1.5},
#  'gym': {'positivo': 3, 'negativo': 5, 'ratio': 0.6666666666666666},
#  'monday': {'positivo': 7, 'negativo': 7, 'ratio': 1.0},
#  'invit': {'positivo': 15, 'negativo': 1, 'ratio': 8.0},
#  'scope': {'positivo': 5, 'negativo': 0, 'ratio': 6.0},
#  'friend': {'positivo': 40, 'negativo': 30, 'ratio': 1.3225806451612903},
#  'nude': {'positivo': 1, 'negativo': 4, 'ratio': 0.4},
#  'sleep': {'positivo': 35, 'negativo': 71, 'ratio': 0.5},
#  'birthday': {'positivo': 53, 'negativo': 16, 'ratio': 3.176470588235294},
#  'want': {'positivo': 69, 'negativo': 185, 'ratio': 0.3763440860215054},
#  't-shirt': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'cool': {'positivo': 29, 'negativo': 4, 'ratio': 6.0},
#  'haw': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'phela': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'mom': {'positivo': 7, 'negativo': 10, 'ratio': 0.7272727272727273},
#  'obvious': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'princ': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'charm': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'stage': {'positivo': 2, 'negativo': 12, 'ratio': 0.23076923076923078},
#  'luck': {'positivo': 26, 'negativo': 5, 'ratio': 4.5},
#  'tyler': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'hipster': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'glass': {'positivo': 3, 'negativo': 2, 'ratio': 1.3333333333333333},
#  'marti': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'glad': {'positivo': 41, 'negativo': 2, 'ratio': 14.0},
#  'done': {'positivo': 40, 'negativo': 18, 'ratio': 2.1578947368421053},
#  'afternoon': {'positivo': 7, 'negativo': 2, 'ratio': 2.6666666666666665},
#  'read': {'positivo': 27, 'negativo': 15, 'ratio': 1.75},
#  'kahfi': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'finish': {'positivo': 15, 'negativo': 10, 'ratio': 1.4545454545454546},
#  'ohmyg': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'yaya': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'dub': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'stalk': {'positivo': 2, 'negativo': 3, 'ratio': 0.75},
#  'ig': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'gondooo': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'moo': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'tologooo': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'becom': {'positivo': 8, 'negativo': 4, 'ratio': 1.8},
#  'detail': {'positivo': 8, 'negativo': 3, 'ratio': 2.25},
#  'zzz': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'xx': {'positivo': 33, 'negativo': 15, 'ratio': 2.125},
#  'physiotherapi': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'hashtag': {'positivo': 3, 'negativo': 1, 'ratio': 2.0},
#  '💪': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'monica': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'miss': {'positivo': 17, 'negativo': 239, 'ratio': 0.075},
#  'sound': {'positivo': 20, 'negativo': 16, 'ratio': 1.2352941176470589},
#  'morn': {'positivo': 68, 'negativo': 23, 'ratio': 2.875},
#  "that'": {'positivo': 49, 'negativo': 46, 'ratio': 1.0638297872340425},
#  'x43': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'definit': {'positivo': 20, 'negativo': 2, 'ratio': 7.0},
#  'tri': {'positivo': 34, 'negativo': 58, 'ratio': 0.5932203389830508},
#  'tonight': {'positivo': 15, 'negativo': 20, 'ratio': 0.7619047619047619},
#  'took': {'positivo': 7, 'negativo': 7, 'ratio': 1.0},
#  'advic': {'positivo': 6, 'negativo': 0, 'ratio': 7.0},
#  'treviso': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'concert': {'positivo': 23, 'negativo': 9, 'ratio': 2.4},
#  'citi': {'positivo': 26, 'negativo': 11, 'ratio': 2.25},
#  'countri': {'positivo': 22, 'negativo': 5, 'ratio': 3.8333333333333335},
#  "i'll": {'positivo': 73, 'negativo': 36, 'ratio': 2.0},
#  'start': {'positivo': 56, 'negativo': 37, 'ratio': 1.5},
#  'fine': {'positivo': 7, 'negativo': 6, 'ratio': 1.1428571428571428},
#  'gorgeou': {'positivo': 9, 'negativo': 1, 'ratio': 5.0},
#  'xo': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'oven': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'roast': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'garlic': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'oliv': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'oil': {'positivo': 4, 'negativo': 1, 'ratio': 2.5},
#  'dri': {'positivo': 4, 'negativo': 1, 'ratio': 2.5},
#  'tomato': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'basil': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'centuri': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'tuna': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'right': {'positivo': 38, 'negativo': 41, 'ratio': 0.9285714285714286},
#  'back': {'positivo': 74, 'negativo': 98, 'ratio': 0.7575757575757576},
#  'atchya': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'even': {'positivo': 26, 'negativo': 52, 'ratio': 0.5094339622641509},
#  'almost': {'positivo': 8, 'negativo': 7, 'ratio': 1.125},
#  'chanc': {'positivo': 3, 'negativo': 14, 'ratio': 0.26666666666666666},
#  'cheer': {'positivo': 17, 'negativo': 3, 'ratio': 4.5},
#  'po': {'positivo': 3, 'negativo': 1, 'ratio': 2.0},
#  'ice': {'positivo': 6, 'negativo': 29, 'ratio': 0.23333333333333334},
#  'cream': {'positivo': 6, 'negativo': 27, 'ratio': 0.25},
#  'agre': {'positivo': 13, 'negativo': 4, 'ratio': 2.8},
#  '100': {'positivo': 6, 'negativo': 6, 'ratio': 1.0},
#  'heheheh': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'that': {'positivo': 10, 'negativo': 9, 'ratio': 1.1},
#  'point': {'positivo': 11, 'negativo': 9, 'ratio': 1.2},
#  'stay': {'positivo': 20, 'negativo': 21, 'ratio': 0.9545454545454546},
#  'home': {'positivo': 20, 'negativo': 52, 'ratio': 0.39622641509433965},
#  'soon': {'positivo': 38, 'negativo': 40, 'ratio': 0.9512195121951219},
#  'promis': {'positivo': 4, 'negativo': 3, 'ratio': 1.25},
#  'web': {'positivo': 4, 'negativo': 2, 'ratio': 1.6666666666666667},
#  'whatsapp': {'positivo': 3, 'negativo': 1, 'ratio': 2.0},
#  'volta': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'funcionar': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'com': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'iphon': {'positivo': 7, 'negativo': 4, 'ratio': 1.6},
#  'jailbroken': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'later': {'positivo': 11, 'negativo': 10, 'ratio': 1.0909090909090908},
#  '34': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'min': {'positivo': 7, 'negativo': 5, 'ratio': 1.3333333333333333},
#  'leia': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'appear': {'positivo': 3, 'negativo': 2, 'ratio': 1.3333333333333333},
#  'hologram': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'r2d2': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'w': {'positivo': 16, 'negativo': 16, 'ratio': 1.0},
#  'messag': {'positivo': 9, 'negativo': 8, 'ratio': 1.1111111111111112},
#  'obi': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'wan': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'sit': {'positivo': 7, 'negativo': 5, 'ratio': 1.3333333333333333},
#  'luke': {'positivo': 4, 'negativo': 5, 'ratio': 0.8333333333333334},
#  'inter': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  '3': {'positivo': 25, 'negativo': 26, 'ratio': 0.9629629629629629},
#  'ucl': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'arsen': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'small': {'positivo': 1, 'negativo': 8, 'ratio': 0.2222222222222222},
#  'team': {'positivo': 24, 'negativo': 13, 'ratio': 1.7857142857142858},
#  'pass': {'positivo': 10, 'negativo': 12, 'ratio': 0.8461538461538461},
#  '🚂': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'dewsburi': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'railway': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'station': {'positivo': 4, 'negativo': 3, 'ratio': 1.25},
#  'dew': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'west': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'yorkshir': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  '430': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'smh': {'positivo': 2, 'negativo': 4, 'ratio': 0.6},
#  '9:25': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'live': {'positivo': 21, 'negativo': 33, 'ratio': 0.6470588235294118},
#  'strang': {'positivo': 4, 'negativo': 0, 'ratio': 5.0},
#  'imagin': {'positivo': 5, 'negativo': 1, 'ratio': 3.0},
#  'megan': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'masaantoday': {'positivo': 4, 'negativo': 0, 'ratio': 5.0},
#  'a4': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'shweta': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'tripathi': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  '5': {'positivo': 15, 'negativo': 11, 'ratio': 1.3333333333333333},
#  '20': {'positivo': 5, 'negativo': 7, 'ratio': 0.75},
#  'kurta': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'half': {'positivo': 6, 'negativo': 9, 'ratio': 0.7},
#  'number': {'positivo': 11, 'negativo': 5, 'ratio': 2.0},
#  'wsalelov': {'positivo': 14, 'negativo': 5, 'ratio': 2.5},
#  'ah': {'positivo': 12, 'negativo': 15, 'ratio': 0.8125},
#  'larri': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'anyway': {'positivo': 14, 'negativo': 10, 'ratio': 1.3636363636363635},
#  'kinda': {'positivo': 12, 'negativo': 9, 'ratio': 1.3},
#  'goood': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'life': {'positivo': 36, 'negativo': 29, 'ratio': 1.2333333333333334},
#  'enn': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'could': {'positivo': 25, 'negativo': 51, 'ratio': 0.5},
#  'warmup': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  '15th': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'bath': {'positivo': 6, 'negativo': 0, 'ratio': 7.0},
#  'dum': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'andar': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'ram': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'sampath': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'sona': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'mohapatra': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'samantha': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'edward': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'mein': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'tulan': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'razi': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'wah': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'josh': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'alway': {'positivo': 48, 'negativo': 48, 'ratio': 1.0},
#  'smile': {'positivo': 47, 'negativo': 9, 'ratio': 4.8},
#  'pictur': {'positivo': 7, 'negativo': 14, 'ratio': 0.5333333333333333},
#  '16.20': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'giveitup': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'given': {'positivo': 3, 'negativo': 1, 'ratio': 2.0},
#  'ga': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'subsidi': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'initi': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'propos': {'positivo': 3, 'negativo': 2, 'ratio': 1.3333333333333333},
#  'delight': {'positivo': 4, 'negativo': 1, 'ratio': 2.5},
#  'yesterday': {'positivo': 4, 'negativo': 9, 'ratio': 0.5},
#  'x42': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'lmaoo': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'song': {'positivo': 16, 'negativo': 25, 'ratio': 0.6538461538461539},
#  'ever': {'positivo': 19, 'negativo': 25, 'ratio': 0.7692307692307693},
#  'shall': {'positivo': 5, 'negativo': 1, 'ratio': 3.0},
#  'littl': {'positivo': 29, 'negativo': 17, 'ratio': 1.6666666666666667},
#  'throwback': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'outli': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'island': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'cheung': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'chau': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'mui': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'wo': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'total': {'positivo': 5, 'negativo': 9, 'ratio': 0.6},
#  'differ': {'positivo': 10, 'negativo': 9, 'ratio': 1.1},
#  'kfckitchentour': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'kitchen': {'positivo': 3, 'negativo': 2, 'ratio': 1.3333333333333333},
#  'clean': {'positivo': 1, 'negativo': 6, 'ratio': 0.2857142857142857},
#  "i'm": {'positivo': 140, 'negativo': 266, 'ratio': 0.5280898876404494},
#  'cusp': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'test': {'positivo': 7, 'negativo': 6, 'ratio': 1.1428571428571428},
#  'water': {'positivo': 7, 'negativo': 8, 'ratio': 0.8888888888888888},
#  'reward': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'arummzz': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  "let'": {'positivo': 18, 'negativo': 2, 'ratio': 6.333333333333333},
#  'drive': {'positivo': 9, 'negativo': 13, 'ratio': 0.7142857142857143},
#  'travel': {'positivo': 19, 'negativo': 9, 'ratio': 2.0},
#  'yogyakarta': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'jeep': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'indonesia': {'positivo': 3, 'negativo': 1, 'ratio': 2.0},
#  'instamood': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'wanna': {'positivo': 23, 'negativo': 76, 'ratio': 0.3116883116883117},
#  'skype': {'positivo': 3, 'negativo': 6, 'ratio': 0.5714285714285714},
#  'may': {'positivo': 16, 'negativo': 15, 'ratio': 1.0625},
#  'nice': {'positivo': 70, 'negativo': 17, 'ratio': 3.9444444444444446},
#  'friendli': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'pretend': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'film': {'positivo': 8, 'negativo': 2, 'ratio': 3.0},
#  'congratul': {'positivo': 9, 'negativo': 2, 'ratio': 3.3333333333333335},
#  'winner': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'cheesydelight': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'contest': {'positivo': 5, 'negativo': 0, 'ratio': 6.0},
#  'address': {'positivo': 8, 'negativo': 3, 'ratio': 2.25},
#  'guy': {'positivo': 48, 'negativo': 45, 'ratio': 1.065217391304348},
#  'market': {'positivo': 5, 'negativo': 2, 'ratio': 2.0},
#  '24/7': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  '14': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'hour': {'positivo': 24, 'negativo': 26, 'ratio': 0.9259259259259259},
#  'leav': {'positivo': 11, 'negativo': 31, 'ratio': 0.375},
#  'without': {'positivo': 9, 'negativo': 20, 'ratio': 0.47619047619047616},
#  'delay': {'positivo': 1, 'negativo': 5, 'ratio': 0.3333333333333333},
#  'actual': {'positivo': 13, 'negativo': 20, 'ratio': 0.6666666666666666},
#  'easi': {'positivo': 7, 'negativo': 5, 'ratio': 1.3333333333333333},
#  'guess': {'positivo': 8, 'negativo': 13, 'ratio': 0.6428571428571429},
#  'train': {'positivo': 7, 'negativo': 10, 'ratio': 0.7272727272727273},
#  'wd': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'shift': {'positivo': 4, 'negativo': 5, 'ratio': 0.8333333333333334},
#  'engin': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'etc': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'sunburn': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'peel': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'blog': {'positivo': 27, 'negativo': 0, 'ratio': 28.0},
#  'huge': {'positivo': 9, 'negativo': 2, 'ratio': 3.3333333333333335},
#  'warm': {'positivo': 4, 'negativo': 3, 'ratio': 1.25},
#  '☆': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'complet': {'positivo': 10, 'negativo': 6, 'ratio': 1.5714285714285714},
#  'triangl': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'northern': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'ireland': {'positivo': 2, 'negativo': 2, 'ratio': 1.0},
#  'sight': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'smthng': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'fr': {'positivo': 3, 'negativo': 3, 'ratio': 1.0},
#  'hug': {'positivo': 11, 'negativo': 21, 'ratio': 0.5454545454545454},
#  'xoxo': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'uu': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'jaann': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'topnewfollow': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'connect': {'positivo': 13, 'negativo': 2, 'ratio': 4.666666666666667},
#  'wonder': {'positivo': 26, 'negativo': 9, 'ratio': 2.7},
#  'made': {'positivo': 38, 'negativo': 21, 'ratio': 1.7727272727272727},
#  'fluffi': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'insid': {'positivo': 7, 'negativo': 9, 'ratio': 0.8},
#  'pirouett': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'moos': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'trip': {'positivo': 12, 'negativo': 11, 'ratio': 1.0833333333333333},
#  'philli': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'decemb': {'positivo': 2, 'negativo': 2, 'ratio': 1.0},
#  "i'd": {'positivo': 13, 'negativo': 10, 'ratio': 1.2727272727272727},
#  'dude': {'positivo': 6, 'negativo': 10, 'ratio': 0.6363636363636364},
#  'x41': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'question': {'positivo': 15, 'negativo': 5, 'ratio': 2.6666666666666665},
#  'flaw': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'pain': {'positivo': 8, 'negativo': 17, 'ratio': 0.5},
#  'negat': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'strength': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'went': {'positivo': 10, 'negativo': 27, 'ratio': 0.39285714285714285},
#  'solo': {'positivo': 4, 'negativo': 6, 'ratio': 0.7142857142857143},
#  'move': {'positivo': 9, 'negativo': 11, 'ratio': 0.8333333333333334},
#  'fav': {'positivo': 11, 'negativo': 0, 'ratio': 12.0},
#  'nirvana': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'smell': {'positivo': 2, 'negativo': 2, 'ratio': 1.0},
#  'teen': {'positivo': 3, 'negativo': 5, 'ratio': 0.6666666666666666},
#  'spirit': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'rip': {'positivo': 3, 'negativo': 8, 'ratio': 0.4444444444444444},
#  'ami': {'positivo': 4, 'negativo': 2, 'ratio': 1.6666666666666667},
#  'winehous': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'coupl': {'positivo': 5, 'negativo': 2, 'ratio': 2.0},
#  'tomhiddleston': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'elizabetholsen': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'yaytheylookgreat': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'goodnight': {'positivo': 18, 'negativo': 1, 'ratio': 9.5},
#  'vid': {'positivo': 8, 'negativo': 0, 'ratio': 9.0},
#  'wake': {'positivo': 10, 'negativo': 18, 'ratio': 0.5789473684210527},
#  'gonna': {'positivo': 16, 'negativo': 44, 'ratio': 0.37777777777777777},
#  'shoot': {'positivo': 5, 'negativo': 6, 'ratio': 0.8571428571428571},
#  'itti': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'bitti': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'teeni': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'bikini': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'much': {'positivo': 73, 'negativo': 116, 'ratio': 0.6324786324786325},
#  '4th': {'positivo': 4, 'negativo': 1, 'ratio': 2.5},
#  'togeth': {'positivo': 6, 'negativo': 6, 'ratio': 1.0},
#  'end': {'positivo': 13, 'negativo': 36, 'ratio': 0.3783783783783784},
#  'xfile': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'content': {'positivo': 3, 'negativo': 1, 'ratio': 2.0},
#  'rain': {'positivo': 18, 'negativo': 36, 'ratio': 0.5135135135135135},
#  'fabul': {'positivo': 4, 'negativo': 0, 'ratio': 5.0},
#  'fantast': {'positivo': 8, 'negativo': 0, 'ratio': 9.0},
#  '♡': {'positivo': 12, 'negativo': 8, 'ratio': 1.4444444444444444},
#  'jb': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'forev': {'positivo': 5, 'negativo': 7, 'ratio': 0.75},
#  'belieb': {'positivo': 3, 'negativo': 1, 'ratio': 2.0},
#  'nighti': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'bug': {'positivo': 2, 'negativo': 2, 'ratio': 1.0},
#  'bite': {'positivo': 1, 'negativo': 3, 'ratio': 0.5},
#  'bracelet': {'positivo': 2, 'negativo': 2, 'ratio': 1.0},
#  'idea': {'positivo': 23, 'negativo': 8, 'ratio': 2.6666666666666665},
#  'foundri': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'game': {'positivo': 23, 'negativo': 25, 'ratio': 0.9230769230769231},
#  'sens': {'positivo': 6, 'negativo': 0, 'ratio': 7.0},
#  'pic': {'positivo': 21, 'negativo': 14, 'ratio': 1.4666666666666666},
#  'ef': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'phone': {'positivo': 16, 'negativo': 26, 'ratio': 0.6296296296296297},
#  'woot': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'derek': {'positivo': 1, 'negativo': 3, 'ratio': 0.5},
#  'use': {'positivo': 32, 'negativo': 31, 'ratio': 1.03125},
#  'parkshar': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'gloucestershir': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'aaaahhh': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'man': {'positivo': 16, 'negativo': 24, 'ratio': 0.68},
#  'traffic': {'positivo': 2, 'negativo': 5, 'ratio': 0.5},
#  'stress': {'positivo': 4, 'negativo': 9, 'ratio': 0.5},
#  'reliev': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  "how'r": {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'arbeloa': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'turn': {'positivo': 13, 'negativo': 13, 'ratio': 1.0},
#  '17': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'omg': {'positivo': 13, 'negativo': 48, 'ratio': 0.2857142857142857},
#  'say': {'positivo': 43, 'negativo': 47, 'ratio': 0.9166666666666666},
#  'europ': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'rise': {'positivo': 2, 'negativo': 2, 'ratio': 1.0},
#  'find': {'positivo': 20, 'negativo': 45, 'ratio': 0.45652173913043476},
#  'hard': {'positivo': 9, 'negativo': 30, 'ratio': 0.3225806451612903},
#  'believ': {'positivo': 7, 'negativo': 11, 'ratio': 0.6666666666666666},
#  'uncount': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'coz': {'positivo': 2, 'negativo': 3, 'ratio': 0.75},
#  'unlimit': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'cours': {'positivo': 11, 'negativo': 7, 'ratio': 1.5},
#  'teamposit': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'aldub': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  '☕': {'positivo': 3, 'negativo': 1, 'ratio': 2.0},
#  'rita': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'info': {'positivo': 10, 'negativo': 1, 'ratio': 5.5},
#  "we'd": {'positivo': 4, 'negativo': 0, 'ratio': 5.0},
#  'way': {'positivo': 34, 'negativo': 31, 'ratio': 1.09375},
#  'boy': {'positivo': 13, 'negativo': 10, 'ratio': 1.2727272727272727},
#  'x40': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'true': {'positivo': 19, 'negativo': 19, 'ratio': 1.0},
#  'sethi': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'high': {'positivo': 6, 'negativo': 8, 'ratio': 0.7777777777777778},
#  'exe': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'skeem': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'saam': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'peopl': {'positivo': 42, 'negativo': 57, 'ratio': 0.7413793103448276},
#  'polit': {'positivo': 2, 'negativo': 2, 'ratio': 1.0},
#  'izzat': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'wese': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'trust': {'positivo': 7, 'negativo': 1, 'ratio': 4.0},
#  'khawateen': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'k': {'positivo': 8, 'negativo': 8, 'ratio': 1.0},
#  'sath': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'mana': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'kar': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'deya': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'sort': {'positivo': 7, 'negativo': 6, 'ratio': 1.1428571428571428},
#  'smart': {'positivo': 5, 'negativo': 1, 'ratio': 3.0},
#  'hair': {'positivo': 7, 'negativo': 16, 'ratio': 0.47058823529411764},
#  'tbh': {'positivo': 5, 'negativo': 12, 'ratio': 0.46153846153846156},
#  'jacob': {'positivo': 2, 'negativo': 4, 'ratio': 0.6},
#  'g': {'positivo': 7, 'negativo': 7, 'ratio': 1.0},
#  'upgrad': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'tee': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'famili': {'positivo': 14, 'negativo': 9, 'ratio': 1.5},
#  'person': {'positivo': 14, 'negativo': 14, 'ratio': 1.0},
#  'two': {'positivo': 15, 'negativo': 13, 'ratio': 1.1428571428571428},
#  'convers': {'positivo': 6, 'negativo': 6, 'ratio': 1.0},
#  'onlin': {'positivo': 4, 'negativo': 13, 'ratio': 0.35714285714285715},
#  'mclaren': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'fridayfeel': {'positivo': 5, 'negativo': 1, 'ratio': 3.0},
#  'tgif': {'positivo': 8, 'negativo': 1, 'ratio': 4.5},
#  'squar': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'enix': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'bissmillah': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'ya': {'positivo': 19, 'negativo': 11, 'ratio': 1.6666666666666667},
#  'allah': {'positivo': 3, 'negativo': 3, 'ratio': 1.0},
#  "we'r": {'positivo': 25, 'negativo': 20, 'ratio': 1.2380952380952381},
#  'socent': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'startup': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'drop': {'positivo': 9, 'negativo': 6, 'ratio': 1.4285714285714286},
#  'your': {'positivo': 3, 'negativo': 5, 'ratio': 0.6666666666666666},
#  'arnd': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'town': {'positivo': 3, 'negativo': 11, 'ratio': 0.3333333333333333},
#  'basic': {'positivo': 4, 'negativo': 2, 'ratio': 1.6666666666666667},
#  'piss': {'positivo': 2, 'negativo': 2, 'ratio': 1.0},
#  'cup': {'positivo': 4, 'negativo': 2, 'ratio': 1.6666666666666667},
#  'also': {'positivo': 28, 'negativo': 17, 'ratio': 1.6111111111111112},
#  'terribl': {'positivo': 2, 'negativo': 10, 'ratio': 0.2727272727272727},
#  'complic': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'discuss': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'snapchat': {'positivo': 31, 'negativo': 64, 'ratio': 0.49230769230769234},
#  'lynettelow': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'kikmenow': {'positivo': 2, 'negativo': 5, 'ratio': 0.5},
#  'snapm': {'positivo': 1, 'negativo': 3, 'ratio': 0.5},
#  'hot': {'positivo': 20, 'negativo': 9, 'ratio': 2.1},
#  'amazon': {'positivo': 1, 'negativo': 4, 'ratio': 0.4},
#  'kikmeguy': {'positivo': 2, 'negativo': 5, 'ratio': 0.5},
#  'defin': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'grow': {'positivo': 6, 'negativo': 3, 'ratio': 1.75},
#  'sport': {'positivo': 4, 'negativo': 0, 'ratio': 5.0},
#  'rt': {'positivo': 9, 'negativo': 5, 'ratio': 1.6666666666666667},
#  'rakyat': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'write': {'positivo': 11, 'negativo': 8, 'ratio': 1.3333333333333333},
#  'sinc': {'positivo': 11, 'negativo': 33, 'ratio': 0.35294117647058826},
#  'mention': {'positivo': 18, 'negativo': 6, 'ratio': 2.7142857142857144},
#  'fli': {'positivo': 5, 'negativo': 8, 'ratio': 0.6666666666666666},
#  'fish': {'positivo': 3, 'negativo': 2, 'ratio': 1.3333333333333333},
#  'promot': {'positivo': 3, 'negativo': 3, 'ratio': 1.0},
#  'post': {'positivo': 16, 'negativo': 9, 'ratio': 1.7},
#  'cyber': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'ourdaughtersourprid': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'mypapamyprid': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'papa': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'coach': {'positivo': 2, 'negativo': 2, 'ratio': 1.0},
#  'posit': {'positivo': 3, 'negativo': 2, 'ratio': 1.3333333333333333},
#  'kha': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'atleast': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'x39': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'mango': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  "lassi'": {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  "monty'": {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'marvel': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'though': {'positivo': 16, 'negativo': 44, 'ratio': 0.37777777777777777},
#  'suspect': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'meant': {'positivo': 2, 'negativo': 4, 'ratio': 0.6},
#  '24': {'positivo': 3, 'negativo': 9, 'ratio': 0.4},
#  'hr': {'positivo': 2, 'negativo': 2, 'ratio': 1.0},
#  'touch': {'positivo': 7, 'negativo': 5, 'ratio': 1.3333333333333333},
#  'kepler': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  '452b': {'positivo': 4, 'negativo': 0, 'ratio': 5.0},
#  'chalna': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'hai': {'positivo': 7, 'negativo': 8, 'ratio': 0.8888888888888888},
#  'thankyou': {'positivo': 12, 'negativo': 2, 'ratio': 4.333333333333333},
#  'hazel': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'food': {'positivo': 6, 'negativo': 12, 'ratio': 0.5384615384615384},
#  'brooklyn': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'pta': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'awak': {'positivo': 8, 'negativo': 8, 'ratio': 1.0},
#  'okayi': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'awww': {'positivo': 12, 'negativo': 19, 'ratio': 0.65},
#  'ha': {'positivo': 18, 'negativo': 6, 'ratio': 2.7142857142857144},
#  'doc': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'splendid': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'spam': {'positivo': 1, 'negativo': 5, 'ratio': 0.3333333333333333},
#  'folder': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'amount': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'nigeria': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'claim': {'positivo': 1, 'negativo': 3, 'ratio': 0.5},
#  'rted': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'leg': {'positivo': 3, 'negativo': 4, 'ratio': 0.8},
#  'hurt': {'positivo': 4, 'negativo': 33, 'ratio': 0.14705882352941177},
#  'bad': {'positivo': 14, 'negativo': 54, 'ratio': 0.2727272727272727},
#  'mine': {'positivo': 11, 'negativo': 10, 'ratio': 1.0909090909090908},
#  'saturday': {'positivo': 5, 'negativo': 10, 'ratio': 0.5454545454545454},
#  'thaaank': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'puhon': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'happinesss': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'tnc': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'prior': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'notif': {'positivo': 2, 'negativo': 2, 'ratio': 1.0},
#  'fat': {'positivo': 1, 'negativo': 4, 'ratio': 0.4},
#  'co': {'positivo': 1, 'negativo': 6, 'ratio': 0.2857142857142857},
#  'probabl': {'positivo': 7, 'negativo': 6, 'ratio': 1.1428571428571428},
#  'ate': {'positivo': 4, 'negativo': 10, 'ratio': 0.45454545454545453},
#  'yuna': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'tamesid': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  '´': {'positivo': 3, 'negativo': 4, 'ratio': 0.8},
#  'googl': {'positivo': 5, 'negativo': 5, 'ratio': 1.0},
#  'account': {'positivo': 17, 'negativo': 17, 'ratio': 1.0},
#  'scouser': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'everyth': {'positivo': 10, 'negativo': 14, 'ratio': 0.7333333333333333},
#  'zoe': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'mate': {'positivo': 5, 'negativo': 2, 'ratio': 2.0},
#  'liter': {'positivo': 5, 'negativo': 13, 'ratio': 0.42857142857142855},
#  "they'r": {'positivo': 10, 'negativo': 13, 'ratio': 0.7857142857142857},
#  'samee': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'edgar': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'updat': {'positivo': 12, 'negativo': 10, 'ratio': 1.1818181818181819},
#  'log': {'positivo': 3, 'negativo': 1, 'ratio': 2.0},
#  'bring': {'positivo': 12, 'negativo': 8, 'ratio': 1.4444444444444444},
#  'abe': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'meet': {'positivo': 26, 'negativo': 22, 'ratio': 1.173913043478261},
#  'x38': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'sigh': {'positivo': 3, 'negativo': 12, 'ratio': 0.3076923076923077},
#  'dreamili': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'pout': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'eye': {'positivo': 12, 'negativo': 11, 'ratio': 1.0833333333333333},
#  'quacketyquack': {'positivo': 6, 'negativo': 0, 'ratio': 7.0},
#  'funni': {'positivo': 15, 'negativo': 4, 'ratio': 3.2},
#  'happen': {'positivo': 13, 'negativo': 43, 'ratio': 0.3181818181818182},
#  'phil': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'em': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'del': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'rodder': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'els': {'positivo': 8, 'negativo': 4, 'ratio': 1.8},
#  'play': {'positivo': 37, 'negativo': 39, 'ratio': 0.95},
#  'newest': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'gamejam': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'irish': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'literatur': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'inaccess': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  "kareena'": {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'fan': {'positivo': 21, 'negativo': 17, 'ratio': 1.2222222222222223},
#  'brain': {'positivo': 10, 'negativo': 2, 'ratio': 3.6666666666666665},
#  'dot': {'positivo': 8, 'negativo': 2, 'ratio': 3.0},
#  'braindot': {'positivo': 8, 'negativo': 0, 'ratio': 9.0},
#  'fair': {'positivo': 4, 'negativo': 8, 'ratio': 0.5555555555555556},
#  'rush': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'either': {'positivo': 10, 'negativo': 11, 'ratio': 0.9166666666666666},
#  'brandi': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  '18': {'positivo': 5, 'negativo': 6, 'ratio': 0.8571428571428571},
#  'carniv': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'men': {'positivo': 8, 'negativo': 0, 'ratio': 9.0},
#  'put': {'positivo': 11, 'negativo': 10, 'ratio': 1.0909090909090908},
#  'mask': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'xavier': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'forneret': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'jennif': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'site': {'positivo': 7, 'negativo': 3, 'ratio': 2.0},
#  'free': {'positivo': 31, 'negativo': 14, 'ratio': 2.1333333333333333},
#  '50.000': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  '8': {'positivo': 10, 'negativo': 7, 'ratio': 1.375},
#  'ball': {'positivo': 7, 'negativo': 2, 'ratio': 2.6666666666666665},
#  'pool': {'positivo': 5, 'negativo': 3, 'ratio': 1.5},
#  'coin': {'positivo': 5, 'negativo': 0, 'ratio': 6.0},
#  'edit': {'positivo': 6, 'negativo': 4, 'ratio': 1.4},
#  'trish': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  '♥': {'positivo': 13, 'negativo': 20, 'ratio': 0.6666666666666666},
#  'grate': {'positivo': 5, 'negativo': 1, 'ratio': 3.0},
#  'three': {'positivo': 8, 'negativo': 6, 'ratio': 1.2857142857142858},
#  'comment': {'positivo': 7, 'negativo': 3, 'ratio': 2.0},
#  'wakeup': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'besid': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'dirti': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'sex': {'positivo': 4, 'negativo': 5, 'ratio': 0.8333333333333334},
#  'lmaooo': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  '😤': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'loui': {'positivo': 4, 'negativo': 4, 'ratio': 1.0},
#  "he'": {'positivo': 10, 'negativo': 19, 'ratio': 0.55},
#  'throw': {'positivo': 3, 'negativo': 2, 'ratio': 1.3333333333333333},
#  'caus': {'positivo': 11, 'negativo': 10, 'ratio': 1.0909090909090908},
#  'inspir': {'positivo': 6, 'negativo': 0, 'ratio': 7.0},
#  'ff': {'positivo': 40, 'negativo': 4, 'ratio': 8.2},
#  'twoof': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'gr8': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'wkend': {'positivo': 3, 'negativo': 0, 'ratio': 4.0},
#  'kind': {'positivo': 22, 'negativo': 9, 'ratio': 2.3},
#  'exhaust': {'positivo': 2, 'negativo': 2, 'ratio': 1.0},
#  'word': {'positivo': 17, 'negativo': 13, 'ratio': 1.2857142857142858},
#  'cheltenham': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'area': {'positivo': 4, 'negativo': 1, 'ratio': 2.5},
#  'kale': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'crisp': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'ruin': {'positivo': 5, 'negativo': 10, 'ratio': 0.5454545454545454},
#  'x37': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'open': {'positivo': 12, 'negativo': 12, 'ratio': 1.0},
#  'worldwid': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'outta': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'sfvbeta': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'vantast': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'xcylin': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'bundl': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'show': {'positivo': 20, 'negativo': 19, 'ratio': 1.05},
#  'internet': {'positivo': 2, 'negativo': 7, 'ratio': 0.375},
#  'price': {'positivo': 3, 'negativo': 4, 'ratio': 0.8},
#  'realisticli': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'pay': {'positivo': 8, 'negativo': 8, 'ratio': 1.0},
#  'net': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'educ': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'power': {'positivo': 6, 'negativo': 5, 'ratio': 1.1666666666666667},
#  'weapon': {'positivo': 1, 'negativo': 2, 'ratio': 0.6666666666666666},
#  'nelson': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'mandela': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'recent': {'positivo': 8, 'negativo': 0, 'ratio': 9.0},
#  'j': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'chenab': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'flow': {'positivo': 5, 'negativo': 0, 'ratio': 6.0},
#  'pakistan': {'positivo': 1, 'negativo': 1, 'ratio': 1.0},
#  'incredibleindia': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'teenchoic': {'positivo': 7, 'negativo': 5, 'ratio': 1.3333333333333333},
#  'choiceinternationalartist': {'positivo': 7,
#   'negativo': 5,
#   'ratio': 1.3333333333333333},
#  'superjunior': {'positivo': 7, 'negativo': 5, 'ratio': 1.3333333333333333},
#  'caught': {'positivo': 4, 'negativo': 1, 'ratio': 2.5},
#  'first': {'positivo': 41, 'negativo': 22, 'ratio': 1.826086956521739},
#  'salmon': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'super-blend': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'project': {'positivo': 6, 'negativo': 3, 'ratio': 1.75},
#  'youth@bipolaruk.org.uk': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'awesom': {'positivo': 35, 'negativo': 5, 'ratio': 6.0},
#  'stream': {'positivo': 12, 'negativo': 21, 'ratio': 0.5909090909090909},
#  'alma': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'mater': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'highschoolday': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'clientvisit': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'faith': {'positivo': 3, 'negativo': 1, 'ratio': 2.0},
#  'christian': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'school': {'positivo': 9, 'negativo': 22, 'ratio': 0.43478260869565216},
#  'lizaminnelli': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'upcom': {'positivo': 2, 'negativo': 0, 'ratio': 3.0},
#  'uk': {'positivo': 4, 'negativo': 6, 'ratio': 0.7142857142857143},
#  '😄': {'positivo': 3, 'negativo': 1, 'ratio': 2.0},
#  'singl': {'positivo': 4, 'negativo': 2, 'ratio': 1.6666666666666667},
#  'hill': {'positivo': 4, 'negativo': 1, 'ratio': 2.5},
#  'everi': {'positivo': 23, 'negativo': 11, 'ratio': 2.0},
#  'beat': {'positivo': 7, 'negativo': 1, 'ratio': 4.0},
#  'wrong': {'positivo': 9, 'negativo': 27, 'ratio': 0.35714285714285715},
#  'readi': {'positivo': 22, 'negativo': 9, 'ratio': 2.3},
#  'natur': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'pefumeri': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'workshop': {'positivo': 2, 'negativo': 1, 'ratio': 1.5},
#  'neal': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'yard': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'covent': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  'tomorrow': {'positivo': 31, 'negativo': 26, 'ratio': 1.1851851851851851},
#  'fback': {'positivo': 26, 'negativo': 0, 'ratio': 27.0},
#  'indo': {'positivo': 1, 'negativo': 0, 'ratio': 2.0},
#  ...}

# %% [markdown]
# **Observe la diferencia entre los ratios positivos y negativos. Emojis como :( y palabras como 'me' tienden a tener una connotación negativa. Otras palabras como 'glad', 'comunity' y 'arrives' tienden a encontrarse en los tw-eets positivos.**

# %% [markdown]
# # Análisis de Error
#
# En esta parte, veremos algunos tweets que el modelo no clasificó correctamente. ¿Por qué crees que ocurrieron las clasificaciones erróneas? ¿Hubo alguna suposición hecha por el modelo de Naive Bayes?

# %% [markdown]
# # Predice con tu propio tweet

# %%
# Testear con un propio tweet
